# %%
#import required libraries
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay, roc_auc_score, roc_curve
#from keras.applications.resnet import ResNet50, ResNet101, preprocess_input
#from keras.preprocessing.image import ImageDataGenerator

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.applications.resnet import ResNet50, ResNet101, preprocess_input  # Uncomment if using these models

# from keras.preprocessing import image_dataset_from_directory
from keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.model_selection import train_test_split
from keras import Model, layers, regularizers
from keras.metrics import Precision, Recall
from keras.models import Sequential
import matplotlib.pyplot as plt
from keras.metrics import AUC
from tensorflow import keras
import tensorflow as tf
import seaborn as sns
import pandas as pd
# import splitfolders
import numpy as np
import shutil
import glob
import os

sns.set()

# %%
# mount google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# #Useful Functions

# %%
# HELPER FUNCTION

#function to count images in subfolders:
def count_images(base_dir):
  allFiles = 0
  for subdir in os.listdir(base_dir):
      subdir_path = os.path.join(base_dir, subdir)
      if os.path.isdir(subdir_path):
          num_files = len(os.listdir(subdir_path))
          print(f"{num_files} files in subdirectory {subdir}.")
      allFiles = allFiles + num_files
  print(f"Total: {allFiles} files.")


def generators(shape, preprocessing, train_dir, val_dir, test_dir, batch_size):
  #create training and validation datasets of given image shape

    imgDatagen= ImageDataGenerator(
      preprocessing_function = preprocessing
    )

    height, width = shape

    train_dataset = imgDatagen.flow_from_directory(
      train_dir,
      target_size = (height, width),
      class_mode= 'categorical',
      batch_size = batch_size,
      shuffle=True
    )

    val_dataset = imgDatagen.flow_from_directory(
      val_dir,
      target_size = (height, width),
      class_mode= 'categorical',
      batch_size = batch_size,
      shuffle=True
    )

    test_dataset = imgDatagen.flow_from_directory(
      test_dir,
      target_size = (height, width),
      class_mode= 'categorical',
      batch_size = batch_size,
      shuffle=False
    )

    return train_dataset, val_dataset, test_dataset

def generators_train_val(shape, preprocessing, train_dir, val_dir, batch_size):
  #create training and validation datasets of given image shape

    imgDatagen= ImageDataGenerator(
      preprocessing_function = preprocessing
    )

    height, width = shape

    train_dataset = imgDatagen.flow_from_directory(
      train_dir,
      target_size = (height, width),
      class_mode= 'categorical',
      batch_size = batch_size,
      shuffle=True
    )

    val_dataset = imgDatagen.flow_from_directory(
      val_dir,
      target_size = (height, width),
      class_mode= 'categorical',
      batch_size = batch_size,
      shuffle=True
    )

    # test_dataset = imgDatagen.flow_from_directory(
    #   test_dir,
    #   target_size = (height, width),
    #   class_mode= 'categorical',
    #   batch_size = batch_size,
    #   shuffle=False
    # )

    return train_dataset, val_dataset

def generator_test(shape, preprocessing, test_dir, batch_size):
  #create training and validation datasets of given image shape

    imgDatagen= ImageDataGenerator(
      preprocessing_function = preprocessing
    )

    height, width = shape

    test_dataset = imgDatagen.flow_from_directory(
      test_dir,
      target_size = (height, width),
      class_mode= 'categorical',
      batch_size = batch_size,
      shuffle=False
    )

    return test_dataset

#function to plot accuracy and loss graphs:
def plot_acc_loss_graphs(model):
  auc_score = model.history.history['auc']
  val_auc_score = model.history.history['val_auc']
  loss =  model.history.history['loss']
  val_loss = model.history.history['val_loss']

  epochs = range(len(loss))

  # create a figure with 1 row and 3 columns
  fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15, 5))

  for ax in axes:
      ax.set_facecolor('lightgray')
      ax.set_xlabel('epochs')
      ax.spines['top'].set_visible(False)
      ax.spines['right'].set_visible(False)
      ax.spines['bottom'].set_visible(False)
      ax.spines['left'].set_visible(False)

  # Plot training and validation auc
  axes[0].plot(epochs, auc_score, color='crimson', label='Training AUC score')
  axes[0].plot(epochs, val_auc_score, color='darkgreen', label='Validation AUC score')
  axes[0].set_ylabel('score')
  axes[0].set_title('Training and Validation Accuracy')
  axes[0].legend()
  axes[0].grid()


  # Plot training and validation loss
  axes[1].plot(epochs, loss, color='crimson', label='Training loss')
  axes[1].plot(epochs, val_loss, color='darkgreen', label='Validation loss')
  axes[1].set_ylabel('loss')
  axes[1].set_title('Training and Validation Loss')
  axes[1].legend()
  axes[0].grid()

  plt.show()


#function to plot classification report, AUROC and confusion matrix

def plot_evaluation_graphs(y_pred, test_dataset):
  true_images, true_labels = next(test_dataset)

  pred_rn = pd.get_dummies(np.argmax(y_pred, axis=-1)).to_numpy().astype(np.float32)

  # classification report
  print(classification_report(true_labels, pred_rn, target_names=classes))

  for label in range(class_count):
    fpr,tpr,thresholds = roc_curve(true_labels[:,label], y_pred[:,label])
    roc_auc = roc_auc_score(true_labels[:,label], y_pred[:,label])

  # create a figure with 1 row and 3 columns
  fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15, 5))

  # evaluation results
  axes[0].plot([0,1],[0,1],'k:',label='Random')
  axes[0].plot(fpr, tpr, label='ROC curve for class {0} (AUC = {1:0.2f})'.format(classes[label], roc_auc))
  axes[0].set_xlabel('False Positive Rate')
  axes[0].set_ylabel('True Positive Rate')
  axes[0].set_title('AUROC metrics')
  axes[0].legend()
  axes[0].grid()

  # Confusion matrix results
  matrix = confusion_matrix(np.argmax(true_labels, axis=-1), np.argmax(pred_rn, axis=-1)) ## pred_x
  cm_display = ConfusionMatrixDisplay(confusion_matrix=matrix, display_labels=classes)
  cm_display.plot(ax=axes[1])
  axes[1].set_title('Confusion Matrix')
  axes[1].grid(False)

  plt.show()


#functions to view sample images

def view_5_images(x, y, p, classes):
    indices = range(5)

    x = x[indices]
    y = y[indices]
    p = p[indices]

    plt.figure(figsize=(10, 5))
    for i in range(5):
        plt.subplot(1, 5, 1 +i)
        plt.imshow(x[i])
        plt.xticks([])
        plt.yticks([])
        col = 'green' if np.argmax(y[i]) == np.argmax(p[i]) else 'red'
        plt.xlabel(classes[np.argmax(p[i])], color=col)
    plt.show()

def view_10_images(x, y, p, classes):
    indices = range(10)

    x = x[indices]
    y = y[indices]
    p = p[indices]

    plt.figure(figsize=(10, 5))
    for i in range(10):
        plt.subplot(2, 5, 1 +i)
        plt.imshow(x[i])
        plt.xticks([])
        plt.yticks([])
        col = 'green' if np.argmax(y[i]) == np.argmax(p[i]) else 'red'
        plt.xlabel(classes[np.argmax(p[i])], color=col)
    plt.show()

def view_2_images(x, y, p, classes):
    plt.figure(figsize=(10, 5))

    for class_index, class_name in enumerate(classes):
        # Select first two images for this class
        class_indices = np.where(np.argmax(y, axis=1) == class_index)[0][:2]

        for i, index in enumerate(class_indices):
            plt.subplot(2, 5, class_index+1+i*5)
            plt.imshow(x[index])
            plt.xticks([])
            plt.yticks([])
            col = 'green' if np.argmax(y[index]) == np.argmax(p[index]) else 'red'
            plt.xlabel(classes[np.argmax(p[index])], color=col)

    plt.tight_layout()
    plt.show()



#####
#predicted results

def get_dataframe_results(y_pred, saved_model, ds_test):
  # Get the predicted class (0 or 1)
  y_pred = saved_model.predict(ds_test, verbose=1)

  # Get the list of image filenames from the generator
  image_filenames = ds_test.filepaths

  # Get the predicted class (0 or 1)
  predicted_classes = np.argmax(y_pred, axis=1)

  # Create a DataFrame with image filenames and predicted class
  df_results = pd.DataFrame({
      'Image_Filename': image_filenames,
      'Predicted_Class': predicted_classes,
      'Prediction_0': y_pred[:, 0],
      'Prediction_1': y_pred[:, 1]
      # Add other columns if needed, depending on your data
  })
  return df_results

  #separate into training folders

def move_predicted_images_into_folders(folder_b, folder_m, df_results):
  # Create folders if they don't exist
  for folder in [folder_b, folder_m]:
      os.makedirs(folder, exist_ok=True)

  # Iterate through the DataFrame and move images based on predicted class
  for index, row in df_results.iterrows():
      image_filename = row['Image_Filename']
      predicted_class = row['Predicted_Class']

      if predicted_class == 0:
          destination_folder = folder_b
      elif predicted_class == 1:
          destination_folder = folder_m
      else:
          # Handle other cases if needed
          continue

      # Construct the destination path
      destination_path = os.path.join(destination_folder, os.path.basename(image_filename))

      # Move the file
      shutil.copy(image_filename, destination_path)

  print("Images moved successfully.")

def copy_jpg_images(source_folder, destination_folder):
    # Ensure the source folder exists
    if not os.path.exists(source_folder):
        print(f"Source folder '{source_folder}' does not exist.")
        return

    # Ensure the destination folder exists, create it if not
    os.makedirs(destination_folder, exist_ok=True)

    # Iterate through files in the source folder
    for file in os.listdir(source_folder):
        source_path = os.path.join(source_folder, file)

        # Check if the file is a JPG image
        if file.lower().endswith('.jpg'):
            destination_path = os.path.join(destination_folder, file)

            # Copy the file to the destination folder
            shutil.copy2(source_path, destination_path)

    print("Images copied successfully.")

def count_images_in_folder(folder_path):
    # Ensure the folder path exists
    if not os.path.exists(folder_path):
        print(f"Folder '{folder_path}' does not exist.")
        return 0

    # Get the list of files in the folder
    files = os.listdir(folder_path)

    # Filter only files (not directories)
    image_files = [file for file in files if os.path.isfile(os.path.join(folder_path, file))]

    # Count the number of image files
    num_images = len(image_files)

    return num_images

# %% [markdown]
# #Load Dataset

# %%
all_labels_df = pd.read_csv(r'/content/drive/MyDrive/All mixed/all_data_labels_loc_aug.csv')
all_labels_df.shape
# Out:
# (956, 3)

# %%
all_labels_df
# Out:
#                        filename   label folder_location
# 0                  benign (102)  benign           cairo
# 1                  benign (112)  benign           cairo
# 2                  benign (114)  benign           cairo
# 3                  benign (115)  benign           cairo
# 4                  benign (155)  benign           cairo
# ..                          ...     ...             ...
# 951    flipped_patient86_RT_bi2  benign          ecurei
# 952  flipped_patient56_LT_1_bi2  benign          ecurei
# 953       flipped_patient12_bi2  benign          ecurei
# 954       flipped_patient13_bi2  benign          ecurei
# 955  flipped_patient69_LT_4_bi3  benign          ecurei
#
# [956 rows x 3 columns]

# %%
parent_dir = r'/content/drive/MyDrive/All mixed/cls/wsl/round1'
classes = ['benign', 'malignant']
split_data=['test','train','val']
class_count=len(classes)
classes_map = dict(zip(classes,range(len(classes)))) #{'benign': 0, 'malignant': 1}

for i in split_data:
  class_dict = {key:len(glob.glob(f'{parent_dir}/{i}/{key}/*.jpg')) for key in classes}

# %%
for i in split_data:
  print(i)
  class_dict = {key:len(glob.glob(f'{parent_dir}/{i}/{key}/*.jpg')) for key in classes}
  print( {key:len(glob.glob(f'{parent_dir}/{i}/{key}/*.jpg')) for key in classes})
# Out:
# test
# {'benign': 131, 'malignant': 131}
# train
# {'benign': 130, 'malignant': 130}
# val
# {'benign': 67, 'malignant': 67}

# %%
print(f'class map: {classes_map} and class dictionary: {class_dict} of {class_count} classes')
# Out:
# class map: {'benign': 0, 'malignant': 1} and class dictionary: {'benign': 67, 'malignant': 67} of 2 classes

# %% [markdown]
# #Setup folders

# %%
train_dir='/content/drive/MyDrive/All mixed/cls/wsl/round1/train'
val_dir='/content/drive/MyDrive/All mixed/cls/wsl/round1/val'
test_dir='/content/drive/MyDrive/All mixed/cls/wsl/round1/test'

# %%
count_images(train_dir)
count_images(val_dir)
count_images(test_dir)
# Out:
# 130 files in subdirectory malignant.
# 130 files in subdirectory benign.
# Total: 260 files.
# 67 files in subdirectory malignant.
# 67 files in subdirectory benign.
# Total: 134 files.
# 131 files in subdirectory malignant.
# 131 files in subdirectory benign.
# Total: 262 files.

# %% [markdown]
# #**WSL ROUND ONE**

# %% [markdown]
# #ResNet50

# %% [markdown]
# ###Create and preprocess datasets

# %%
#preprocess the datasets
ds_train_rn, ds_val_rn = generators_train_val((224,224), preprocess_input, train_dir, val_dir,8)
ds_test_rn=generator_test((224,224), preprocess_input, test_dir,262)
# Out:
# Found 260 images belonging to 2 classes.
# Found 134 images belonging to 2 classes.
# Found 262 images belonging to 2 classes.

# %% [markdown]
# ###Train, Compile & Fit Model

# %%
pre_trained_model_rs = Sequential();

pre_trained_model_rs = ResNet50(input_shape=(224,224, 3),
                             include_top = False,
                             weights = 'imagenet',
                             pooling='avg',
                             classes=2
                             )
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 [==============================] - 3s 0us/step

# %%
# Freeze layers
for layer in pre_trained_model_rs.layers:
  layer.trainable = False

x = pre_trained_model_rs.output
# x = layers.Flatten()(x)
# # x = layers.GlobalAveragePooling2D()(x)
# x = layers.Dense(512, activation='relu')(x)
x = layers.Dense(64, activation='relu')(x)
# # x = layers.BatchNormalization()
x = layers.Dropout(0.5)(x)
output= layers.Dense(class_count, activation='softmax')(x)

#resnet50 model
resnet_model = Model(inputs=pre_trained_model_rs.input, outputs=output)

# %%
#model architecture
#resnet_model.summary()

# %%
# Compile model
resnet_model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
              loss=tf.keras.losses.CategoricalCrossentropy(),
              metrics=[AUC(name='auc')]
              )

# Train model
resnet_model.fit(ds_train_rn,
          validation_data=ds_val_rn,
          epochs=200,
          callbacks=[tf.keras.callbacks.EarlyStopping(monitor='val_auc', patience=50),
                    #  tf.keras.callbacks.ModelCheckpoint(monitor='val_auc')
                     ]
          )
# Out:
# Epoch 1/200
# 33/33 [==============================] - 7s 99ms/step - loss: 0.7257 - auc: 0.7820 - val_loss: 0.5793 - val_auc: 0.8740
# Epoch 2/200
# 33/33 [==============================] - 2s 65ms/step - loss: 0.3819 - auc: 0.9068 - val_loss: 0.3664 - val_auc: 0.9179
# Epoch 3/200
# 33/33 [==============================] - 2s 62ms/step - loss: 0.2619 - auc: 0.9573 - val_loss: 0.3590 - val_auc: 0.9264
# Epoch 4/200
# 33/33 [==============================] - 2s 62ms/step - loss: 0.3256 - auc: 0.9348 - val_loss: 0.3531 - val_auc: 0.9248
# Epoch 5/200
# 33/33 [==============================] - 2s 63ms/step - loss: 0.2772 - auc: 0.9523 - val_loss: 0.3614 - val_auc: 0.9277
# Epoch 6/200
# 33/33 [==============================] - 2s 63ms/step - loss: 0.1972 - auc: 0.9766 - val_loss: 0.3892 - val_auc: 0.9221
# Epoch 7/200
# 33/33 [==============================] - 2s 64ms/step - loss: 0.2027 - auc: 0.9748 - val_loss: 0.3507 - val_auc: 0.9319
# Epoch 8/200
# 33/33 [==============================] - 2s 67ms/step - loss: 0.1768 - auc: 0.9825 - val_loss: 0.3567 - val_auc: 0.9351
# Epoch 9/200
# 33/33 [==============================] - 2s 63ms/step - loss: 0.1737 - auc: 0.9821 - val_loss: 0.3472 - val_auc: 0.9385
# Epoch 10/200
# 33/33 [==============================] - 2s 66ms/step - loss: 0.1354 - auc: 0.9895 - val_loss: 0.3785 - val_auc: 0.9368
# Epoch 11/200
# 33/33 [==============================] - 2s 65ms/step - loss: 0.1362 - auc: 0.9895 - val_loss: 0.3369 - val_auc: 0.9396
# Epoch 12/200
# 33/33 [==============================] - 2s 63ms/step - loss: 0.1218 - auc: 0.9912 - val_loss: 0.3729 - val_auc: 0.9385
# Epoch 13/200
# 33/33 [==============================] - 2s 64ms/step - loss: 0.0993 - auc: 0.9964 - val_loss: 0.4150 - val_auc: 0.9302
# Epoch 14/200
# 33/33 [==============================] - 2s 64ms/step - loss: 0.1072 - auc: 0.9930 - val_loss: 0.4501 - val_auc: 0.9287
# Epoch 15/200
# 33/33 [==============================] - 2s 61ms/step - loss: 0.0698 - auc: 0.9986 - val_loss: 0.4067 - val_auc: 0.9338
# Epoch 16/200
# 33/33 [==============================] - 2s 62ms/step - loss: 0.0805 - auc: 0.9959 - val_loss: 0.4617 - val_auc: 0.9325
# Epoch 17/200
# 33/33 [==============================] - 2s 63ms/step - loss: 0.0480 - auc: 0.9993 - val_loss: 0.5012 - val_auc: 0.9272
# Epoch 18/200
# 33/33 [==============================] - 2s 64ms/step - loss: 0.0589 - auc: 0.9987 - val_loss: 0.4588 - val_auc: 0.9326
# Epoch 19/200
# 33/33 [==============================] - 2s 67ms/step - loss: 0.0634 - auc: 0.9985 - val_loss: 0.4674 - val_auc: 0.9330
# Epoch 20/200
# 33/33 [==============================] - 2s 68ms/step - loss: 0.0706 - auc: 0.9974 - val_loss: 0.4738 - val_auc: 0.9285
# Epoch 21/200
# 33/33 [==============================] - 2s 68ms/step - loss: 0.0808 - auc: 0.9959 - val_loss: 0.4828 - val_auc: 0.9252
# Epoch 22/200
# 33/33 [==============================] - 2s 63ms/step - loss: 0.0595 - auc: 0.9984 - val_loss: 0.4636 - val_auc: 0.9330
# Epoch 23/200
# 33/33 [==============================] - 2s 66ms/step - loss: 0.0518 - auc: 0.9983 - val_loss: 0.4837 - val_auc: 0.9275
# Epoch 24/200
# 33/33 [==============================] - 2s 64ms/step - loss: 0.0402 - auc: 0.9996 - val_loss: 0.5600 - val_auc: 0.9260
# Epoch 25/200
# 33/33 [==============================] - 2s 65ms/step - loss: 0.0543 - auc: 0.9984 - val_loss: 0.6182 - val_auc: 0.9232
# Epoch 26/200
# 33/33 [==============================] - 2s 63ms/step - loss: 0.0357 - auc: 0.9996 - val_loss: 0.5832 - val_auc: 0.9276
# Epoch 27/200
# 33/33 [==============================] - 2s 61ms/step - loss: 0.0272 - auc: 0.9999 - val_loss: 0.5581 - val_auc: 0.9241
# Epoch 28/200
# 33/33 [==============================] - 2s 65ms/step - loss: 0.0306 - auc: 0.9998 - val_loss: 0.5505 - val_auc: 0.9183
# Epoch 29/200
# 33/33 [==============================] - 2s 66ms/step - loss: 0.0284 - auc: 1.0000 - val_loss: 0.6501 - val_auc: 0.9172
# Epoch 30/200
# 33/33 [==============================] - 2s 63ms/step - loss: 0.0190 - auc: 1.0000 - val_loss: 0.6088 - val_auc: 0.9236
# Epoch 31/200
# 33/33 [==============================] - 2s 66ms/step - loss: 0.0236 - auc: 1.0000 - val_loss: 0.6110 - val_auc: 0.9212
# Epoch 32/200
# 33/33 [==============================] - 2s 63ms/step - loss: 0.0186 - auc: 1.0000 - val_loss: 0.6032 - val_auc: 0.9213
# Epoch 33/200
# 33/33 [==============================] - 2s 62ms/step - loss: 0.0455 - auc: 0.9988 - val_loss: 0.5292 - val_auc: 0.9190
# Epoch 34/200
# 33/33 [==============================] - 2s 63ms/step - loss: 0.0209 - auc: 0.9999 - val_loss: 0.5612 - val_auc: 0.9228
# Epoch 35/200
# 33/33 [==============================] - 2s 61ms/step - loss: 0.0143 - auc: 1.0000 - val_loss: 0.7105 - val_auc: 0.9133
# Epoch 36/200
# 33/33 [==============================] - 2s 63ms/step - loss: 0.0091 - auc: 1.0000 - val_loss: 0.6888 - val_auc: 0.9154
# Epoch 37/200
# 33/33 [==============================] - 2s 66ms/step - loss: 0.0130 - auc: 1.0000 - val_loss: 0.6466 - val_auc: 0.9190
# Epoch 38/200
# 33/33 [==============================] - 2s 63ms/step - loss: 0.0304 - auc: 0.9995 - val_loss: 0.6078 - val_auc: 0.9179
# Epoch 39/200
# 33/33 [==============================] - 2s 63ms/step - loss: 0.0205 - auc: 0.9999 - val_loss: 0.5996 - val_auc: 0.9170
# Epoch 40/200
# 33/33 [==============================] - 2s 64ms/step - loss: 0.0248 - auc: 0.9998 - val_loss: 0.6208 - val_auc: 0.9162
# Epoch 41/200
# 33/33 [==============================] - 2s 63ms/step - loss: 0.0303 - auc: 0.9996 - val_loss: 0.6423 - val_auc: 0.9131
# Epoch 42/200
# 33/33 [==============================] - 2s 63ms/step - loss: 0.0128 - auc: 1.0000 - val_loss: 0.8048 - val_auc: 0.9130
# Epoch 43/200
# 33/33 [==============================] - 2s 64ms/step - loss: 0.0249 - auc: 0.9995 - val_loss: 0.7324 - val_auc: 0.9178
# Epoch 44/200
# 33/33 [==============================] - 2s 64ms/step - loss: 0.0292 - auc: 0.9996 - val_loss: 0.7799 - val_auc: 0.9125
# Epoch 45/200
# 33/33 [==============================] - 2s 63ms/step - loss: 0.0297 - auc: 0.9996 - val_loss: 0.6999 - val_auc: 0.9199
# Epoch 46/200
# 33/33 [==============================] - 2s 63ms/step - loss: 0.0247 - auc: 0.9997 - val_loss: 0.6329 - val_auc: 0.9259
# Epoch 47/200
# 33/33 [==============================] - 2s 63ms/step - loss: 0.0264 - auc: 0.9996 - val_loss: 0.7872 - val_auc: 0.9069
# Epoch 48/200
# 33/33 [==============================] - 2s 63ms/step - loss: 0.0134 - auc: 1.0000 - val_loss: 0.8151 - val_auc: 0.9008
# Epoch 49/200
# 33/33 [==============================] - 2s 64ms/step - loss: 0.0097 - auc: 1.0000 - val_loss: 0.8005 - val_auc: 0.9013
# Epoch 50/200
# 33/33 [==============================] - 2s 62ms/step - loss: 0.0167 - auc: 1.0000 - val_loss: 0.7066 - val_auc: 0.9104
# Epoch 51/200
# 33/33 [==============================] - 2s 62ms/step - loss: 0.0307 - auc: 0.9994 - val_loss: 0.7767 - val_auc: 0.9230
# Epoch 52/200
# 33/33 [==============================] - 2s 63ms/step - loss: 0.0101 - auc: 1.0000 - val_loss: 0.7531 - val_auc: 0.9220
# Epoch 53/200
# 33/33 [==============================] - 2s 66ms/step - loss: 0.0146 - auc: 0.9999 - val_loss: 0.7412 - val_auc: 0.9098
# Epoch 54/200
# 33/33 [==============================] - 2s 66ms/step - loss: 0.0192 - auc: 0.9998 - val_loss: 0.8815 - val_auc: 0.9104
# Epoch 55/200
# 33/33 [==============================] - 2s 66ms/step - loss: 0.0107 - auc: 1.0000 - val_loss: 0.7689 - val_auc: 0.9159
# Epoch 56/200
# 33/33 [==============================] - 2s 63ms/step - loss: 0.0066 - auc: 1.0000 - val_loss: 0.8561 - val_auc: 0.9116
# Epoch 57/200
# 33/33 [==============================] - 2s 66ms/step - loss: 0.0080 - auc: 1.0000 - val_loss: 0.8438 - val_auc: 0.9049
# Epoch 58/200
# 33/33 [==============================] - 2s 62ms/step - loss: 0.0089 - auc: 1.0000 - val_loss: 0.8772 - val_auc: 0.9009
# Epoch 59/200
# 33/33 [==============================] - 2s 64ms/step - loss: 0.0214 - auc: 0.9997 - val_loss: 0.8237 - val_auc: 0.8995
# Epoch 60/200
# 33/33 [==============================] - 2s 67ms/step - loss: 0.0338 - auc: 0.9993 - val_loss: 0.7390 - val_auc: 0.9166
# Epoch 61/200
# 33/33 [==============================] - 2s 65ms/step - loss: 0.0194 - auc: 0.9999 - val_loss: 0.6688 - val_auc: 0.9118

# %% [markdown]
# ###Performance

# %%
plot_acc_loss_graphs(resnet_model)

# %% [markdown]
# ###Evaluation

# %%
##Evaluation
# resnet_model.save('/content/drive/MyDrive/Research/models/resnet_model_ai.h5')
# Assuming 'model' is your TensorFlow model
resnet_model.save("/content/drive/MyDrive/All mixed/cls/wsl/round1/resnet50_model_02.h5")
#load the model:
# saved_resnet_model = tf.keras.models.load_model('/content/drive/MyDrive/Research/models/resnet_model_ai.h5');

# %%
resnet_model = tf.keras.models.load_model('/content/drive/MyDrive/All mixed/cls/wsl/round1/resnet50_model_02.h5')

# %%
y_pred_rn = resnet_model.predict(ds_test_rn, verbose=1)
print(f'y_pred_shape:{y_pred_rn.shape} and shape[0] is: {y_pred_rn.shape[0]}')
# Out:
# 1/1 [==============================] - 18s 18s/step
# y_pred_shape:(262, 2) and shape[0] is: 262

# %%
plot_evaluation_graphs(y_pred_rn, ds_test_rn)
# Out:
#               precision    recall  f1-score   support
#
#       benign       0.86      0.92      0.89       131
#    malignant       0.91      0.85      0.88       131
#
#    micro avg       0.89      0.89      0.89       262
#    macro avg       0.89      0.89      0.89       262
# weighted avg       0.89      0.89      0.89       262
#  samples avg       0.89      0.89      0.89       262

# %% [markdown]
# ###Smaller generator - TAKEN

# %% [markdown]
# ####Create and preprocess datasets

# %%
import torch
from torch.utils.data import Dataset, DataLoader
data_test,true_labels=next(ds_test_rn)
# Define a custom dataset
class CustomDataset(Dataset):
    def __init__(self, data, labels):
        self.data = data
        self.labels = labels

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        return self.data[idx], self.labels[idx]

# Assuming you have your data and labels in numpy arrays data_train and labels_train
data_train = data_test.astype(np.float32)  # Make sure data is in the correct format
labels_train = y_pred_rn.astype(np.int64)  # Make sure labels are in the correct format

# Create a Dataset object
dataset = CustomDataset(data_train, labels_train)

# Create a DataLoader from the Dataset
data_loader = DataLoader(dataset, batch_size=262, shuffle=True)

# %%
data_loader
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-0d203074b114> in <cell line: 1>()
# ----> 1 data_loader
#
# NameError: name 'data_loader' is not defined

# %%
import numpy as np
from keras.preprocessing.image import ImageDataGenerator

# Create an ImageDataGenerator
#data_generator = ImageDataGenerator(rescale=1./255)  # Add any other necessary preprocessing steps

# Convert DataLoader to a custom data generator function
def custom_generator(data_loader):
    imgDatagen= ImageDataGenerator(preprocessing_function = preprocessing)
    for batch_data, batch_labels in data_loader:
        yield batch_data.numpy(), batch_labels.numpy()  # Convert PyTorch tensors to numpy arrays

# Use the custom data generator to create a Keras DirectoryIterator-like object
keras_data_iterator = custom_generator(data_loader)

# Now you can use keras_data_iterator as a Keras data generator

# %%
def replace_labels(dataset, new_labels):
    modified_dataset = []
    for data, _ in dataset:
        modified_dataset.append((data, new_labels))  # Replace the original labels with new_labels

    return modified_dataset

# Suppose you have a test_dataset object returned by the generator_test function
# And you have a list of new labels named new_labels

# Call the replace_labels function to replace the labels of test_dataset with new_labels
modified_test_dataset = replace_labels(ds_test_rn, y_pred_rn)

# %%
keras_data_iterator
# Out:
# <generator object custom_generator at 0x7968d72c7530>

# %%
import torch
from torch.utils.data import ConcatDataset, DataLoader

# %%
test_dir='/content/drive/MyDrive/All mixed/cls/wsl/round2/test'

# %%
#preprocess the datasets
ds_train_sm_rn, ds_val_sm_rn = generators_train_val((224,224), preprocess_input, train_dir, val_dir, 16)
ds_test_sm_rn = generator_test((224,224), preprocess_input, test_dir, 262)
# Out:
# Found 260 images belonging to 2 classes.
# Found 134 images belonging to 2 classes.
# Found 70 images belonging to 2 classes.

# %%
ds_train_sm_rn

# %%
# Merge the datasets of both data loaders into one dataset
ds_train_sm_rn = ConcatDataset([data_loader, ds_train_rn])

# %%
ds_train_sm_rn

# %% [markdown]
# ####Train, Compile & Fit Model

# %%
pre_trained_model_rs = Sequential();

pre_trained_model_rs = ResNet50(input_shape=(224,224, 3),
                             include_top = False,
                             weights = 'imagenet',
                             pooling='avg',
                             classes=2
                             )

# %%
# Freeze layers
for layer in pre_trained_model_rs.layers:
  layer.trainable = False

x = pre_trained_model_rs.output
x = layers.Flatten()(x)
# # x = layers.GlobalAveragePooling2D()(x)
# x = layers.Dense(512, activation='relu')(x)
x = layers.Dense(32, activation='relu')(x)
# # x = layers.BatchNormalization()
x = layers.Dropout(0.5)(x)
output= layers.Dense(class_count, activation='softmax')(x)

#resnet50 model
resnet_model = Model(inputs=pre_trained_model_rs.input, outputs=output)

# %%
#model architecture
resnet_model.summary()
# Out:
# Model: "model_4"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_4 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  conv1_pad (ZeroPadding2D)   (None, 230, 230, 3)          0         ['input_4[0][0]']
#
#  conv1_conv (Conv2D)         (None, 112, 112, 64)         9472      ['conv1_pad[0][0]']
#
#  conv1_bn (BatchNormalizati  (None, 112, 112, 64)         256       ['conv1_conv[0][0]']
#  on)
#
#  conv1_relu (Activation)     (None, 112, 112, 64)         0         ['conv1_bn[0][0]']
#
#  pool1_pad (ZeroPadding2D)   (None, 114, 114, 64)         0         ['conv1_relu[0][0]']
#
#  pool1_pool (MaxPooling2D)   (None, 56, 56, 64)           0         ['pool1_pad[0][0]']
#
#  conv2_block1_1_conv (Conv2  (None, 56, 56, 64)           4160      ['pool1_pool[0][0]']
#  D)
#
#  conv2_block1_1_bn (BatchNo  (None, 56, 56, 64)           256       ['conv2_block1_1_conv[0][0]']
#  rmalization)
#
#  conv2_block1_1_relu (Activ  (None, 56, 56, 64)           0         ['conv2_block1_1_bn[0][0]']
#  ation)
#
#  conv2_block1_2_conv (Conv2  (None, 56, 56, 64)           36928     ['conv2_block1_1_relu[0][0]']
#  D)
#
#  conv2_block1_2_bn (BatchNo  (None, 56, 56, 64)           256       ['conv2_block1_2_conv[0][0]']
#  rmalization)
#
#  conv2_block1_2_relu (Activ  (None, 56, 56, 64)           0         ['conv2_block1_2_bn[0][0]']
#  ation)
#
#  conv2_block1_0_conv (Conv2  (None, 56, 56, 256)          16640     ['pool1_pool[0][0]']
#  D)
#
#  conv2_block1_3_conv (Conv2  (None, 56, 56, 256)          16640     ['conv2_block1_2_relu[0][0]']
#  D)
#
#  conv2_block1_0_bn (BatchNo  (None, 56, 56, 256)          1024      ['conv2_block1_0_conv[0][0]']
#  rmalization)
#
#  conv2_block1_3_bn (BatchNo  (None, 56, 56, 256)          1024      ['conv2_block1_3_conv[0][0]']
#  rmalization)
#
#  conv2_block1_add (Add)      (None, 56, 56, 256)          0         ['conv2_block1_0_bn[0][0]',
#                                                                      'conv2_block1_3_bn[0][0]']
#
#  conv2_block1_out (Activati  (None, 56, 56, 256)          0         ['conv2_block1_add[0][0]']
#  on)
#
#  conv2_block2_1_conv (Conv2  (None, 56, 56, 64)           16448     ['conv2_block1_out[0][0]']
#  D)
#
#  conv2_block2_1_bn (BatchNo  (None, 56, 56, 64)           256       ['conv2_block2_1_conv[0][0]']
#  rmalization)
#
#  conv2_block2_1_relu (Activ  (None, 56, 56, 64)           0         ['conv2_block2_1_bn[0][0]']
#  ation)
#
#  conv2_block2_2_conv (Conv2  (None, 56, 56, 64)           36928     ['conv2_block2_1_relu[0][0]']
#  D)
#
#  conv2_block2_2_bn (BatchNo  (None, 56, 56, 64)           256       ['conv2_block2_2_conv[0][0]']
#  rmalization)
#
#  conv2_block2_2_relu (Activ  (None, 56, 56, 64)           0         ['conv2_block2_2_bn[0][0]']
#  ation)
#
#  conv2_block2_3_conv (Conv2  (None, 56, 56, 256)          16640     ['conv2_block2_2_relu[0][0]']
#  D)
#
#  conv2_block2_3_bn (BatchNo  (None, 56, 56, 256)          1024      ['conv2_block2_3_conv[0][0]']
#  rmalization)
#
#  conv2_block2_add (Add)      (None, 56, 56, 256)          0         ['conv2_block1_out[0][0]',
#                                                                      'conv2_block2_3_bn[0][0]']
#
#  conv2_block2_out (Activati  (None, 56, 56, 256)          0         ['conv2_block2_add[0][0]']
#  on)
#
#  conv2_block3_1_conv (Conv2  (None, 56, 56, 64)           16448     ['conv2_block2_out[0][0]']
#  D)
#
#  conv2_block3_1_bn (BatchNo  (None, 56, 56, 64)           256       ['conv2_block3_1_conv[0][0]']
#  rmalization)
#
#  conv2_block3_1_relu (Activ  (None, 56, 56, 64)           0         ['conv2_block3_1_bn[0][0]']
#  ation)
#
#  conv2_block3_2_conv (Conv2  (None, 56, 56, 64)           36928     ['conv2_block3_1_relu[0][0]']
#  D)
#
#  conv2_block3_2_bn (BatchNo  (None, 56, 56, 64)           256       ['conv2_block3_2_conv[0][0]']
#  rmalization)
#
#  conv2_block3_2_relu (Activ  (None, 56, 56, 64)           0         ['conv2_block3_2_bn[0][0]']
#  ation)
#
#  conv2_block3_3_conv (Conv2  (None, 56, 56, 256)          16640     ['conv2_block3_2_relu[0][0]']
#  D)
#
#  conv2_block3_3_bn (BatchNo  (None, 56, 56, 256)          1024      ['conv2_block3_3_conv[0][0]']
#  rmalization)
#
#  conv2_block3_add (Add)      (None, 56, 56, 256)          0         ['conv2_block2_out[0][0]',
#                                                                      'conv2_block3_3_bn[0][0]']
#
#  conv2_block3_out (Activati  (None, 56, 56, 256)          0         ['conv2_block3_add[0][0]']
#  on)
#
#  conv3_block1_1_conv (Conv2  (None, 28, 28, 128)          32896     ['conv2_block3_out[0][0]']
#  D)
#
#  conv3_block1_1_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block1_1_conv[0][0]']
#  rmalization)
#
#  conv3_block1_1_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block1_1_bn[0][0]']
#  ation)
#
#  conv3_block1_2_conv (Conv2  (None, 28, 28, 128)          147584    ['conv3_block1_1_relu[0][0]']
#  D)
#
#  conv3_block1_2_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block1_2_conv[0][0]']
#  rmalization)
#
#  conv3_block1_2_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block1_2_bn[0][0]']
#  ation)
#
#  conv3_block1_0_conv (Conv2  (None, 28, 28, 512)          131584    ['conv2_block3_out[0][0]']
#  D)
#
#  conv3_block1_3_conv (Conv2  (None, 28, 28, 512)          66048     ['conv3_block1_2_relu[0][0]']
#  D)
#
#  conv3_block1_0_bn (BatchNo  (None, 28, 28, 512)          2048      ['conv3_block1_0_conv[0][0]']
#  rmalization)
#
#  conv3_block1_3_bn (BatchNo  (None, 28, 28, 512)          2048      ['conv3_block1_3_conv[0][0]']
#  rmalization)
#
#  conv3_block1_add (Add)      (None, 28, 28, 512)          0         ['conv3_block1_0_bn[0][0]',
#                                                                      'conv3_block1_3_bn[0][0]']
#
#  conv3_block1_out (Activati  (None, 28, 28, 512)          0         ['conv3_block1_add[0][0]']
#  on)
#
#  conv3_block2_1_conv (Conv2  (None, 28, 28, 128)          65664     ['conv3_block1_out[0][0]']
#  D)
#
#  conv3_block2_1_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block2_1_conv[0][0]']
#  rmalization)
#
#  conv3_block2_1_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block2_1_bn[0][0]']
#  ation)
#
#  conv3_block2_2_conv (Conv2  (None, 28, 28, 128)          147584    ['conv3_block2_1_relu[0][0]']
#  D)
#
#  conv3_block2_2_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block2_2_conv[0][0]']
#  rmalization)
#
#  conv3_block2_2_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block2_2_bn[0][0]']
#  ation)
#
#  conv3_block2_3_conv (Conv2  (None, 28, 28, 512)          66048     ['conv3_block2_2_relu[0][0]']
#  D)
#
#  conv3_block2_3_bn (BatchNo  (None, 28, 28, 512)          2048      ['conv3_block2_3_conv[0][0]']
#  rmalization)
#
#  conv3_block2_add (Add)      (None, 28, 28, 512)          0         ['conv3_block1_out[0][0]',
#                                                                      'conv3_block2_3_bn[0][0]']
#
#  conv3_block2_out (Activati  (None, 28, 28, 512)          0         ['conv3_block2_add[0][0]']
#  on)
#
#  conv3_block3_1_conv (Conv2  (None, 28, 28, 128)          65664     ['conv3_block2_out[0][0]']
#  D)
#
#  conv3_block3_1_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block3_1_conv[0][0]']
#  rmalization)
#
#  conv3_block3_1_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block3_1_bn[0][0]']
#  ation)
#
#  conv3_block3_2_conv (Conv2  (None, 28, 28, 128)          147584    ['conv3_block3_1_relu[0][0]']
#  D)
#
#  conv3_block3_2_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block3_2_conv[0][0]']
#  rmalization)
#
#  conv3_block3_2_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block3_2_bn[0][0]']
#  ation)
#
#  conv3_block3_3_conv (Conv2  (None, 28, 28, 512)          66048     ['conv3_block3_2_relu[0][0]']
#  D)
#
#  conv3_block3_3_bn (BatchNo  (None, 28, 28, 512)          2048      ['conv3_block3_3_conv[0][0]']
#  rmalization)
#
#  conv3_block3_add (Add)      (None, 28, 28, 512)          0         ['conv3_block2_out[0][0]',
#                                                                      'conv3_block3_3_bn[0][0]']
#
#  conv3_block3_out (Activati  (None, 28, 28, 512)          0         ['conv3_block3_add[0][0]']
#  on)
#
#  conv3_block4_1_conv (Conv2  (None, 28, 28, 128)          65664     ['conv3_block3_out[0][0]']
#  D)
#
#  conv3_block4_1_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block4_1_conv[0][0]']
#  rmalization)
#
#  conv3_block4_1_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block4_1_bn[0][0]']
#  ation)
#
#  conv3_block4_2_conv (Conv2  (None, 28, 28, 128)          147584    ['conv3_block4_1_relu[0][0]']
#  D)
#
#  conv3_block4_2_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block4_2_conv[0][0]']
#  rmalization)
#
#  conv3_block4_2_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block4_2_bn[0][0]']
#  ation)
#
#  conv3_block4_3_conv (Conv2  (None, 28, 28, 512)          66048     ['conv3_block4_2_relu[0][0]']
#  D)
#
#  conv3_block4_3_bn (BatchNo  (None, 28, 28, 512)          2048      ['conv3_block4_3_conv[0][0]']
#  rmalization)
#
#  conv3_block4_add (Add)      (None, 28, 28, 512)          0         ['conv3_block3_out[0][0]',
#                                                                      'conv3_block4_3_bn[0][0]']
#
#  conv3_block4_out (Activati  (None, 28, 28, 512)          0         ['conv3_block4_add[0][0]']
#  on)
#
#  conv4_block1_1_conv (Conv2  (None, 14, 14, 256)          131328    ['conv3_block4_out[0][0]']
#  D)
#
#  conv4_block1_1_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block1_1_conv[0][0]']
#  rmalization)
#
#  conv4_block1_1_relu (Activ  (None, 14, 14, 256)          0         ['conv4_block1_1_bn[0][0]']
#  ation)
#
#  conv4_block1_2_conv (Conv2  (None, 14, 14, 256)          590080    ['conv4_block1_1_relu[0][0]']
#  D)
#
#  conv4_block1_2_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block1_2_conv[0][0]']
#  rmalization)
#
#  conv4_block1_2_relu (Activ  (None, 14, 14, 256)          0         ['conv4_block1_2_bn[0][0]']
#  ation)
#
#  conv4_block1_0_conv (Conv2  (None, 14, 14, 1024)         525312    ['conv3_block4_out[0][0]']
#  D)
#
#  conv4_block1_3_conv (Conv2  (None, 14, 14, 1024)         263168    ['conv4_block1_2_relu[0][0]']
#  D)
#
#  conv4_block1_0_bn (BatchNo  (None, 14, 14, 1024)         4096      ['conv4_block1_0_conv[0][0]']
#  rmalization)
#
#  conv4_block1_3_bn (BatchNo  (None, 14, 14, 1024)         4096      ['conv4_block1_3_conv[0][0]']
#  rmalization)
#
#  conv4_block1_add (Add)      (None, 14, 14, 1024)         0         ['conv4_block1_0_bn[0][0]',
#                                                                      'conv4_block1_3_bn[0][0]']
#
#  conv4_block1_out (Activati  (None, 14, 14, 1024)         0         ['conv4_block1_add[0][0]']
#  on)
#
#  conv4_block2_1_conv (Conv2  (None, 14, 14, 256)          262400    ['conv4_block1_out[0][0]']
#  D)
#
#  conv4_block2_1_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block2_1_conv[0][0]']
#  rmalization)
#
#  conv4_block2_1_relu (Activ  (None, 14, 14, 256)          0         ['conv4_block2_1_bn[0][0]']
#  ation)
#
#  conv4_block2_2_conv (Conv2  (None, 14, 14, 256)          590080    ['conv4_block2_1_relu[0][0]']
#  D)
#
#  conv4_block2_2_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block2_2_conv[0][0]']
#  rmalization)
#
#  conv4_block2_2_relu (Activ  (None, 14, 14, 256)          0         ['conv4_block2_2_bn[0][0]']
#  ation)
#
#  conv4_block2_3_conv (Conv2  (None, 14, 14, 1024)         263168    ['conv4_block2_2_relu[0][0]']
#  D)
#
#  conv4_block2_3_bn (BatchNo  (None, 14, 14, 1024)         4096      ['conv4_block2_3_conv[0][0]']
#  rmalization)
#
#  conv4_block2_add (Add)      (None, 14, 14, 1024)         0         ['conv4_block1_out[0][0]',
#                                                                      'conv4_block2_3_bn[0][0]']
#
#  conv4_block2_out (Activati  (None, 14, 14, 1024)         0         ['conv4_block2_add[0][0]']
#  on)
#
#  conv4_block3_1_conv (Conv2  (None, 14, 14, 256)          262400    ['conv4_block2_out[0][0]']
#  D)
#
#  conv4_block3_1_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block3_1_conv[0][0]']
#  rmalization)
#
#  conv4_block3_1_relu (Activ  (None, 14, 14, 256)          0         ['conv4_block3_1_bn[0][0]']
#  ation)
#
#  conv4_block3_2_conv (Conv2  (None, 14, 14, 256)          590080    ['conv4_block3_1_relu[0][0]']
#  D)
#
#  conv4_block3_2_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block3_2_conv[0][0]']
#  rmalization)
#
#  conv4_block3_2_relu (Activ  (None, 14, 14, 256)          0         ['conv4_block3_2_bn[0][0]']
#  ation)
#
#  conv4_block3_3_conv (Conv2  (None, 14, 14, 1024)         263168    ['conv4_block3_2_relu[0][0]']
#  D)
#
#  conv4_block3_3_bn (BatchNo  (None, 14, 14, 1024)         4096      ['conv4_block3_3_conv[0][0]']
#  rmalization)
#
#  conv4_block3_add (Add)      (None, 14, 14, 1024)         0         ['conv4_block2_out[0][0]',
#                                                                      'conv4_block3_3_bn[0][0]']
#
#  conv4_block3_out (Activati  (None, 14, 14, 1024)         0         ['conv4_block3_add[0][0]']
#  on)
#
#  conv4_block4_1_conv (Conv2  (None, 14, 14, 256)          262400    ['conv4_block3_out[0][0]']
#  D)
#
#  conv4_block4_1_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block4_1_conv[0][0]']
#  rmalization)
#
#  conv4_block4_1_relu (Activ  (None, 14, 14, 256)          0         ['conv4_block4_1_bn[0][0]']
#  ation)
#
#  conv4_block4_2_conv (Conv2  (None, 14, 14, 256)          590080    ['conv4_block4_1_relu[0][0]']
#  D)
#
#  conv4_block4_2_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block4_2_conv[0][0]']
#  rmalization)
#
#  conv4_block4_2_relu (Activ  (None, 14, 14, 256)          0         ['conv4_block4_2_bn[0][0]']
#  ation)
#
#  conv4_block4_3_conv (Conv2  (None, 14, 14, 1024)         263168    ['conv4_block4_2_relu[0][0]']
#  D)
#
#  conv4_block4_3_bn (BatchNo  (None, 14, 14, 1024)         4096      ['conv4_block4_3_conv[0][0]']
#  rmalization)
#
#  conv4_block4_add (Add)      (None, 14, 14, 1024)         0         ['conv4_block3_out[0][0]',
#                                                                      'conv4_block4_3_bn[0][0]']
#
#  conv4_block4_out (Activati  (None, 14, 14, 1024)         0         ['conv4_block4_add[0][0]']
#  on)
#
#  conv4_block5_1_conv (Conv2  (None, 14, 14, 256)          262400    ['conv4_block4_out[0][0]']
#  D)
#
#  conv4_block5_1_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block5_1_conv[0][0]']
#  rmalization)
#
#  conv4_block5_1_relu (Activ  (None, 14, 14, 256)          0         ['conv4_block5_1_bn[0][0]']
#  ation)
#
#  conv4_block5_2_conv (Conv2  (None, 14, 14, 256)          590080    ['conv4_block5_1_relu[0][0]']
#  D)
#
#  conv4_block5_2_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block5_2_conv[0][0]']
#  rmalization)
#
#  conv4_block5_2_relu (Activ  (None, 14, 14, 256)          0         ['conv4_block5_2_bn[0][0]']
#  ation)
#
#  conv4_block5_3_conv (Conv2  (None, 14, 14, 1024)         263168    ['conv4_block5_2_relu[0][0]']
#  D)
#
#  conv4_block5_3_bn (BatchNo  (None, 14, 14, 1024)         4096      ['conv4_block5_3_conv[0][0]']
#  rmalization)
#
#  conv4_block5_add (Add)      (None, 14, 14, 1024)         0         ['conv4_block4_out[0][0]',
#                                                                      'conv4_block5_3_bn[0][0]']
#
#  conv4_block5_out (Activati  (None, 14, 14, 1024)         0         ['conv4_block5_add[0][0]']
#  on)
#
#  conv4_block6_1_conv (Conv2  (None, 14, 14, 256)          262400    ['conv4_block5_out[0][0]']
#  D)
#
#  conv4_block6_1_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block6_1_conv[0][0]']
#  rmalization)
#
#  conv4_block6_1_relu (Activ  (None, 14, 14, 256)          0         ['conv4_block6_1_bn[0][0]']
#  ation)
#
#  conv4_block6_2_conv (Conv2  (None, 14, 14, 256)          590080    ['conv4_block6_1_relu[0][0]']
#  D)
#
#  conv4_block6_2_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block6_2_conv[0][0]']
#  rmalization)
#
#  conv4_block6_2_relu (Activ  (None, 14, 14, 256)          0         ['conv4_block6_2_bn[0][0]']
#  ation)
#
#  conv4_block6_3_conv (Conv2  (None, 14, 14, 1024)         263168    ['conv4_block6_2_relu[0][0]']
#  D)
#
#  conv4_block6_3_bn (BatchNo  (None, 14, 14, 1024)         4096      ['conv4_block6_3_conv[0][0]']
#  rmalization)
#
#  conv4_block6_add (Add)      (None, 14, 14, 1024)         0         ['conv4_block5_out[0][0]',
#                                                                      'conv4_block6_3_bn[0][0]']
#
#  conv4_block6_out (Activati  (None, 14, 14, 1024)         0         ['conv4_block6_add[0][0]']
#  on)
#
#  conv5_block1_1_conv (Conv2  (None, 7, 7, 512)            524800    ['conv4_block6_out[0][0]']
#  D)
#
#  conv5_block1_1_bn (BatchNo  (None, 7, 7, 512)            2048      ['conv5_block1_1_conv[0][0]']
#  rmalization)
#
#  conv5_block1_1_relu (Activ  (None, 7, 7, 512)            0         ['conv5_block1_1_bn[0][0]']
#  ation)
#
#  conv5_block1_2_conv (Conv2  (None, 7, 7, 512)            2359808   ['conv5_block1_1_relu[0][0]']
#  D)
#
#  conv5_block1_2_bn (BatchNo  (None, 7, 7, 512)            2048      ['conv5_block1_2_conv[0][0]']
#  rmalization)
#
#  conv5_block1_2_relu (Activ  (None, 7, 7, 512)            0         ['conv5_block1_2_bn[0][0]']
#  ation)
#
#  conv5_block1_0_conv (Conv2  (None, 7, 7, 2048)           2099200   ['conv4_block6_out[0][0]']
#  D)
#
#  conv5_block1_3_conv (Conv2  (None, 7, 7, 2048)           1050624   ['conv5_block1_2_relu[0][0]']
#  D)
#
#  conv5_block1_0_bn (BatchNo  (None, 7, 7, 2048)           8192      ['conv5_block1_0_conv[0][0]']
#  rmalization)
#
#  conv5_block1_3_bn (BatchNo  (None, 7, 7, 2048)           8192      ['conv5_block1_3_conv[0][0]']
#  rmalization)
#
#  conv5_block1_add (Add)      (None, 7, 7, 2048)           0         ['conv5_block1_0_bn[0][0]',
#                                                                      'conv5_block1_3_bn[0][0]']
#
#  conv5_block1_out (Activati  (None, 7, 7, 2048)           0         ['conv5_block1_add[0][0]']
#  on)
#
#  conv5_block2_1_conv (Conv2  (None, 7, 7, 512)            1049088   ['conv5_block1_out[0][0]']
#  D)
#
#  conv5_block2_1_bn (BatchNo  (None, 7, 7, 512)            2048      ['conv5_block2_1_conv[0][0]']
#  rmalization)
#
#  conv5_block2_1_relu (Activ  (None, 7, 7, 512)            0         ['conv5_block2_1_bn[0][0]']
#  ation)
#
#  conv5_block2_2_conv (Conv2  (None, 7, 7, 512)            2359808   ['conv5_block2_1_relu[0][0]']
#  D)
#
#  conv5_block2_2_bn (BatchNo  (None, 7, 7, 512)            2048      ['conv5_block2_2_conv[0][0]']
#  rmalization)
#
#  conv5_block2_2_relu (Activ  (None, 7, 7, 512)            0         ['conv5_block2_2_bn[0][0]']
#  ation)
#
#  conv5_block2_3_conv (Conv2  (None, 7, 7, 2048)           1050624   ['conv5_block2_2_relu[0][0]']
#  D)
#
#  conv5_block2_3_bn (BatchNo  (None, 7, 7, 2048)           8192      ['conv5_block2_3_conv[0][0]']
#  rmalization)
#
#  conv5_block2_add (Add)      (None, 7, 7, 2048)           0         ['conv5_block1_out[0][0]',
#                                                                      'conv5_block2_3_bn[0][0]']
#
#  conv5_block2_out (Activati  (None, 7, 7, 2048)           0         ['conv5_block2_add[0][0]']
#  on)
#
#  conv5_block3_1_conv (Conv2  (None, 7, 7, 512)            1049088   ['conv5_block2_out[0][0]']
#  D)
#
#  conv5_block3_1_bn (BatchNo  (None, 7, 7, 512)            2048      ['conv5_block3_1_conv[0][0]']
#  rmalization)
#
#  conv5_block3_1_relu (Activ  (None, 7, 7, 512)            0         ['conv5_block3_1_bn[0][0]']
#  ation)
#
#  conv5_block3_2_conv (Conv2  (None, 7, 7, 512)            2359808   ['conv5_block3_1_relu[0][0]']
#  D)
#
#  conv5_block3_2_bn (BatchNo  (None, 7, 7, 512)            2048      ['conv5_block3_2_conv[0][0]']
#  rmalization)
#
#  conv5_block3_2_relu (Activ  (None, 7, 7, 512)            0         ['conv5_block3_2_bn[0][0]']
#  ation)
#
#  conv5_block3_3_conv (Conv2  (None, 7, 7, 2048)           1050624   ['conv5_block3_2_relu[0][0]']
#  D)
#
#  conv5_block3_3_bn (BatchNo  (None, 7, 7, 2048)           8192      ['conv5_block3_3_conv[0][0]']
#  rmalization)
#
#  conv5_block3_add (Add)      (None, 7, 7, 2048)           0         ['conv5_block2_out[0][0]',
#                                                                      'conv5_block3_3_bn[0][0]']
#
#  conv5_block3_out (Activati  (None, 7, 7, 2048)           0         ['conv5_block3_add[0][0]']
#  on)
#
#  avg_pool (GlobalAveragePoo  (None, 2048)                 0         ['conv5_block3_out[0][0]']
#  ling2D)
#
#  flatten_3 (Flatten)         (None, 2048)                 0         ['avg_pool[0][0]']
#
#  dense_8 (Dense)             (None, 32)                   65568     ['flatten_3[0][0]']
#
#  dropout_4 (Dropout)         (None, 32)                   0         ['dense_8[0][0]']
#
#  dense_9 (Dense)             (None, 2)                    66        ['dropout_4[0][0]']
#
# ==================================================================================================
# Total params: 23653346 (90.23 MB)
# Trainable params: 65634 (256.38 KB)
# Non-trainable params: 23587712 (89.98 MB)
# __________________________________________________________________________________________________

# %%
# Compile model
resnet_model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
              loss=tf.keras.losses.CategoricalCrossentropy(),
              metrics=[AUC(name='auc')]
              )

# Train model
resnet_model.fit(ds_train_sm_rn,
          validation_data=ds_val_sm_rn,
          epochs=200,
          callbacks=[tf.keras.callbacks.EarlyStopping(monitor='val_auc', patience=15),
                    #  tf.keras.callbacks.ModelCheckpoint(monitor='val_auc')
                     ]
          )
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-37-7fe2b21d306f> in <cell line: 8>()
#       6
#       7 # Train model
# ----> 8 resnet_model.fit(ds_train_sm_rn,
#       9           validation_data=ds_val_sm_rn,
#      10           epochs=200,
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/data_adapter.py in select_data_adapter(x, y)
#    1103     if not adapter_cls:
#    1104         # TODO(scottzhu): This should be a less implementation-specific error.
# -> 1105         raise ValueError(
#    1106             "Failed to find data adapter that can handle input: {}, {}".format(
#    1107                 _type_name(x), _type_name(y)
#
# ValueError: Failed to find data adapter that can handle input: <class 'torch.utils.data.dataset.ConcatDataset'>, <class 'NoneType'>

# %% [markdown]
# ####Performance

# %%
plot_acc_loss_graphs(resnet_model)

# %% [markdown]
# ####Evaluation

# %%
##Evaluation
# resnet_model.save('/content/drive/MyDrive/Research/models/resnet_model_ai.h5')
# Assuming 'model' is your TensorFlow model
# resnet_model.save("/content/drive/MyDrive/Research/models/resnet50_sm_wsl_model_03.h5")
#load the model:
saved_resnet_model = tf.keras.models.load_model('/content/drive/MyDrive/Research/models/resnet50_sm_wsl_model_03.h5');

# %%
y_pred_rn = saved_resnet_model.predict(ds_test_sm_rn, verbose=1)
print(f'y_pred_shape:{y_pred_rn.shape} and shape[0] is: {y_pred_rn.shape[0]}')
# Out:
# 1/1 [==============================] - 15s 15s/step
# y_pred_shape:(262, 2) and shape[0] is: 262

# %%
true_images_rn, true_labels_rn = ds_test_sm_rn.next()

# %%
true_images_rn.shape
# Out:
# (262, 224, 224, 3)

# %%
plot_evaluation_graphs(y_pred_rn, ds_test_sm_rn)
# Out:
#               precision    recall  f1-score   support
#
#       benign       0.81      0.92      0.86       131
#    malignant       0.91      0.79      0.84       131
#
#    micro avg       0.85      0.85      0.85       262
#    macro avg       0.86      0.85      0.85       262
# weighted avg       0.86      0.85      0.85       262
#  samples avg       0.85      0.85      0.85       262

# %%
y_pred_rn.shape
# Out:
# (262, 2)

# %% [markdown]
# #Xception

# %% [markdown]
# ##Create and preprocess datasets

# %%
# def preprocess_xc(images, labels):
#   return tf.keras.applications.xception.preprocess_input(images), labels

# %%
ds_train_xc, ds_val_xc, ds_test_xc = generators((224,224), tf.keras.applications.xception.preprocess_input, train_dir, val_dir, test_dir, 70)
# Out:
# Found 260 images belonging to 2 classes.
# Found 134 images belonging to 2 classes.
# Found 0 images belonging to 2 classes.

# %%
imagesX, labelsX = ds_test_xc.next()
imagesX.shape
# Out:
# (0, 224, 224, 3)

# %% [markdown]
# ##Train, Compile & Fit Model

# %%
pre_trained_model_xc = Sequential();

# %%
pre_trained_model_xc = tf.keras.applications.Xception(input_shape=(224,224, 3),
                             include_top = False,
                             weights = 'imagenet',
                             pooling='avg',
                             classes=2
                             )

# Freeze layers
for layer in pre_trained_model_xc.layers:
  layer.trainable = False

x = pre_trained_model_xc.output
x = layers.Flatten()(x)
# x = layers.GlobalAveragePooling2D()(x)
# x = layers.Dense(512, activation='relu')(x)
# x = layers.Dropout(0.5)(x)
x = layers.Dense(32, activation='relu')(x)
x = layers.Dropout(0.5)(x)
output= layers.Dense(class_count, activation='softmax')(x)

#Xception model
xception_model = Model(pre_trained_model_xc.input, output)

# %%
xception_model.summary()

# %%
# Compile model 1e-5
xception_model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.000001),
              loss=tf.keras.losses.CategoricalCrossentropy(),
              metrics=[AUC(name='auc')]
              )

# Train model
xception_model.fit(ds_train_xc,
          validation_data=ds_val_xc,
          epochs=200,
          # callbacks=callback_params,
          # class_weight=class_weights,
          callbacks=[tf.keras.callbacks.EarlyStopping(monitor='val_auc', patience=3),
                    #  tf.keras.callbacks.ModelCheckpoint('models/xception_ai_{val_auc:.3f}.h5',
                    #                                     save_best_only=True,
                    #                                     save_weights_only=False,
                    #                                     monitor='val_auc')
                     ]
          )
# Out:
# Epoch 1/200
# 8/8 [==============================] - 8s 619ms/step - loss: 0.6843 - auc: 0.6059 - val_loss: 0.6648 - val_auc: 0.6453
# Epoch 2/200
# 8/8 [==============================] - 4s 433ms/step - loss: 0.6652 - auc: 0.6361 - val_loss: 0.6636 - val_auc: 0.6500
# Epoch 3/200
# 8/8 [==============================] - 4s 436ms/step - loss: 0.6504 - auc: 0.6674 - val_loss: 0.6626 - val_auc: 0.6527
# Epoch 4/200
# 8/8 [==============================] - 4s 525ms/step - loss: 0.6858 - auc: 0.6130 - val_loss: 0.6616 - val_auc: 0.6549
# Epoch 5/200
# 8/8 [==============================] - 4s 439ms/step - loss: 0.6486 - auc: 0.6681 - val_loss: 0.6606 - val_auc: 0.6547
# Epoch 6/200
# 8/8 [==============================] - 4s 451ms/step - loss: 0.6468 - auc: 0.6638 - val_loss: 0.6595 - val_auc: 0.6605
# Epoch 7/200
# 8/8 [==============================] - 4s 511ms/step - loss: 0.6675 - auc: 0.6319 - val_loss: 0.6584 - val_auc: 0.6619
# Epoch 8/200
# 8/8 [==============================] - 4s 551ms/step - loss: 0.6485 - auc: 0.6745 - val_loss: 0.6574 - val_auc: 0.6636
# Epoch 9/200
# 8/8 [==============================] - 4s 436ms/step - loss: 0.6641 - auc: 0.6509 - val_loss: 0.6565 - val_auc: 0.6663
# Epoch 10/200
# 8/8 [==============================] - 4s 540ms/step - loss: 0.6634 - auc: 0.6431 - val_loss: 0.6554 - val_auc: 0.6687
# Epoch 11/200
# 8/8 [==============================] - 4s 513ms/step - loss: 0.6507 - auc: 0.6626 - val_loss: 0.6545 - val_auc: 0.6708
# Epoch 12/200
# 8/8 [==============================] - 4s 485ms/step - loss: 0.6400 - auc: 0.6782 - val_loss: 0.6536 - val_auc: 0.6724
# Epoch 13/200
# 8/8 [==============================] - 4s 438ms/step - loss: 0.6778 - auc: 0.6178 - val_loss: 0.6527 - val_auc: 0.6728
# Epoch 14/200
# 8/8 [==============================] - 4s 442ms/step - loss: 0.6486 - auc: 0.6703 - val_loss: 0.6518 - val_auc: 0.6764
# Epoch 15/200
# 8/8 [==============================] - 5s 557ms/step - loss: 0.6573 - auc: 0.6489 - val_loss: 0.6509 - val_auc: 0.6794
# Epoch 16/200
# 8/8 [==============================] - 4s 438ms/step - loss: 0.6423 - auc: 0.6776 - val_loss: 0.6499 - val_auc: 0.6791
# Epoch 17/200
# 8/8 [==============================] - 4s 482ms/step - loss: 0.6508 - auc: 0.6585 - val_loss: 0.6490 - val_auc: 0.6798
# Epoch 18/200
# 8/8 [==============================] - 4s 490ms/step - loss: 0.6616 - auc: 0.6393 - val_loss: 0.6482 - val_auc: 0.6824
# Epoch 19/200
# 8/8 [==============================] - 4s 481ms/step - loss: 0.6652 - auc: 0.6404 - val_loss: 0.6473 - val_auc: 0.6839
# Epoch 20/200
# 8/8 [==============================] - 4s 439ms/step - loss: 0.6516 - auc: 0.6561 - val_loss: 0.6465 - val_auc: 0.6857
# Epoch 21/200
# 8/8 [==============================] - 4s 500ms/step - loss: 0.6409 - auc: 0.6854 - val_loss: 0.6456 - val_auc: 0.6875
# Epoch 22/200
# 8/8 [==============================] - 4s 505ms/step - loss: 0.6251 - auc: 0.7011 - val_loss: 0.6448 - val_auc: 0.6898
# Epoch 23/200
# 8/8 [==============================] - 4s 445ms/step - loss: 0.6374 - auc: 0.6819 - val_loss: 0.6440 - val_auc: 0.6917
# Epoch 24/200
# 8/8 [==============================] - 4s 439ms/step - loss: 0.6335 - auc: 0.6899 - val_loss: 0.6432 - val_auc: 0.6935
# Epoch 25/200
# 8/8 [==============================] - 5s 590ms/step - loss: 0.6333 - auc: 0.6871 - val_loss: 0.6424 - val_auc: 0.6956
# Epoch 26/200
# 8/8 [==============================] - 6s 652ms/step - loss: 0.6271 - auc: 0.6965 - val_loss: 0.6416 - val_auc: 0.6970
# Epoch 27/200
# 8/8 [==============================] - 4s 436ms/step - loss: 0.6423 - auc: 0.6776 - val_loss: 0.6408 - val_auc: 0.6984
# Epoch 28/200
# 8/8 [==============================] - 4s 543ms/step - loss: 0.6394 - auc: 0.6763 - val_loss: 0.6399 - val_auc: 0.7002
# Epoch 29/200
# 8/8 [==============================] - 4s 469ms/step - loss: 0.6329 - auc: 0.6920 - val_loss: 0.6391 - val_auc: 0.6987
# Epoch 30/200
# 8/8 [==============================] - 4s 446ms/step - loss: 0.6312 - auc: 0.6895 - val_loss: 0.6384 - val_auc: 0.7013
# Epoch 31/200
# 8/8 [==============================] - 4s 511ms/step - loss: 0.6337 - auc: 0.6911 - val_loss: 0.6376 - val_auc: 0.7043
# Epoch 32/200
# 8/8 [==============================] - 4s 529ms/step - loss: 0.6374 - auc: 0.6866 - val_loss: 0.6369 - val_auc: 0.7044
# Epoch 33/200
# 8/8 [==============================] - 4s 447ms/step - loss: 0.6307 - auc: 0.6947 - val_loss: 0.6362 - val_auc: 0.7062
# Epoch 34/200
# 8/8 [==============================] - 4s 445ms/step - loss: 0.6300 - auc: 0.7000 - val_loss: 0.6355 - val_auc: 0.7078
# Epoch 35/200
# 8/8 [==============================] - 4s 465ms/step - loss: 0.6160 - auc: 0.7169 - val_loss: 0.6347 - val_auc: 0.7084
# Epoch 36/200
# 8/8 [==============================] - 4s 514ms/step - loss: 0.6266 - auc: 0.6943 - val_loss: 0.6340 - val_auc: 0.7099
# Epoch 37/200
# 8/8 [==============================] - 4s 437ms/step - loss: 0.6328 - auc: 0.6942 - val_loss: 0.6333 - val_auc: 0.7115
# Epoch 38/200
# 8/8 [==============================] - 4s 447ms/step - loss: 0.6334 - auc: 0.6794 - val_loss: 0.6326 - val_auc: 0.7134
# Epoch 39/200
# 8/8 [==============================] - 4s 557ms/step - loss: 0.6151 - auc: 0.7161 - val_loss: 0.6319 - val_auc: 0.7138
# Epoch 40/200
# 8/8 [==============================] - 4s 495ms/step - loss: 0.5980 - auc: 0.7436 - val_loss: 0.6313 - val_auc: 0.7154
# Epoch 41/200
# 8/8 [==============================] - 4s 448ms/step - loss: 0.6118 - auc: 0.7176 - val_loss: 0.6306 - val_auc: 0.7156
# Epoch 42/200
# 8/8 [==============================] - 4s 556ms/step - loss: 0.6252 - auc: 0.7075 - val_loss: 0.6299 - val_auc: 0.7172
# Epoch 43/200
# 8/8 [==============================] - 5s 639ms/step - loss: 0.6259 - auc: 0.7000 - val_loss: 0.6292 - val_auc: 0.7177
# Epoch 44/200
# 8/8 [==============================] - 4s 446ms/step - loss: 0.6363 - auc: 0.6894 - val_loss: 0.6286 - val_auc: 0.7195
# Epoch 45/200
# 8/8 [==============================] - 4s 456ms/step - loss: 0.6068 - auc: 0.7307 - val_loss: 0.6279 - val_auc: 0.7207
# Epoch 46/200
# 8/8 [==============================] - 4s 567ms/step - loss: 0.6142 - auc: 0.7256 - val_loss: 0.6273 - val_auc: 0.7217
# Epoch 47/200
# 8/8 [==============================] - 4s 441ms/step - loss: 0.6275 - auc: 0.7014 - val_loss: 0.6267 - val_auc: 0.7221
# Epoch 48/200
# 8/8 [==============================] - 4s 450ms/step - loss: 0.6371 - auc: 0.6842 - val_loss: 0.6261 - val_auc: 0.7234
# Epoch 49/200
# 8/8 [==============================] - 4s 560ms/step - loss: 0.6281 - auc: 0.6944 - val_loss: 0.6254 - val_auc: 0.7229
# Epoch 50/200
# 8/8 [==============================] - 4s 472ms/step - loss: 0.6035 - auc: 0.7355 - val_loss: 0.6248 - val_auc: 0.7230
# Epoch 51/200
# 8/8 [==============================] - 4s 499ms/step - loss: 0.6168 - auc: 0.7205 - val_loss: 0.6242 - val_auc: 0.7241
# Epoch 52/200
# 8/8 [==============================] - 4s 469ms/step - loss: 0.6122 - auc: 0.7223 - val_loss: 0.6236 - val_auc: 0.7248
# Epoch 53/200
# 8/8 [==============================] - 4s 504ms/step - loss: 0.6043 - auc: 0.7388 - val_loss: 0.6230 - val_auc: 0.7276
# Epoch 54/200
# 8/8 [==============================] - 4s 440ms/step - loss: 0.6248 - auc: 0.7084 - val_loss: 0.6224 - val_auc: 0.7283
# Epoch 55/200
# 8/8 [==============================] - 4s 429ms/step - loss: 0.5941 - auc: 0.7547 - val_loss: 0.6217 - val_auc: 0.7290
# Epoch 56/200
# 8/8 [==============================] - 4s 515ms/step - loss: 0.6107 - auc: 0.7248 - val_loss: 0.6212 - val_auc: 0.7294
# Epoch 57/200
# 8/8 [==============================] - 4s 537ms/step - loss: 0.6146 - auc: 0.7258 - val_loss: 0.6206 - val_auc: 0.7299
# Epoch 58/200
# 8/8 [==============================] - 4s 431ms/step - loss: 0.5816 - auc: 0.7730 - val_loss: 0.6200 - val_auc: 0.7309
# Epoch 59/200
# 8/8 [==============================] - 4s 486ms/step - loss: 0.6084 - auc: 0.7298 - val_loss: 0.6195 - val_auc: 0.7327
# Epoch 60/200
# 8/8 [==============================] - 4s 532ms/step - loss: 0.6205 - auc: 0.7069 - val_loss: 0.6189 - val_auc: 0.7337
# Epoch 61/200
# 8/8 [==============================] - 4s 495ms/step - loss: 0.5847 - auc: 0.7635 - val_loss: 0.6184 - val_auc: 0.7344
# Epoch 62/200
# 8/8 [==============================] - 4s 439ms/step - loss: 0.6133 - auc: 0.7244 - val_loss: 0.6178 - val_auc: 0.7345
# Epoch 63/200
# 8/8 [==============================] - 4s 441ms/step - loss: 0.5866 - auc: 0.7626 - val_loss: 0.6173 - val_auc: 0.7358
# Epoch 64/200
# 8/8 [==============================] - 4s 490ms/step - loss: 0.6053 - auc: 0.7244 - val_loss: 0.6167 - val_auc: 0.7371
# Epoch 65/200
# 8/8 [==============================] - 4s 501ms/step - loss: 0.6028 - auc: 0.7421 - val_loss: 0.6162 - val_auc: 0.7364
# Epoch 66/200
# 8/8 [==============================] - 4s 490ms/step - loss: 0.6038 - auc: 0.7357 - val_loss: 0.6156 - val_auc: 0.7372
# Epoch 67/200
# 8/8 [==============================] - 4s 438ms/step - loss: 0.6007 - auc: 0.7377 - val_loss: 0.6151 - val_auc: 0.7375
# Epoch 68/200
# 8/8 [==============================] - 4s 494ms/step - loss: 0.5925 - auc: 0.7430 - val_loss: 0.6145 - val_auc: 0.7381
# Epoch 69/200
# 8/8 [==============================] - 4s 469ms/step - loss: 0.6029 - auc: 0.7336 - val_loss: 0.6140 - val_auc: 0.7384
# Epoch 70/200
# 8/8 [==============================] - 4s 446ms/step - loss: 0.5923 - auc: 0.7586 - val_loss: 0.6134 - val_auc: 0.7392
# Epoch 71/200
# 8/8 [==============================] - 4s 493ms/step - loss: 0.5960 - auc: 0.7455 - val_loss: 0.6129 - val_auc: 0.7400
# Epoch 72/200
# 8/8 [==============================] - 4s 531ms/step - loss: 0.6022 - auc: 0.7389 - val_loss: 0.6124 - val_auc: 0.7412
# Epoch 73/200
# 8/8 [==============================] - 4s 441ms/step - loss: 0.5950 - auc: 0.7568 - val_loss: 0.6118 - val_auc: 0.7414
# Epoch 74/200
# 8/8 [==============================] - 4s 433ms/step - loss: 0.5787 - auc: 0.7641 - val_loss: 0.6113 - val_auc: 0.7421
# Epoch 75/200
# 8/8 [==============================] - 4s 467ms/step - loss: 0.5847 - auc: 0.7563 - val_loss: 0.6107 - val_auc: 0.7421
# Epoch 76/200
# 8/8 [==============================] - 4s 529ms/step - loss: 0.5972 - auc: 0.7405 - val_loss: 0.6102 - val_auc: 0.7428
# Epoch 77/200
# 8/8 [==============================] - 4s 437ms/step - loss: 0.6138 - auc: 0.7217 - val_loss: 0.6096 - val_auc: 0.7423
# Epoch 78/200
# 8/8 [==============================] - 4s 441ms/step - loss: 0.5801 - auc: 0.7668 - val_loss: 0.6091 - val_auc: 0.7429
# Epoch 79/200
# 8/8 [==============================] - 4s 511ms/step - loss: 0.5975 - auc: 0.7455 - val_loss: 0.6086 - val_auc: 0.7428
# Epoch 80/200
# 8/8 [==============================] - 4s 475ms/step - loss: 0.6030 - auc: 0.7345 - val_loss: 0.6080 - val_auc: 0.7453
# Epoch 81/200
# 8/8 [==============================] - 4s 434ms/step - loss: 0.5793 - auc: 0.7720 - val_loss: 0.6075 - val_auc: 0.7460
# Epoch 82/200
# 8/8 [==============================] - 4s 437ms/step - loss: 0.5965 - auc: 0.7381 - val_loss: 0.6069 - val_auc: 0.7467
# Epoch 83/200
# 8/8 [==============================] - 4s 502ms/step - loss: 0.5815 - auc: 0.7657 - val_loss: 0.6064 - val_auc: 0.7480
# Epoch 84/200
# 8/8 [==============================] - 4s 481ms/step - loss: 0.5796 - auc: 0.7654 - val_loss: 0.6059 - val_auc: 0.7483
# Epoch 85/200
# 8/8 [==============================] - 4s 445ms/step - loss: 0.5833 - auc: 0.7604 - val_loss: 0.6054 - val_auc: 0.7491
# Epoch 86/200
# 8/8 [==============================] - 4s 538ms/step - loss: 0.5726 - auc: 0.7776 - val_loss: 0.6048 - val_auc: 0.7485
# Epoch 87/200
# 8/8 [==============================] - 4s 486ms/step - loss: 0.6005 - auc: 0.7366 - val_loss: 0.6043 - val_auc: 0.7489
# Epoch 88/200
# 8/8 [==============================] - 4s 438ms/step - loss: 0.6096 - auc: 0.7274 - val_loss: 0.6038 - val_auc: 0.7490

# %% [markdown]
# ##Performance

# %%
plot_acc_loss_graphs(xception_model)

# %% [markdown]
# ## Evaluation

# %%
#save model
xception_model.save('/content/drive/MyDrive/Research/models/xception_model_01.h5')

# %%
#load saved model:
saved_xception_model = tf.keras.models.load_model('/content/drive/MyDrive/Research/models/xception_model_ai.h5');

# %%
#predict
y_pred_xc = xception_model.predict(ds_test_xc)
print(f'y_pred_shape:{y_pred_xc.shape} and shape[0] is: {y_pred_xc.shape[0]}')
# Out:
# 1/1 [==============================] - 1s 933ms/step
# y_pred_shape:(70, 2) and shape[0] is: 70

# %%
plot_evaluation_graphs(y_pred_xc, ds_test_xc)
# Out:
#               precision    recall  f1-score   support
#
#       benign       0.47      0.46      0.46        35
#    malignant       0.47      0.49      0.48        35
#
#    micro avg       0.47      0.47      0.47        70
#    macro avg       0.47      0.47      0.47        70
# weighted avg       0.47      0.47      0.47        70
#  samples avg       0.47      0.47      0.47        70

# %% [markdown]
# ##View Sample Images

# %%
#view sample images
image_xc, label_xc = ds_test_xc.next()
view_2_images(image_xc, label_xc, y_pred_xc, classes)
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ##Smaller generator

# %% [markdown]
# ###Create and preprocess datasets

# %%
# def preprocess_xc(images, labels):
#   return tf.keras.applications.xception.preprocess_input(images), labels

# %%
ds_train_sm_xc, ds_val_sm_xc = generators_train_val((224,224), tf.keras.applications.xception.preprocess_input, train_dir, val_dir, 16)
ds_test_sm_xc = generator_test((224,224), tf.keras.applications.xception.preprocess_input, test_dir, 262)
# Out:
# Found 260 images belonging to 2 classes.
# Found 134 images belonging to 2 classes.
# Found 262 images belonging to 2 classes.
# Found 262 images belonging to 2 classes.

# %% [markdown]
# ###Train, Compile & Fit Model

# %%
pre_trained_model_xc = Sequential();
pre_trained_model_xc = tf.keras.applications.Xception(input_shape=(224,224, 3),
                             include_top = False,
                             weights = 'imagenet',
                             pooling='avg',
                             classes=2
                             )

# Freeze layers
for layer in pre_trained_model_xc.layers:
  layer.trainable = False

x = pre_trained_model_xc.output
x = layers.Flatten()(x)
# x = layers.GlobalAveragePooling2D()(x)
# x = layers.Dense(512, activation='relu')(x)
# x = layers.Dropout(0.5)(x)
x = layers.Dense(64, activation='relu')(x)
x = layers.Dropout(0.5)(x)
output= layers.Dense(class_count, activation='softmax')(x)

#Xception model
xception_model = Model(pre_trained_model_xc.input, output)

# %%
xception_model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_3 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  block1_conv1 (Conv2D)       (None, 111, 111, 32)         864       ['input_3[0][0]']
#
#  block1_conv1_bn (BatchNorm  (None, 111, 111, 32)         128       ['block1_conv1[0][0]']
#  alization)
#
#  block1_conv1_act (Activati  (None, 111, 111, 32)         0         ['block1_conv1_bn[0][0]']
#  on)
#
#  block1_conv2 (Conv2D)       (None, 109, 109, 64)         18432     ['block1_conv1_act[0][0]']
#
#  block1_conv2_bn (BatchNorm  (None, 109, 109, 64)         256       ['block1_conv2[0][0]']
#  alization)
#
#  block1_conv2_act (Activati  (None, 109, 109, 64)         0         ['block1_conv2_bn[0][0]']
#  on)
#
#  block2_sepconv1 (Separable  (None, 109, 109, 128)        8768      ['block1_conv2_act[0][0]']
#  Conv2D)
#
#  block2_sepconv1_bn (BatchN  (None, 109, 109, 128)        512       ['block2_sepconv1[0][0]']
#  ormalization)
#
#  block2_sepconv2_act (Activ  (None, 109, 109, 128)        0         ['block2_sepconv1_bn[0][0]']
#  ation)
#
#  block2_sepconv2 (Separable  (None, 109, 109, 128)        17536     ['block2_sepconv2_act[0][0]']
#  Conv2D)
#
#  block2_sepconv2_bn (BatchN  (None, 109, 109, 128)        512       ['block2_sepconv2[0][0]']
#  ormalization)
#
#  conv2d_4 (Conv2D)           (None, 55, 55, 128)          8192      ['block1_conv2_act[0][0]']
#
#  block2_pool (MaxPooling2D)  (None, 55, 55, 128)          0         ['block2_sepconv2_bn[0][0]']
#
#  batch_normalization_4 (Bat  (None, 55, 55, 128)          512       ['conv2d_4[0][0]']
#  chNormalization)
#
#  add_12 (Add)                (None, 55, 55, 128)          0         ['block2_pool[0][0]',
#                                                                      'batch_normalization_4[0][0]'
#                                                                     ]
#
#  block3_sepconv1_act (Activ  (None, 55, 55, 128)          0         ['add_12[0][0]']
#  ation)
#
#  block3_sepconv1 (Separable  (None, 55, 55, 256)          33920     ['block3_sepconv1_act[0][0]']
#  Conv2D)
#
#  block3_sepconv1_bn (BatchN  (None, 55, 55, 256)          1024      ['block3_sepconv1[0][0]']
#  ormalization)
#
#  block3_sepconv2_act (Activ  (None, 55, 55, 256)          0         ['block3_sepconv1_bn[0][0]']
#  ation)
#
#  block3_sepconv2 (Separable  (None, 55, 55, 256)          67840     ['block3_sepconv2_act[0][0]']
#  Conv2D)
#
#  block3_sepconv2_bn (BatchN  (None, 55, 55, 256)          1024      ['block3_sepconv2[0][0]']
#  ormalization)
#
#  conv2d_5 (Conv2D)           (None, 28, 28, 256)          32768     ['add_12[0][0]']
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)          0         ['block3_sepconv2_bn[0][0]']
#
#  batch_normalization_5 (Bat  (None, 28, 28, 256)          1024      ['conv2d_5[0][0]']
#  chNormalization)
#
#  add_13 (Add)                (None, 28, 28, 256)          0         ['block3_pool[0][0]',
#                                                                      'batch_normalization_5[0][0]'
#                                                                     ]
#
#  block4_sepconv1_act (Activ  (None, 28, 28, 256)          0         ['add_13[0][0]']
#  ation)
#
#  block4_sepconv1 (Separable  (None, 28, 28, 728)          188672    ['block4_sepconv1_act[0][0]']
#  Conv2D)
#
#  block4_sepconv1_bn (BatchN  (None, 28, 28, 728)          2912      ['block4_sepconv1[0][0]']
#  ormalization)
#
#  block4_sepconv2_act (Activ  (None, 28, 28, 728)          0         ['block4_sepconv1_bn[0][0]']
#  ation)
#
#  block4_sepconv2 (Separable  (None, 28, 28, 728)          536536    ['block4_sepconv2_act[0][0]']
#  Conv2D)
#
#  block4_sepconv2_bn (BatchN  (None, 28, 28, 728)          2912      ['block4_sepconv2[0][0]']
#  ormalization)
#
#  conv2d_6 (Conv2D)           (None, 14, 14, 728)          186368    ['add_13[0][0]']
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 728)          0         ['block4_sepconv2_bn[0][0]']
#
#  batch_normalization_6 (Bat  (None, 14, 14, 728)          2912      ['conv2d_6[0][0]']
#  chNormalization)
#
#  add_14 (Add)                (None, 14, 14, 728)          0         ['block4_pool[0][0]',
#                                                                      'batch_normalization_6[0][0]'
#                                                                     ]
#
#  block5_sepconv1_act (Activ  (None, 14, 14, 728)          0         ['add_14[0][0]']
#  ation)
#
#  block5_sepconv1 (Separable  (None, 14, 14, 728)          536536    ['block5_sepconv1_act[0][0]']
#  Conv2D)
#
#  block5_sepconv1_bn (BatchN  (None, 14, 14, 728)          2912      ['block5_sepconv1[0][0]']
#  ormalization)
#
#  block5_sepconv2_act (Activ  (None, 14, 14, 728)          0         ['block5_sepconv1_bn[0][0]']
#  ation)
#
#  block5_sepconv2 (Separable  (None, 14, 14, 728)          536536    ['block5_sepconv2_act[0][0]']
#  Conv2D)
#
#  block5_sepconv2_bn (BatchN  (None, 14, 14, 728)          2912      ['block5_sepconv2[0][0]']
#  ormalization)
#
#  block5_sepconv3_act (Activ  (None, 14, 14, 728)          0         ['block5_sepconv2_bn[0][0]']
#  ation)
#
#  block5_sepconv3 (Separable  (None, 14, 14, 728)          536536    ['block5_sepconv3_act[0][0]']
#  Conv2D)
#
#  block5_sepconv3_bn (BatchN  (None, 14, 14, 728)          2912      ['block5_sepconv3[0][0]']
#  ormalization)
#
#  add_15 (Add)                (None, 14, 14, 728)          0         ['block5_sepconv3_bn[0][0]',
#                                                                      'add_14[0][0]']
#
#  block6_sepconv1_act (Activ  (None, 14, 14, 728)          0         ['add_15[0][0]']
#  ation)
#
#  block6_sepconv1 (Separable  (None, 14, 14, 728)          536536    ['block6_sepconv1_act[0][0]']
#  Conv2D)
#
#  block6_sepconv1_bn (BatchN  (None, 14, 14, 728)          2912      ['block6_sepconv1[0][0]']
#  ormalization)
#
#  block6_sepconv2_act (Activ  (None, 14, 14, 728)          0         ['block6_sepconv1_bn[0][0]']
#  ation)
#
#  block6_sepconv2 (Separable  (None, 14, 14, 728)          536536    ['block6_sepconv2_act[0][0]']
#  Conv2D)
#
#  block6_sepconv2_bn (BatchN  (None, 14, 14, 728)          2912      ['block6_sepconv2[0][0]']
#  ormalization)
#
#  block6_sepconv3_act (Activ  (None, 14, 14, 728)          0         ['block6_sepconv2_bn[0][0]']
#  ation)
#
#  block6_sepconv3 (Separable  (None, 14, 14, 728)          536536    ['block6_sepconv3_act[0][0]']
#  Conv2D)
#
#  block6_sepconv3_bn (BatchN  (None, 14, 14, 728)          2912      ['block6_sepconv3[0][0]']
#  ormalization)
#
#  add_16 (Add)                (None, 14, 14, 728)          0         ['block6_sepconv3_bn[0][0]',
#                                                                      'add_15[0][0]']
#
#  block7_sepconv1_act (Activ  (None, 14, 14, 728)          0         ['add_16[0][0]']
#  ation)
#
#  block7_sepconv1 (Separable  (None, 14, 14, 728)          536536    ['block7_sepconv1_act[0][0]']
#  Conv2D)
#
#  block7_sepconv1_bn (BatchN  (None, 14, 14, 728)          2912      ['block7_sepconv1[0][0]']
#  ormalization)
#
#  block7_sepconv2_act (Activ  (None, 14, 14, 728)          0         ['block7_sepconv1_bn[0][0]']
#  ation)
#
#  block7_sepconv2 (Separable  (None, 14, 14, 728)          536536    ['block7_sepconv2_act[0][0]']
#  Conv2D)
#
#  block7_sepconv2_bn (BatchN  (None, 14, 14, 728)          2912      ['block7_sepconv2[0][0]']
#  ormalization)
#
#  block7_sepconv3_act (Activ  (None, 14, 14, 728)          0         ['block7_sepconv2_bn[0][0]']
#  ation)
#
#  block7_sepconv3 (Separable  (None, 14, 14, 728)          536536    ['block7_sepconv3_act[0][0]']
#  Conv2D)
#
#  block7_sepconv3_bn (BatchN  (None, 14, 14, 728)          2912      ['block7_sepconv3[0][0]']
#  ormalization)
#
#  add_17 (Add)                (None, 14, 14, 728)          0         ['block7_sepconv3_bn[0][0]',
#                                                                      'add_16[0][0]']
#
#  block8_sepconv1_act (Activ  (None, 14, 14, 728)          0         ['add_17[0][0]']
#  ation)
#
#  block8_sepconv1 (Separable  (None, 14, 14, 728)          536536    ['block8_sepconv1_act[0][0]']
#  Conv2D)
#
#  block8_sepconv1_bn (BatchN  (None, 14, 14, 728)          2912      ['block8_sepconv1[0][0]']
#  ormalization)
#
#  block8_sepconv2_act (Activ  (None, 14, 14, 728)          0         ['block8_sepconv1_bn[0][0]']
#  ation)
#
#  block8_sepconv2 (Separable  (None, 14, 14, 728)          536536    ['block8_sepconv2_act[0][0]']
#  Conv2D)
#
#  block8_sepconv2_bn (BatchN  (None, 14, 14, 728)          2912      ['block8_sepconv2[0][0]']
#  ormalization)
#
#  block8_sepconv3_act (Activ  (None, 14, 14, 728)          0         ['block8_sepconv2_bn[0][0]']
#  ation)
#
#  block8_sepconv3 (Separable  (None, 14, 14, 728)          536536    ['block8_sepconv3_act[0][0]']
#  Conv2D)
#
#  block8_sepconv3_bn (BatchN  (None, 14, 14, 728)          2912      ['block8_sepconv3[0][0]']
#  ormalization)
#
#  add_18 (Add)                (None, 14, 14, 728)          0         ['block8_sepconv3_bn[0][0]',
#                                                                      'add_17[0][0]']
#
#  block9_sepconv1_act (Activ  (None, 14, 14, 728)          0         ['add_18[0][0]']
#  ation)
#
#  block9_sepconv1 (Separable  (None, 14, 14, 728)          536536    ['block9_sepconv1_act[0][0]']
#  Conv2D)
#
#  block9_sepconv1_bn (BatchN  (None, 14, 14, 728)          2912      ['block9_sepconv1[0][0]']
#  ormalization)
#
#  block9_sepconv2_act (Activ  (None, 14, 14, 728)          0         ['block9_sepconv1_bn[0][0]']
#  ation)
#
#  block9_sepconv2 (Separable  (None, 14, 14, 728)          536536    ['block9_sepconv2_act[0][0]']
#  Conv2D)
#
#  block9_sepconv2_bn (BatchN  (None, 14, 14, 728)          2912      ['block9_sepconv2[0][0]']
#  ormalization)
#
#  block9_sepconv3_act (Activ  (None, 14, 14, 728)          0         ['block9_sepconv2_bn[0][0]']
#  ation)
#
#  block9_sepconv3 (Separable  (None, 14, 14, 728)          536536    ['block9_sepconv3_act[0][0]']
#  Conv2D)
#
#  block9_sepconv3_bn (BatchN  (None, 14, 14, 728)          2912      ['block9_sepconv3[0][0]']
#  ormalization)
#
#  add_19 (Add)                (None, 14, 14, 728)          0         ['block9_sepconv3_bn[0][0]',
#                                                                      'add_18[0][0]']
#
#  block10_sepconv1_act (Acti  (None, 14, 14, 728)          0         ['add_19[0][0]']
#  vation)
#
#  block10_sepconv1 (Separabl  (None, 14, 14, 728)          536536    ['block10_sepconv1_act[0][0]']
#  eConv2D)
#
#  block10_sepconv1_bn (Batch  (None, 14, 14, 728)          2912      ['block10_sepconv1[0][0]']
#  Normalization)
#
#  block10_sepconv2_act (Acti  (None, 14, 14, 728)          0         ['block10_sepconv1_bn[0][0]']
#  vation)
#
#  block10_sepconv2 (Separabl  (None, 14, 14, 728)          536536    ['block10_sepconv2_act[0][0]']
#  eConv2D)
#
#  block10_sepconv2_bn (Batch  (None, 14, 14, 728)          2912      ['block10_sepconv2[0][0]']
#  Normalization)
#
#  block10_sepconv3_act (Acti  (None, 14, 14, 728)          0         ['block10_sepconv2_bn[0][0]']
#  vation)
#
#  block10_sepconv3 (Separabl  (None, 14, 14, 728)          536536    ['block10_sepconv3_act[0][0]']
#  eConv2D)
#
#  block10_sepconv3_bn (Batch  (None, 14, 14, 728)          2912      ['block10_sepconv3[0][0]']
#  Normalization)
#
#  add_20 (Add)                (None, 14, 14, 728)          0         ['block10_sepconv3_bn[0][0]',
#                                                                      'add_19[0][0]']
#
#  block11_sepconv1_act (Acti  (None, 14, 14, 728)          0         ['add_20[0][0]']
#  vation)
#
#  block11_sepconv1 (Separabl  (None, 14, 14, 728)          536536    ['block11_sepconv1_act[0][0]']
#  eConv2D)
#
#  block11_sepconv1_bn (Batch  (None, 14, 14, 728)          2912      ['block11_sepconv1[0][0]']
#  Normalization)
#
#  block11_sepconv2_act (Acti  (None, 14, 14, 728)          0         ['block11_sepconv1_bn[0][0]']
#  vation)
#
#  block11_sepconv2 (Separabl  (None, 14, 14, 728)          536536    ['block11_sepconv2_act[0][0]']
#  eConv2D)
#
#  block11_sepconv2_bn (Batch  (None, 14, 14, 728)          2912      ['block11_sepconv2[0][0]']
#  Normalization)
#
#  block11_sepconv3_act (Acti  (None, 14, 14, 728)          0         ['block11_sepconv2_bn[0][0]']
#  vation)
#
#  block11_sepconv3 (Separabl  (None, 14, 14, 728)          536536    ['block11_sepconv3_act[0][0]']
#  eConv2D)
#
#  block11_sepconv3_bn (Batch  (None, 14, 14, 728)          2912      ['block11_sepconv3[0][0]']
#  Normalization)
#
#  add_21 (Add)                (None, 14, 14, 728)          0         ['block11_sepconv3_bn[0][0]',
#                                                                      'add_20[0][0]']
#
#  block12_sepconv1_act (Acti  (None, 14, 14, 728)          0         ['add_21[0][0]']
#  vation)
#
#  block12_sepconv1 (Separabl  (None, 14, 14, 728)          536536    ['block12_sepconv1_act[0][0]']
#  eConv2D)
#
#  block12_sepconv1_bn (Batch  (None, 14, 14, 728)          2912      ['block12_sepconv1[0][0]']
#  Normalization)
#
#  block12_sepconv2_act (Acti  (None, 14, 14, 728)          0         ['block12_sepconv1_bn[0][0]']
#  vation)
#
#  block12_sepconv2 (Separabl  (None, 14, 14, 728)          536536    ['block12_sepconv2_act[0][0]']
#  eConv2D)
#
#  block12_sepconv2_bn (Batch  (None, 14, 14, 728)          2912      ['block12_sepconv2[0][0]']
#  Normalization)
#
#  block12_sepconv3_act (Acti  (None, 14, 14, 728)          0         ['block12_sepconv2_bn[0][0]']
#  vation)
#
#  block12_sepconv3 (Separabl  (None, 14, 14, 728)          536536    ['block12_sepconv3_act[0][0]']
#  eConv2D)
#
#  block12_sepconv3_bn (Batch  (None, 14, 14, 728)          2912      ['block12_sepconv3[0][0]']
#  Normalization)
#
#  add_22 (Add)                (None, 14, 14, 728)          0         ['block12_sepconv3_bn[0][0]',
#                                                                      'add_21[0][0]']
#
#  block13_sepconv1_act (Acti  (None, 14, 14, 728)          0         ['add_22[0][0]']
#  vation)
#
#  block13_sepconv1 (Separabl  (None, 14, 14, 728)          536536    ['block13_sepconv1_act[0][0]']
#  eConv2D)
#
#  block13_sepconv1_bn (Batch  (None, 14, 14, 728)          2912      ['block13_sepconv1[0][0]']
#  Normalization)
#
#  block13_sepconv2_act (Acti  (None, 14, 14, 728)          0         ['block13_sepconv1_bn[0][0]']
#  vation)
#
#  block13_sepconv2 (Separabl  (None, 14, 14, 1024)         752024    ['block13_sepconv2_act[0][0]']
#  eConv2D)
#
#  block13_sepconv2_bn (Batch  (None, 14, 14, 1024)         4096      ['block13_sepconv2[0][0]']
#  Normalization)
#
#  conv2d_7 (Conv2D)           (None, 7, 7, 1024)           745472    ['add_22[0][0]']
#
#  block13_pool (MaxPooling2D  (None, 7, 7, 1024)           0         ['block13_sepconv2_bn[0][0]']
#  )
#
#  batch_normalization_7 (Bat  (None, 7, 7, 1024)           4096      ['conv2d_7[0][0]']
#  chNormalization)
#
#  add_23 (Add)                (None, 7, 7, 1024)           0         ['block13_pool[0][0]',
#                                                                      'batch_normalization_7[0][0]'
#                                                                     ]
#
#  block14_sepconv1 (Separabl  (None, 7, 7, 1536)           1582080   ['add_23[0][0]']
#  eConv2D)
#
#  block14_sepconv1_bn (Batch  (None, 7, 7, 1536)           6144      ['block14_sepconv1[0][0]']
#  Normalization)
#
#  block14_sepconv1_act (Acti  (None, 7, 7, 1536)           0         ['block14_sepconv1_bn[0][0]']
#  vation)
#
#  block14_sepconv2 (Separabl  (None, 7, 7, 2048)           3159552   ['block14_sepconv1_act[0][0]']
#  eConv2D)
#
#  block14_sepconv2_bn (Batch  (None, 7, 7, 2048)           8192      ['block14_sepconv2[0][0]']
#  Normalization)
#
#  block14_sepconv2_act (Acti  (None, 7, 7, 2048)           0         ['block14_sepconv2_bn[0][0]']
#  vation)
#
#  global_average_pooling2d_1  (None, 2048)                 0         ['block14_sepconv2_act[0][0]']
#   (GlobalAveragePooling2D)
#
#  flatten_2 (Flatten)         (None, 2048)                 0         ['global_average_pooling2d_1[0
#                                                                     ][0]']
#
#  dense_4 (Dense)             (None, 64)                   131136    ['flatten_2[0][0]']
#
#  dropout_2 (Dropout)         (None, 64)                   0         ['dense_4[0][0]']
#
#  dense_5 (Dense)             (None, 2)                    130       ['dropout_2[0][0]']
#
# ==================================================================================================
# Total params: 20992746 (80.08 MB)
# Trainable params: 131266 (512.76 KB)
# Non-trainable params: 20861480 (79.58 MB)
# __________________________________________________________________________________________________

# %%
# Compile model 1e-5
xception_model.compile(optimizer=tf.keras.optimizers.AdamW(learning_rate=0.00001),
              loss=tf.keras.losses.CategoricalCrossentropy(),
              metrics=[AUC(name='auc')]
              )

# Train model
xception_model.fit(ds_train_sm_xc,
          validation_data=ds_val_sm_xc,
          epochs=300,
          # callbacks=callback_params,
          # class_weight=class_weights,
          callbacks=[tf.keras.callbacks.EarlyStopping(monitor='val_auc', patience=5),
                    #  tf.keras.callbacks.ModelCheckpoint('models/xception_ai_{val_auc:.3f}.h5',
                    #                                     save_best_only=True,
                    #                                     save_weights_only=False,
                    #                                     monitor='val_auc')
                     ]
          )
# Out:
# Epoch 1/300
# 17/17 [==============================] - 6s 170ms/step - loss: 0.7791 - auc: 0.5040 - val_loss: 0.7226 - val_auc: 0.5194
# Epoch 2/300
# 17/17 [==============================] - 3s 173ms/step - loss: 0.7629 - auc: 0.5254 - val_loss: 0.7086 - val_auc: 0.5365
# Epoch 3/300
# 17/17 [==============================] - 3s 169ms/step - loss: 0.7511 - auc: 0.5126 - val_loss: 0.6946 - val_auc: 0.5569
# Epoch 4/300
# 17/17 [==============================] - 2s 111ms/step - loss: 0.7405 - auc: 0.5283 - val_loss: 0.6826 - val_auc: 0.5728
# Epoch 5/300
# 17/17 [==============================] - 2s 113ms/step - loss: 0.7726 - auc: 0.4737 - val_loss: 0.6716 - val_auc: 0.5928
# Epoch 6/300
# 17/17 [==============================] - 2s 116ms/step - loss: 0.7204 - auc: 0.5591 - val_loss: 0.6606 - val_auc: 0.6152
# Epoch 7/300
# 17/17 [==============================] - 3s 163ms/step - loss: 0.6888 - auc: 0.5935 - val_loss: 0.6516 - val_auc: 0.6394
# Epoch 8/300
# 17/17 [==============================] - 3s 174ms/step - loss: 0.7092 - auc: 0.5692 - val_loss: 0.6431 - val_auc: 0.6605
# Epoch 9/300
# 17/17 [==============================] - 2s 123ms/step - loss: 0.6747 - auc: 0.6289 - val_loss: 0.6347 - val_auc: 0.6894
# Epoch 10/300
# 17/17 [==============================] - 2s 122ms/step - loss: 0.6506 - auc: 0.6598 - val_loss: 0.6275 - val_auc: 0.7096
# Epoch 11/300
# 17/17 [==============================] - 2s 112ms/step - loss: 0.6283 - auc: 0.6969 - val_loss: 0.6201 - val_auc: 0.7372
# Epoch 12/300
# 17/17 [==============================] - 2s 112ms/step - loss: 0.6119 - auc: 0.7312 - val_loss: 0.6131 - val_auc: 0.7579
# Epoch 13/300
# 17/17 [==============================] - 2s 113ms/step - loss: 0.6160 - auc: 0.7134 - val_loss: 0.6067 - val_auc: 0.7681
# Epoch 14/300
# 17/17 [==============================] - 3s 160ms/step - loss: 0.5820 - auc: 0.7696 - val_loss: 0.6011 - val_auc: 0.7829
# Epoch 15/300
# 17/17 [==============================] - 3s 167ms/step - loss: 0.5971 - auc: 0.7376 - val_loss: 0.5956 - val_auc: 0.7914
# Epoch 16/300
# 17/17 [==============================] - 2s 119ms/step - loss: 0.6089 - auc: 0.7313 - val_loss: 0.5906 - val_auc: 0.7975
# Epoch 17/300
# 17/17 [==============================] - 2s 115ms/step - loss: 0.5748 - auc: 0.7683 - val_loss: 0.5850 - val_auc: 0.8045
# Epoch 18/300
# 17/17 [==============================] - 2s 115ms/step - loss: 0.6040 - auc: 0.7239 - val_loss: 0.5800 - val_auc: 0.8113
# Epoch 19/300
# 17/17 [==============================] - 2s 129ms/step - loss: 0.5850 - auc: 0.7574 - val_loss: 0.5753 - val_auc: 0.8137
# Epoch 20/300
# 17/17 [==============================] - 2s 145ms/step - loss: 0.5799 - auc: 0.7594 - val_loss: 0.5703 - val_auc: 0.8173
# Epoch 21/300
# 17/17 [==============================] - 2s 138ms/step - loss: 0.5463 - auc: 0.8118 - val_loss: 0.5657 - val_auc: 0.8211
# Epoch 22/300
# 17/17 [==============================] - 2s 116ms/step - loss: 0.5354 - auc: 0.8264 - val_loss: 0.5617 - val_auc: 0.8223
# Epoch 23/300
# 17/17 [==============================] - 2s 115ms/step - loss: 0.5354 - auc: 0.8210 - val_loss: 0.5579 - val_auc: 0.8231
# Epoch 24/300
# 17/17 [==============================] - 2s 120ms/step - loss: 0.5709 - auc: 0.7844 - val_loss: 0.5540 - val_auc: 0.8276
# Epoch 25/300
# 17/17 [==============================] - 2s 137ms/step - loss: 0.5491 - auc: 0.8097 - val_loss: 0.5503 - val_auc: 0.8290
# Epoch 26/300
# 17/17 [==============================] - 3s 172ms/step - loss: 0.5130 - auc: 0.8505 - val_loss: 0.5475 - val_auc: 0.8287
# Epoch 27/300
# 17/17 [==============================] - 2s 116ms/step - loss: 0.5303 - auc: 0.8374 - val_loss: 0.5440 - val_auc: 0.8302
# Epoch 28/300
# 17/17 [==============================] - 2s 113ms/step - loss: 0.5436 - auc: 0.8146 - val_loss: 0.5401 - val_auc: 0.8318
# Epoch 29/300
# 17/17 [==============================] - 2s 114ms/step - loss: 0.5182 - auc: 0.8460 - val_loss: 0.5367 - val_auc: 0.8336
# Epoch 30/300
# 17/17 [==============================] - 2s 114ms/step - loss: 0.4914 - auc: 0.8754 - val_loss: 0.5337 - val_auc: 0.8353
# Epoch 31/300
# 17/17 [==============================] - 3s 155ms/step - loss: 0.5031 - auc: 0.8597 - val_loss: 0.5307 - val_auc: 0.8365
# Epoch 32/300
# 17/17 [==============================] - 3s 170ms/step - loss: 0.4947 - auc: 0.8674 - val_loss: 0.5282 - val_auc: 0.8369
# Epoch 33/300
# 17/17 [==============================] - 2s 114ms/step - loss: 0.5046 - auc: 0.8592 - val_loss: 0.5258 - val_auc: 0.8347
# Epoch 34/300
# 17/17 [==============================] - 2s 116ms/step - loss: 0.4574 - auc: 0.9030 - val_loss: 0.5235 - val_auc: 0.8359
# Epoch 35/300
# 17/17 [==============================] - 2s 114ms/step - loss: 0.4808 - auc: 0.8781 - val_loss: 0.5210 - val_auc: 0.8377
# Epoch 36/300
# 17/17 [==============================] - 2s 117ms/step - loss: 0.4677 - auc: 0.8927 - val_loss: 0.5183 - val_auc: 0.8394
# Epoch 37/300
# 17/17 [==============================] - 2s 144ms/step - loss: 0.4596 - auc: 0.9012 - val_loss: 0.5165 - val_auc: 0.8369
# Epoch 38/300
# 17/17 [==============================] - 3s 167ms/step - loss: 0.4622 - auc: 0.8791 - val_loss: 0.5140 - val_auc: 0.8382
# Epoch 39/300
# 17/17 [==============================] - 2s 124ms/step - loss: 0.4646 - auc: 0.8855 - val_loss: 0.5121 - val_auc: 0.8389
# Epoch 40/300
# 17/17 [==============================] - 2s 116ms/step - loss: 0.4786 - auc: 0.8724 - val_loss: 0.5102 - val_auc: 0.8396
# Epoch 41/300
# 17/17 [==============================] - 2s 115ms/step - loss: 0.4517 - auc: 0.8947 - val_loss: 0.5083 - val_auc: 0.8403
# Epoch 42/300
# 17/17 [==============================] - 2s 117ms/step - loss: 0.4711 - auc: 0.8784 - val_loss: 0.5067 - val_auc: 0.8394
# Epoch 43/300
# 17/17 [==============================] - 2s 115ms/step - loss: 0.4443 - auc: 0.8928 - val_loss: 0.5046 - val_auc: 0.8409
# Epoch 44/300
# 17/17 [==============================] - 3s 166ms/step - loss: 0.4266 - auc: 0.9104 - val_loss: 0.5024 - val_auc: 0.8426
# Epoch 45/300
# 17/17 [==============================] - 2s 145ms/step - loss: 0.4422 - auc: 0.9053 - val_loss: 0.5009 - val_auc: 0.8428
# Epoch 46/300
# 17/17 [==============================] - 2s 123ms/step - loss: 0.4424 - auc: 0.8985 - val_loss: 0.4997 - val_auc: 0.8419
# Epoch 47/300
# 17/17 [==============================] - 2s 116ms/step - loss: 0.4500 - auc: 0.8975 - val_loss: 0.4990 - val_auc: 0.8424
# Epoch 48/300
# 17/17 [==============================] - 2s 118ms/step - loss: 0.4164 - auc: 0.9186 - val_loss: 0.4974 - val_auc: 0.8422
# Epoch 49/300
# 17/17 [==============================] - 2s 114ms/step - loss: 0.4284 - auc: 0.9053 - val_loss: 0.4964 - val_auc: 0.8423
# Epoch 50/300
# 17/17 [==============================] - 2s 115ms/step - loss: 0.4397 - auc: 0.8977 - val_loss: 0.4954 - val_auc: 0.8429
# Epoch 51/300
# 17/17 [==============================] - 2s 128ms/step - loss: 0.4002 - auc: 0.9320 - val_loss: 0.4941 - val_auc: 0.8428
# Epoch 52/300
# 17/17 [==============================] - 2s 138ms/step - loss: 0.3978 - auc: 0.9274 - val_loss: 0.4926 - val_auc: 0.8443
# Epoch 53/300
# 17/17 [==============================] - 2s 140ms/step - loss: 0.4069 - auc: 0.9181 - val_loss: 0.4913 - val_auc: 0.8452
# Epoch 54/300
# 17/17 [==============================] - 2s 115ms/step - loss: 0.4120 - auc: 0.9119 - val_loss: 0.4903 - val_auc: 0.8456
# Epoch 55/300
# 17/17 [==============================] - 2s 122ms/step - loss: 0.4245 - auc: 0.9024 - val_loss: 0.4892 - val_auc: 0.8465
# Epoch 56/300
# 17/17 [==============================] - 2s 121ms/step - loss: 0.3995 - auc: 0.9289 - val_loss: 0.4885 - val_auc: 0.8462
# Epoch 57/300
# 17/17 [==============================] - 2s 115ms/step - loss: 0.4256 - auc: 0.9081 - val_loss: 0.4870 - val_auc: 0.8463
# Epoch 58/300
# 17/17 [==============================] - 3s 154ms/step - loss: 0.3945 - auc: 0.9313 - val_loss: 0.4864 - val_auc: 0.8473
# Epoch 59/300
# 17/17 [==============================] - 3s 173ms/step - loss: 0.4021 - auc: 0.9250 - val_loss: 0.4855 - val_auc: 0.8481
# Epoch 60/300
# 17/17 [==============================] - 2s 115ms/step - loss: 0.3844 - auc: 0.9313 - val_loss: 0.4843 - val_auc: 0.8486
# Epoch 61/300
# 17/17 [==============================] - 2s 115ms/step - loss: 0.3999 - auc: 0.9247 - val_loss: 0.4835 - val_auc: 0.8490
# Epoch 62/300
# 17/17 [==============================] - 2s 113ms/step - loss: 0.4002 - auc: 0.9217 - val_loss: 0.4819 - val_auc: 0.8491
# Epoch 63/300
# 17/17 [==============================] - 2s 115ms/step - loss: 0.3751 - auc: 0.9372 - val_loss: 0.4815 - val_auc: 0.8494
# Epoch 64/300
# 17/17 [==============================] - 2s 135ms/step - loss: 0.3878 - auc: 0.9279 - val_loss: 0.4817 - val_auc: 0.8480
# Epoch 65/300
# 17/17 [==============================] - 3s 173ms/step - loss: 0.3876 - auc: 0.9320 - val_loss: 0.4809 - val_auc: 0.8487
# Epoch 66/300
# 17/17 [==============================] - 2s 115ms/step - loss: 0.4164 - auc: 0.8994 - val_loss: 0.4804 - val_auc: 0.8489
# Epoch 67/300
# 17/17 [==============================] - 3s 150ms/step - loss: 0.3657 - auc: 0.9467 - val_loss: 0.4793 - val_auc: 0.8504
# Epoch 68/300
# 17/17 [==============================] - 2s 117ms/step - loss: 0.3735 - auc: 0.9289 - val_loss: 0.4792 - val_auc: 0.8498
# Epoch 69/300
# 17/17 [==============================] - 3s 165ms/step - loss: 0.3893 - auc: 0.9183 - val_loss: 0.4787 - val_auc: 0.8499
# Epoch 70/300
# 17/17 [==============================] - 2s 111ms/step - loss: 0.3795 - auc: 0.9359 - val_loss: 0.4778 - val_auc: 0.8499
# Epoch 71/300
# 17/17 [==============================] - 2s 117ms/step - loss: 0.3805 - auc: 0.9356 - val_loss: 0.4775 - val_auc: 0.8496
# Epoch 72/300
# 17/17 [==============================] - 2s 117ms/step - loss: 0.3623 - auc: 0.9401 - val_loss: 0.4774 - val_auc: 0.8500

# %% [markdown]
# ###Performance

# %%
plot_acc_loss_graphs(xception_model)

# %% [markdown]
# ### Evaluation

# %%
#save model
xception_model.save('/content/drive/MyDrive/Research/models/xception_model_sm_wsl_02_adamw.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
#load saved model:
saved_xception_model = tf.keras.models.load_model('/content/drive/MyDrive/Research/models/xception_model_ai.h5');

# %%
#predict
y_pred_xc = xception_model.predict(ds_test_sm_xc)
print(f'y_pred_shape:{y_pred_xc.shape} and shape[0] is: {y_pred_xc.shape[0]}')
# Out:
# 1/1 [==============================] - 2s 2s/step
# y_pred_shape:(262, 2) and shape[0] is: 262

# %%
plot_evaluation_graphs(y_pred_xc, ds_test_sm_xc)
# Out:
#               precision    recall  f1-score   support
#
#       benign       0.82      0.89      0.86       131
#    malignant       0.88      0.81      0.84       131
#
#    micro avg       0.85      0.85      0.85       262
#    macro avg       0.85      0.85      0.85       262
# weighted avg       0.85      0.85      0.85       262
#  samples avg       0.85      0.85      0.85       262

# %% [markdown]
# #MobileNet

# %% [markdown]
# ##Create and preprocess datasets

# %%
# def preprocess_mn(images, labels):
#   return tf.keras.applications.mobilenet.preprocess_input(images), labels

# %%
ds_train_mn, ds_val_mn = generators_train_val((224,224), tf.keras.applications.mobilenet.preprocess_input, train_dir, val_dir,8)
ds_test_mn = generator_test((224,224), tf.keras.applications.mobilenet.preprocess_input, test_dir, 262)
# Out:
# Found 260 images belonging to 2 classes.
# Found 134 images belonging to 2 classes.
# Found 262 images belonging to 2 classes.

# %% [markdown]
# ##Train

# %%
pre_trained_model_mn= Sequential();

pre_trained_model_mn = tf.keras.applications.MobileNet(input_shape=(224,224, 3),  ##
                             include_top = False,
                             weights = 'imagenet',
                             pooling='avg',
                             classes=2
                             )

# Freeze layers
for layer in pre_trained_model_mn.layers: ##
  layer.trainable = False

x = pre_trained_model_mn.output ##
x = layers.Flatten()(x)
# x = layers.GlobalAveragePooling2D()(x)
# x = layers.Dense(512, activation='relu')(x)
# x = layers.Dropout(0.5)(x)
x = layers.Dense(64, activation='relu')(x)
x = layers.Dropout(0.5)(x)
output= layers.Dense(class_count, activation='softmax')(x)

#mobile model
mobileNet_model = Model(pre_trained_model_mn.input, output) ##

# %%
# Compile model
mobileNet_model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
              loss=tf.keras.losses.CategoricalCrossentropy(),
              metrics=[AUC(name='auc')]
              )

# Train model
mobileNet_model.fit(ds_train_mn, ##
          validation_data=ds_val_mn, ##
          epochs=200,
          # callbacks=callback_params,
          # class_weight=class_weights,
          callbacks=[tf.keras.callbacks.EarlyStopping(monitor='val_auc', patience=15),
                    #  tf.keras.callbacks.ModelCheckpoint('models/mobileNet_ai_{val_auc:.3f}.h5',
                    #                                     save_best_only=True,
                    #                                     save_weights_only=False,
                    #                                     monitor='val_auc')
                     ]
          )
# Out:
# Epoch 1/200
# 33/33 [==============================] - 94s 3s/step - loss: 0.9041 - auc: 0.5759 - val_loss: 0.5470 - val_auc: 0.7959
# Epoch 2/200
# 33/33 [==============================] - 2s 68ms/step - loss: 0.6367 - auc: 0.7406 - val_loss: 0.4494 - val_auc: 0.8845
# Epoch 3/200
# 33/33 [==============================] - 2s 71ms/step - loss: 0.5183 - auc: 0.8234 - val_loss: 0.4147 - val_auc: 0.9003
# Epoch 4/200
# 33/33 [==============================] - 2s 73ms/step - loss: 0.4900 - auc: 0.8396 - val_loss: 0.3850 - val_auc: 0.9147
# Epoch 5/200
# 33/33 [==============================] - 3s 81ms/step - loss: 0.4289 - auc: 0.8757 - val_loss: 0.3729 - val_auc: 0.9193
# Epoch 6/200
# 33/33 [==============================] - 2s 73ms/step - loss: 0.3476 - auc: 0.9283 - val_loss: 0.3713 - val_auc: 0.9162
# Epoch 7/200
# 33/33 [==============================] - 2s 68ms/step - loss: 0.3658 - auc: 0.9184 - val_loss: 0.3540 - val_auc: 0.9236
# Epoch 8/200
# 33/33 [==============================] - 3s 84ms/step - loss: 0.3943 - auc: 0.9003 - val_loss: 0.3529 - val_auc: 0.9226
# Epoch 9/200
# 33/33 [==============================] - 3s 92ms/step - loss: 0.3435 - auc: 0.9294 - val_loss: 0.3500 - val_auc: 0.9245
# Epoch 10/200
# 33/33 [==============================] - 2s 68ms/step - loss: 0.3218 - auc: 0.9408 - val_loss: 0.3457 - val_auc: 0.9256
# Epoch 11/200
# 33/33 [==============================] - 3s 91ms/step - loss: 0.2954 - auc: 0.9502 - val_loss: 0.3427 - val_auc: 0.9276
# Epoch 12/200
# 33/33 [==============================] - 2s 66ms/step - loss: 0.2641 - auc: 0.9642 - val_loss: 0.3387 - val_auc: 0.9290
# Epoch 13/200
# 33/33 [==============================] - 3s 100ms/step - loss: 0.2763 - auc: 0.9563 - val_loss: 0.3390 - val_auc: 0.9282
# Epoch 14/200
# 33/33 [==============================] - 2s 75ms/step - loss: 0.2639 - auc: 0.9626 - val_loss: 0.3380 - val_auc: 0.9290
# Epoch 15/200
# 33/33 [==============================] - 2s 69ms/step - loss: 0.2763 - auc: 0.9558 - val_loss: 0.3362 - val_auc: 0.9296
# Epoch 16/200
# 33/33 [==============================] - 2s 69ms/step - loss: 0.2441 - auc: 0.9675 - val_loss: 0.3377 - val_auc: 0.9290
# Epoch 17/200
# 33/33 [==============================] - 2s 69ms/step - loss: 0.2182 - auc: 0.9793 - val_loss: 0.3288 - val_auc: 0.9333
# Epoch 18/200
# 33/33 [==============================] - 3s 89ms/step - loss: 0.2179 - auc: 0.9779 - val_loss: 0.3347 - val_auc: 0.9305
# Epoch 19/200
# 33/33 [==============================] - 2s 69ms/step - loss: 0.2444 - auc: 0.9660 - val_loss: 0.3323 - val_auc: 0.9318
# Epoch 20/200
# 33/33 [==============================] - 2s 68ms/step - loss: 0.2227 - auc: 0.9756 - val_loss: 0.3313 - val_auc: 0.9328
# Epoch 21/200
# 33/33 [==============================] - 2s 70ms/step - loss: 0.1949 - auc: 0.9838 - val_loss: 0.3341 - val_auc: 0.9321
# Epoch 22/200
# 33/33 [==============================] - 3s 85ms/step - loss: 0.2092 - auc: 0.9795 - val_loss: 0.3337 - val_auc: 0.9332
# Epoch 23/200
# 33/33 [==============================] - 2s 69ms/step - loss: 0.1721 - auc: 0.9884 - val_loss: 0.3387 - val_auc: 0.9319
# Epoch 24/200
# 33/33 [==============================] - 2s 70ms/step - loss: 0.1887 - auc: 0.9836 - val_loss: 0.3374 - val_auc: 0.9326
# Epoch 25/200
# 33/33 [==============================] - 2s 68ms/step - loss: 0.1807 - auc: 0.9858 - val_loss: 0.3353 - val_auc: 0.9338
# Epoch 26/200
# 33/33 [==============================] - 2s 72ms/step - loss: 0.1790 - auc: 0.9855 - val_loss: 0.3412 - val_auc: 0.9304
# Epoch 27/200
# 33/33 [==============================] - 3s 98ms/step - loss: 0.1857 - auc: 0.9842 - val_loss: 0.3413 - val_auc: 0.9309
# Epoch 28/200
# 33/33 [==============================] - 2s 68ms/step - loss: 0.1738 - auc: 0.9858 - val_loss: 0.3430 - val_auc: 0.9311
# Epoch 29/200
# 33/33 [==============================] - 2s 69ms/step - loss: 0.1620 - auc: 0.9897 - val_loss: 0.3425 - val_auc: 0.9311
# Epoch 30/200
# 33/33 [==============================] - 2s 68ms/step - loss: 0.1672 - auc: 0.9879 - val_loss: 0.3413 - val_auc: 0.9311
# Epoch 31/200
# 33/33 [==============================] - 2s 68ms/step - loss: 0.1382 - auc: 0.9950 - val_loss: 0.3485 - val_auc: 0.9301
# Epoch 32/200
# 33/33 [==============================] - 3s 84ms/step - loss: 0.1554 - auc: 0.9902 - val_loss: 0.3460 - val_auc: 0.9332
# Epoch 33/200
# 33/33 [==============================] - 3s 89ms/step - loss: 0.1603 - auc: 0.9890 - val_loss: 0.3547 - val_auc: 0.9306
# Epoch 34/200
# 33/33 [==============================] - 3s 84ms/step - loss: 0.1369 - auc: 0.9933 - val_loss: 0.3414 - val_auc: 0.9334
# Epoch 35/200
# 33/33 [==============================] - 2s 70ms/step - loss: 0.1382 - auc: 0.9944 - val_loss: 0.3437 - val_auc: 0.9341
# Epoch 36/200
# 33/33 [==============================] - 3s 101ms/step - loss: 0.1261 - auc: 0.9947 - val_loss: 0.3473 - val_auc: 0.9334
# Epoch 37/200
# 33/33 [==============================] - 5s 148ms/step - loss: 0.1334 - auc: 0.9942 - val_loss: 0.3594 - val_auc: 0.9300
# Epoch 38/200
# 33/33 [==============================] - 2s 69ms/step - loss: 0.1339 - auc: 0.9939 - val_loss: 0.3475 - val_auc: 0.9355
# Epoch 39/200
# 33/33 [==============================] - 2s 67ms/step - loss: 0.1349 - auc: 0.9949 - val_loss: 0.3510 - val_auc: 0.9340
# Epoch 40/200
# 33/33 [==============================] - 2s 67ms/step - loss: 0.1205 - auc: 0.9959 - val_loss: 0.3531 - val_auc: 0.9334
# Epoch 41/200
# 33/33 [==============================] - 3s 87ms/step - loss: 0.1149 - auc: 0.9963 - val_loss: 0.3566 - val_auc: 0.9335
# Epoch 42/200
# 33/33 [==============================] - 2s 68ms/step - loss: 0.0959 - auc: 0.9983 - val_loss: 0.3692 - val_auc: 0.9285
# Epoch 43/200
# 33/33 [==============================] - 3s 84ms/step - loss: 0.0989 - auc: 0.9977 - val_loss: 0.3702 - val_auc: 0.9297
# Epoch 44/200
# 33/33 [==============================] - 2s 69ms/step - loss: 0.0927 - auc: 0.9990 - val_loss: 0.3621 - val_auc: 0.9314
# Epoch 45/200
# 33/33 [==============================] - 3s 78ms/step - loss: 0.0963 - auc: 0.9978 - val_loss: 0.3683 - val_auc: 0.9307
# Epoch 46/200
# 33/33 [==============================] - 2s 72ms/step - loss: 0.0950 - auc: 0.9982 - val_loss: 0.3729 - val_auc: 0.9285
# Epoch 47/200
# 33/33 [==============================] - 2s 71ms/step - loss: 0.0934 - auc: 0.9978 - val_loss: 0.3777 - val_auc: 0.9294
# Epoch 48/200
# 33/33 [==============================] - 3s 87ms/step - loss: 0.0912 - auc: 0.9981 - val_loss: 0.3692 - val_auc: 0.9306
# Epoch 49/200
# 33/33 [==============================] - 3s 89ms/step - loss: 0.0896 - auc: 0.9984 - val_loss: 0.3732 - val_auc: 0.9304
# Epoch 50/200
# 33/33 [==============================] - 2s 68ms/step - loss: 0.0969 - auc: 0.9968 - val_loss: 0.3689 - val_auc: 0.9332
# Epoch 51/200
# 33/33 [==============================] - 2s 68ms/step - loss: 0.0864 - auc: 0.9986 - val_loss: 0.3790 - val_auc: 0.9302
# Epoch 52/200
# 33/33 [==============================] - 2s 69ms/step - loss: 0.0879 - auc: 0.9975 - val_loss: 0.3849 - val_auc: 0.9290
# Epoch 53/200
# 33/33 [==============================] - 2s 67ms/step - loss: 0.0807 - auc: 0.9983 - val_loss: 0.3722 - val_auc: 0.9338

# %%
##save model
# resnet_model.save('/content/drive/MyDrive/Research/models/resnet_model_ai.h5')
# Assuming 'model' is your TensorFlow model
mobileNet_model.save("/content/drive/MyDrive/All mixed/cls/wsl/round1/mobileNet_model_01.h5")
#load the model:
# saved_resnet_model = tf.keras.models.load_model('/content/drive/MyDrive/Research/models/resnet_model_ai.h5');
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %% [markdown]
# ##Performance

# %%
plot_acc_loss_graphs(mobileNet_model)

# %% [markdown]
# ## Evaluation

# %%
#save model
mobileNet_model.save('/content/drive/MyDrive/All mixed/cls/wsl/round1/mobileNet_model_01.h5')

# %%
#load saved model:
saved_mobileNet_model = tf.keras.models.load_model('/content/drive/MyDrive/All mixed/cls/wsl/round1/mobileNet_model_01.h5');

# %%
#predict
y_pred_mn = mobileNet_model.predict(ds_test_mn, verbose=1)
print(f'y_pred_shape:{y_pred_mn.shape} and shape[0] is: {y_pred_mn.shape[0]}')
# Out:
# 1/1 [==============================] - 7s 7s/step
# y_pred_shape:(262, 2) and shape[0] is: 262

# %%
plot_evaluation_graphs(y_pred_mn, ds_test_mn)
# Out:
#               precision    recall  f1-score   support
#
#       benign       0.82      0.89      0.86       131
#    malignant       0.88      0.81      0.84       131
#
#    micro avg       0.85      0.85      0.85       262
#    macro avg       0.85      0.85      0.85       262
# weighted avg       0.85      0.85      0.85       262
#  samples avg       0.85      0.85      0.85       262

# %% [markdown]
# ##View sample images

# %%
#view sample images
image_mn, label_mn = ds_test_mn.next()
view_2_images(image_mn, label_mn, y_pred_mn, classes)
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ##Smaller Generators - TAKEN

# %% [markdown]
# ###Create and preprocess datasets

# %%
# def preprocess_mn(images, labels):
#   return tf.keras.applications.mobilenet.preprocess_input(images), labels

# %%
ds_train_sm_mn, ds_val_sm_mn = generators_train_val((224,224), tf.keras.applications.mobilenet.preprocess_input, train_dir, val_dir, 10)
ds_test_sm_mn = generator_test((224,224), tf.keras.applications.mobilenet.preprocess_input, test_dir, 262)
# Out:
# Found 260 images belonging to 2 classes.
# Found 134 images belonging to 2 classes.
# Found 262 images belonging to 2 classes.

# %% [markdown]
# ###Train

# %%
pre_trained_model_mn= Sequential();

pre_trained_model_mn = tf.keras.applications.MobileNet(input_shape=(224,224, 3),  ##
                             include_top = False,
                             weights = 'imagenet',
                             pooling='avg',
                             classes=2
                             )

# Freeze layers
for layer in pre_trained_model_mn.layers: ##
  layer.trainable = False

x = pre_trained_model_mn.output ##
x = layers.Flatten()(x)
# x = layers.GlobalAveragePooling2D()(x)
# x = layers.Dense(512, activation='relu')(x)
# x = layers.Dropout(0.5)(x)
x = layers.Dense(60, activation='relu')(x)
x = layers.Dropout(0.5)(x)
output= layers.Dense(class_count, activation='softmax')(x)

#mobile model
mobileNet_model = Model(pre_trained_model_mn.input, output) ##

# %%
# Compile model
mobileNet_model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
              loss=tf.keras.losses.CategoricalCrossentropy(),
              metrics=[AUC(name='auc')]
              )

# Train model
mobileNet_model.fit(ds_train_sm_mn, ##
          validation_data=ds_val_sm_mn, ##
          epochs=200,
          # callbacks=callback_params,
          # class_weight=class_weights,
          callbacks=[tf.keras.callbacks.EarlyStopping(monitor='val_auc', patience=15),
                    #  tf.keras.callbacks.ModelCheckpoint('models/mobileNet_ai_{val_auc:.3f}.h5',
                    #                                     save_best_only=True,
                    #                                     save_weights_only=False,
                    #                                     monitor='val_auc')
                     ]
          )
# Out:
# Epoch 1/200
# 26/26 [==============================] - 8s 138ms/step - loss: 0.8064 - auc: 0.6464 - val_loss: 0.5324 - val_auc: 0.8074
# Epoch 2/200
# 26/26 [==============================] - 3s 102ms/step - loss: 0.7054 - auc: 0.7166 - val_loss: 0.4489 - val_auc: 0.8748
# Epoch 3/200
# 26/26 [==============================] - 2s 88ms/step - loss: 0.4792 - auc: 0.8574 - val_loss: 0.4138 - val_auc: 0.8959
# Epoch 4/200
# 26/26 [==============================] - 2s 92ms/step - loss: 0.4308 - auc: 0.8797 - val_loss: 0.3965 - val_auc: 0.9058
# Epoch 5/200
# 26/26 [==============================] - 2s 86ms/step - loss: 0.4099 - auc: 0.8927 - val_loss: 0.3736 - val_auc: 0.9184
# Epoch 6/200
# 26/26 [==============================] - 3s 107ms/step - loss: 0.3366 - auc: 0.9303 - val_loss: 0.3688 - val_auc: 0.9169
# Epoch 7/200
# 26/26 [==============================] - 3s 123ms/step - loss: 0.3512 - auc: 0.9218 - val_loss: 0.3602 - val_auc: 0.9212
# Epoch 8/200
# 26/26 [==============================] - 2s 91ms/step - loss: 0.2923 - auc: 0.9489 - val_loss: 0.3504 - val_auc: 0.9257
# Epoch 9/200
# 26/26 [==============================] - 2s 87ms/step - loss: 0.3221 - auc: 0.9403 - val_loss: 0.3560 - val_auc: 0.9214
# Epoch 10/200
# 26/26 [==============================] - 2s 88ms/step - loss: 0.3242 - auc: 0.9354 - val_loss: 0.3492 - val_auc: 0.9253
# Epoch 11/200
# 26/26 [==============================] - 2s 90ms/step - loss: 0.2735 - auc: 0.9590 - val_loss: 0.3449 - val_auc: 0.9265
# Epoch 12/200
# 26/26 [==============================] - 3s 128ms/step - loss: 0.2540 - auc: 0.9672 - val_loss: 0.3440 - val_auc: 0.9277
# Epoch 13/200
# 26/26 [==============================] - 2s 89ms/step - loss: 0.2660 - auc: 0.9594 - val_loss: 0.3368 - val_auc: 0.9309
# Epoch 14/200
# 26/26 [==============================] - 2s 86ms/step - loss: 0.2678 - auc: 0.9580 - val_loss: 0.3356 - val_auc: 0.9309
# Epoch 15/200
# 26/26 [==============================] - 2s 87ms/step - loss: 0.2208 - auc: 0.9742 - val_loss: 0.3381 - val_auc: 0.9310
# Epoch 16/200
# 26/26 [==============================] - 2s 95ms/step - loss: 0.2372 - auc: 0.9690 - val_loss: 0.3308 - val_auc: 0.9329
# Epoch 17/200
# 26/26 [==============================] - 3s 101ms/step - loss: 0.2175 - auc: 0.9768 - val_loss: 0.3428 - val_auc: 0.9294
# Epoch 18/200
# 26/26 [==============================] - 2s 89ms/step - loss: 0.2431 - auc: 0.9669 - val_loss: 0.3354 - val_auc: 0.9318
# Epoch 19/200
# 26/26 [==============================] - 3s 108ms/step - loss: 0.1910 - auc: 0.9841 - val_loss: 0.3469 - val_auc: 0.9280
# Epoch 20/200
# 26/26 [==============================] - 2s 91ms/step - loss: 0.1884 - auc: 0.9855 - val_loss: 0.3423 - val_auc: 0.9299
# Epoch 21/200
# 26/26 [==============================] - 3s 114ms/step - loss: 0.2023 - auc: 0.9791 - val_loss: 0.3373 - val_auc: 0.9314
# Epoch 22/200
# 26/26 [==============================] - 2s 89ms/step - loss: 0.1920 - auc: 0.9844 - val_loss: 0.3448 - val_auc: 0.9299
# Epoch 23/200
# 26/26 [==============================] - 2s 86ms/step - loss: 0.1647 - auc: 0.9886 - val_loss: 0.3501 - val_auc: 0.9292
# Epoch 24/200
# 26/26 [==============================] - 2s 88ms/step - loss: 0.1738 - auc: 0.9848 - val_loss: 0.3306 - val_auc: 0.9339
# Epoch 25/200
# 26/26 [==============================] - 3s 112ms/step - loss: 0.1677 - auc: 0.9899 - val_loss: 0.3391 - val_auc: 0.9320
# Epoch 26/200
# 26/26 [==============================] - 2s 87ms/step - loss: 0.1775 - auc: 0.9837 - val_loss: 0.3350 - val_auc: 0.9339
# Epoch 27/200
# 26/26 [==============================] - 2s 85ms/step - loss: 0.1664 - auc: 0.9870 - val_loss: 0.3440 - val_auc: 0.9324
# Epoch 28/200
# 26/26 [==============================] - 2s 90ms/step - loss: 0.1567 - auc: 0.9894 - val_loss: 0.3411 - val_auc: 0.9333
# Epoch 29/200
# 26/26 [==============================] - 2s 87ms/step - loss: 0.1381 - auc: 0.9926 - val_loss: 0.3454 - val_auc: 0.9325
# Epoch 30/200
# 26/26 [==============================] - 3s 128ms/step - loss: 0.1454 - auc: 0.9907 - val_loss: 0.3463 - val_auc: 0.9324
# Epoch 31/200
# 26/26 [==============================] - 2s 86ms/step - loss: 0.1430 - auc: 0.9915 - val_loss: 0.3510 - val_auc: 0.9311
# Epoch 32/200
# 26/26 [==============================] - 2s 87ms/step - loss: 0.1366 - auc: 0.9919 - val_loss: 0.3503 - val_auc: 0.9324
# Epoch 33/200
# 26/26 [==============================] - 2s 85ms/step - loss: 0.1407 - auc: 0.9911 - val_loss: 0.3442 - val_auc: 0.9336
# Epoch 34/200
# 26/26 [==============================] - 2s 88ms/step - loss: 0.1197 - auc: 0.9954 - val_loss: 0.3492 - val_auc: 0.9332
# Epoch 35/200
# 26/26 [==============================] - 3s 102ms/step - loss: 0.1193 - auc: 0.9968 - val_loss: 0.3484 - val_auc: 0.9339
# Epoch 36/200
# 26/26 [==============================] - 3s 110ms/step - loss: 0.1201 - auc: 0.9959 - val_loss: 0.3568 - val_auc: 0.9335
# Epoch 37/200
# 26/26 [==============================] - 2s 86ms/step - loss: 0.1244 - auc: 0.9940 - val_loss: 0.3528 - val_auc: 0.9356
# Epoch 38/200
# 26/26 [==============================] - 2s 88ms/step - loss: 0.1153 - auc: 0.9957 - val_loss: 0.3484 - val_auc: 0.9357
# Epoch 39/200
# 26/26 [==============================] - 2s 84ms/step - loss: 0.1238 - auc: 0.9941 - val_loss: 0.3537 - val_auc: 0.9351
# Epoch 40/200
# 26/26 [==============================] - 3s 110ms/step - loss: 0.0979 - auc: 0.9981 - val_loss: 0.3665 - val_auc: 0.9331
# Epoch 41/200
# 26/26 [==============================] - 2s 89ms/step - loss: 0.1063 - auc: 0.9966 - val_loss: 0.3497 - val_auc: 0.9360
# Epoch 42/200
# 26/26 [==============================] - 2s 88ms/step - loss: 0.1033 - auc: 0.9968 - val_loss: 0.3597 - val_auc: 0.9342
# Epoch 43/200
# 26/26 [==============================] - 3s 104ms/step - loss: 0.1010 - auc: 0.9972 - val_loss: 0.3529 - val_auc: 0.9357
# Epoch 44/200
# 26/26 [==============================] - 3s 110ms/step - loss: 0.0903 - auc: 0.9979 - val_loss: 0.3683 - val_auc: 0.9312
# Epoch 45/200
# 26/26 [==============================] - 3s 106ms/step - loss: 0.1041 - auc: 0.9964 - val_loss: 0.3664 - val_auc: 0.9321
# Epoch 46/200
# 26/26 [==============================] - 2s 91ms/step - loss: 0.0936 - auc: 0.9980 - val_loss: 0.3633 - val_auc: 0.9329
# Epoch 47/200
# 26/26 [==============================] - 2s 89ms/step - loss: 0.0798 - auc: 0.9993 - val_loss: 0.3702 - val_auc: 0.9321
# Epoch 48/200
# 26/26 [==============================] - 2s 90ms/step - loss: 0.0725 - auc: 0.9990 - val_loss: 0.3705 - val_auc: 0.9327
# Epoch 49/200
# 26/26 [==============================] - 3s 120ms/step - loss: 0.0717 - auc: 0.9996 - val_loss: 0.3613 - val_auc: 0.9343
# Epoch 50/200
# 26/26 [==============================] - 2s 91ms/step - loss: 0.0977 - auc: 0.9970 - val_loss: 0.3774 - val_auc: 0.9323
# Epoch 51/200
# 26/26 [==============================] - 2s 90ms/step - loss: 0.0745 - auc: 0.9997 - val_loss: 0.3848 - val_auc: 0.9312
# Epoch 52/200
# 26/26 [==============================] - 2s 93ms/step - loss: 0.0753 - auc: 0.9990 - val_loss: 0.3827 - val_auc: 0.9322
# Epoch 53/200
# 26/26 [==============================] - 3s 99ms/step - loss: 0.0790 - auc: 0.9984 - val_loss: 0.3919 - val_auc: 0.9315
# Epoch 54/200
# 26/26 [==============================] - 3s 113ms/step - loss: 0.0733 - auc: 0.9993 - val_loss: 0.3700 - val_auc: 0.9333
# Epoch 55/200
# 26/26 [==============================] - 2s 87ms/step - loss: 0.0827 - auc: 0.9978 - val_loss: 0.3825 - val_auc: 0.9322
# Epoch 56/200
# 26/26 [==============================] - 2s 91ms/step - loss: 0.0727 - auc: 0.9995 - val_loss: 0.3823 - val_auc: 0.9341

# %%
##save model
# resnet_model.save('/content/drive/MyDrive/Research/models/resnet_model_ai.h5')
# Assuming 'model' is your TensorFlow model
mobileNet_model.save("/content/drive/MyDrive/All mixed/cls/wsl/round1/mobileNet_model_sm_03.h5")
#load the model:
# saved_resnet_model = tf.keras.models.load_model('/content/drive/MyDrive/Research/models/resnet_model_ai.h5');
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %% [markdown]
# ###Performance

# %%
plot_acc_loss_graphs(mobileNet_model)

# %% [markdown]
# ### Evaluation

# %%
#save model
#mobileNet_model.save('/content/drive/MyDrive/Research/models/mobileNet_model_03.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
#load saved model:
saved_mobileNet_model = tf.keras.models.load_model('/content/drive/MyDrive/All mixed/cls/wsl/round1/mobileNet_model_sm_03.h5');
#saved_mobileNet_model2 = tf.keras.models.load_model('/content/drive/MyDrive/Research/models/mobileNet_model_sm_01.h5');
#saved_mobileNet_model3 = tf.keras.models.load_model('/content/drive/MyDrive/Research/models/mobileNet_model_sm_02.h5');

# %%
#predict
y_pred_mn = saved_mobileNet_model.predict(ds_test_sm_mn, verbose=1)
print(f'y_pred_shape:{y_pred_mn.shape} and shape[0] is: {y_pred_mn.shape[0]}')
# Out:
# 1/1 [==============================] - 2s 2s/step
# y_pred_shape:(262, 2) and shape[0] is: 262

# %%
plot_evaluation_graphs(y_pred_mn, ds_test_sm_mn)
# Out:
#               precision    recall  f1-score   support
#
#       benign       0.84      0.89      0.86       131
#    malignant       0.88      0.83      0.85       131
#
#    micro avg       0.86      0.86      0.86       262
#    macro avg       0.86      0.86      0.86       262
# weighted avg       0.86      0.86      0.86       262
#  samples avg       0.86      0.86      0.86       262

# %% [markdown]
# #VGG19

# %% [markdown]
# ##Create and preprocess datasets

# %%
# def preprocess_v19(images, labels):
#   return tf.keras.applications.vgg19.preprocess_input(images), labels

# %%
# ds_train_v19, ds_val_v19, ds_test_v19 = get_image_dataset_arrays(batch_size_p=64, img_size_p=224)
ds_train_v19, ds_val_v19, ds_test_v19 = generators((224,224), tf.keras.applications.vgg19.preprocess_input, train_dir, val_dir, test_dir, 70)
# Out:
# Found 260 images belonging to 2 classes.
# Found 134 images belonging to 2 classes.
# Found 0 images belonging to 2 classes.

# %% [markdown]
# ##Train, compile and fit model

# %%
pre_trained_model_v19 = Sequential();
pre_trained_model_v19 = tf.keras.applications.VGG19(input_shape=(224,224, 3),  ##
                             include_top = False,
                             weights = 'imagenet',
                             pooling='avg',
                             classes=2
                             )

# Freeze layers
for layer in pre_trained_model_v19.layers: ##
  layer.trainable = False

x = pre_trained_model_v19.output ##
x = layers.Flatten()(x)
x = layers.Dense(32, activation='relu')(x)
x = layers.Dropout(0.5)(x)
output= layers.Dense(class_count, activation='softmax')(x)

#vgg19 model
vgg19_model = Model(pre_trained_model_v19.input, output) ##

# %%
# Compile model
vgg19_model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
              loss=tf.keras.losses.CategoricalCrossentropy(),
              metrics=[AUC(name='auc')]
              )

# Train model
vgg19_model.fit(ds_train_v19, ##
          validation_data=ds_val_v19, ##
          epochs=200,
          # class_weight=class_weights,
          callbacks=[tf.keras.callbacks.EarlyStopping(monitor='val_auc', patience=10),
                    #  tf.keras.callbacks.ModelCheckpoint('models/vgg19_ai_{val_auc:.3f}.h5',
                    #                                     save_best_only=True,
                    #                                     save_weights_only=False,
                    #                                     monitor='val_auc')
                     ]
          )
# Out:
# Epoch 1/200
# 8/8 [==============================] - 7s 690ms/step - loss: 2.3178 - auc: 0.5251 - val_loss: 0.4878 - val_auc: 0.8457
# Epoch 2/200
# 8/8 [==============================] - 4s 499ms/step - loss: 0.8094 - auc: 0.7740 - val_loss: 0.4190 - val_auc: 0.8966
# Epoch 3/200
# 8/8 [==============================] - 5s 565ms/step - loss: 0.5275 - auc: 0.8624 - val_loss: 0.3899 - val_auc: 0.9063
# Epoch 4/200
# 8/8 [==============================] - 5s 667ms/step - loss: 0.4676 - auc: 0.8720 - val_loss: 0.4007 - val_auc: 0.9037
# Epoch 5/200
# 8/8 [==============================] - 4s 510ms/step - loss: 0.3972 - auc: 0.9022 - val_loss: 0.3900 - val_auc: 0.9053
# Epoch 6/200
# 8/8 [==============================] - 4s 512ms/step - loss: 0.3266 - auc: 0.9298 - val_loss: 0.3883 - val_auc: 0.9052
# Epoch 7/200
# 8/8 [==============================] - 5s 641ms/step - loss: 0.3446 - auc: 0.9203 - val_loss: 0.3895 - val_auc: 0.9067
# Epoch 8/200
# 8/8 [==============================] - 4s 493ms/step - loss: 0.3382 - auc: 0.9252 - val_loss: 0.3810 - val_auc: 0.9111
# Epoch 9/200
# 8/8 [==============================] - 5s 610ms/step - loss: 0.3020 - auc: 0.9410 - val_loss: 0.3765 - val_auc: 0.9145
# Epoch 10/200
# 8/8 [==============================] - 5s 533ms/step - loss: 0.3044 - auc: 0.9391 - val_loss: 0.3735 - val_auc: 0.9187
# Epoch 11/200
# 8/8 [==============================] - 4s 498ms/step - loss: 0.2830 - auc: 0.9502 - val_loss: 0.3734 - val_auc: 0.9186
# Epoch 12/200
# 8/8 [==============================] - 4s 528ms/step - loss: 0.2643 - auc: 0.9572 - val_loss: 0.3729 - val_auc: 0.9156
# Epoch 13/200
# 8/8 [==============================] - 5s 585ms/step - loss: 0.2651 - auc: 0.9560 - val_loss: 0.3728 - val_auc: 0.9173
# Epoch 14/200
# 8/8 [==============================] - 4s 519ms/step - loss: 0.2541 - auc: 0.9611 - val_loss: 0.3714 - val_auc: 0.9226
# Epoch 15/200
# 8/8 [==============================] - 4s 543ms/step - loss: 0.2410 - auc: 0.9639 - val_loss: 0.3674 - val_auc: 0.9265
# Epoch 16/200
# 8/8 [==============================] - 5s 614ms/step - loss: 0.2268 - auc: 0.9694 - val_loss: 0.3640 - val_auc: 0.9316
# Epoch 17/200
# 8/8 [==============================] - 4s 498ms/step - loss: 0.2179 - auc: 0.9713 - val_loss: 0.3682 - val_auc: 0.9285
# Epoch 18/200
# 8/8 [==============================] - 4s 512ms/step - loss: 0.2176 - auc: 0.9711 - val_loss: 0.3706 - val_auc: 0.9260
# Epoch 19/200
# 8/8 [==============================] - 5s 566ms/step - loss: 0.2152 - auc: 0.9722 - val_loss: 0.3751 - val_auc: 0.9249
# Epoch 20/200
# 8/8 [==============================] - 5s 605ms/step - loss: 0.2261 - auc: 0.9688 - val_loss: 0.3702 - val_auc: 0.9256
# Epoch 21/200
# 8/8 [==============================] - 4s 483ms/step - loss: 0.2096 - auc: 0.9756 - val_loss: 0.3691 - val_auc: 0.9279
# Epoch 22/200
# 8/8 [==============================] - 4s 507ms/step - loss: 0.1857 - auc: 0.9806 - val_loss: 0.3680 - val_auc: 0.9293
# Epoch 23/200
# 8/8 [==============================] - 5s 702ms/step - loss: 0.1791 - auc: 0.9830 - val_loss: 0.3730 - val_auc: 0.9284
# Epoch 24/200
# 8/8 [==============================] - 4s 553ms/step - loss: 0.1859 - auc: 0.9799 - val_loss: 0.3751 - val_auc: 0.9306
# Epoch 25/200
# 8/8 [==============================] - 5s 627ms/step - loss: 0.1736 - auc: 0.9833 - val_loss: 0.3672 - val_auc: 0.9299
# Epoch 26/200
# 8/8 [==============================] - 4s 497ms/step - loss: 0.1620 - auc: 0.9876 - val_loss: 0.3685 - val_auc: 0.9318
# Epoch 27/200
# 8/8 [==============================] - 5s 601ms/step - loss: 0.1639 - auc: 0.9854 - val_loss: 0.3753 - val_auc: 0.9341
# Epoch 28/200
# 8/8 [==============================] - 5s 540ms/step - loss: 0.1638 - auc: 0.9848 - val_loss: 0.3637 - val_auc: 0.9353
# Epoch 29/200
# 8/8 [==============================] - 4s 503ms/step - loss: 0.1523 - auc: 0.9882 - val_loss: 0.3660 - val_auc: 0.9343
# Epoch 30/200
# 8/8 [==============================] - 5s 585ms/step - loss: 0.1502 - auc: 0.9890 - val_loss: 0.3725 - val_auc: 0.9351
# Epoch 31/200
# 8/8 [==============================] - 5s 627ms/step - loss: 0.1524 - auc: 0.9881 - val_loss: 0.3671 - val_auc: 0.9335
# Epoch 32/200
# 8/8 [==============================] - 5s 636ms/step - loss: 0.1316 - auc: 0.9928 - val_loss: 0.3808 - val_auc: 0.9346
# Epoch 33/200
# 8/8 [==============================] - 5s 555ms/step - loss: 0.1469 - auc: 0.9890 - val_loss: 0.3722 - val_auc: 0.9338
# Epoch 34/200
# 8/8 [==============================] - 4s 564ms/step - loss: 0.1320 - auc: 0.9922 - val_loss: 0.3868 - val_auc: 0.9339
# Epoch 35/200
# 8/8 [==============================] - 5s 552ms/step - loss: 0.1291 - auc: 0.9920 - val_loss: 0.3827 - val_auc: 0.9352
# Epoch 36/200
# 8/8 [==============================] - 5s 582ms/step - loss: 0.1274 - auc: 0.9925 - val_loss: 0.3959 - val_auc: 0.9348
# Epoch 37/200
# 8/8 [==============================] - 4s 508ms/step - loss: 0.1098 - auc: 0.9955 - val_loss: 0.3898 - val_auc: 0.9362
# Epoch 38/200
# 8/8 [==============================] - 4s 545ms/step - loss: 0.1154 - auc: 0.9942 - val_loss: 0.4068 - val_auc: 0.9358
# Epoch 39/200
# 8/8 [==============================] - 5s 637ms/step - loss: 0.1126 - auc: 0.9936 - val_loss: 0.3999 - val_auc: 0.9349
# Epoch 40/200
# 8/8 [==============================] - 5s 605ms/step - loss: 0.1267 - auc: 0.9919 - val_loss: 0.4024 - val_auc: 0.9354
# Epoch 41/200
# 8/8 [==============================] - 5s 599ms/step - loss: 0.1132 - auc: 0.9944 - val_loss: 0.3974 - val_auc: 0.9350
# Epoch 42/200
# 8/8 [==============================] - 4s 519ms/step - loss: 0.1054 - auc: 0.9959 - val_loss: 0.4076 - val_auc: 0.9364
# Epoch 43/200
# 8/8 [==============================] - 4s 506ms/step - loss: 0.0984 - auc: 0.9960 - val_loss: 0.4013 - val_auc: 0.9370
# Epoch 44/200
# 8/8 [==============================] - 5s 598ms/step - loss: 0.0979 - auc: 0.9965 - val_loss: 0.4088 - val_auc: 0.9363
# Epoch 45/200
# 8/8 [==============================] - 5s 544ms/step - loss: 0.1013 - auc: 0.9959 - val_loss: 0.4198 - val_auc: 0.9323
# Epoch 46/200
# 8/8 [==============================] - 4s 505ms/step - loss: 0.0999 - auc: 0.9959 - val_loss: 0.4085 - val_auc: 0.9355
# Epoch 47/200
# 8/8 [==============================] - 5s 563ms/step - loss: 0.0904 - auc: 0.9973 - val_loss: 0.4048 - val_auc: 0.9377
# Epoch 48/200
# 8/8 [==============================] - 5s 649ms/step - loss: 0.1036 - auc: 0.9956 - val_loss: 0.4247 - val_auc: 0.9321
# Epoch 49/200
# 8/8 [==============================] - 4s 504ms/step - loss: 0.0801 - auc: 0.9976 - val_loss: 0.4210 - val_auc: 0.9347
# Epoch 50/200
# 8/8 [==============================] - 4s 508ms/step - loss: 0.0919 - auc: 0.9969 - val_loss: 0.4146 - val_auc: 0.9352
# Epoch 51/200
# 8/8 [==============================] - 5s 617ms/step - loss: 0.0885 - auc: 0.9969 - val_loss: 0.4172 - val_auc: 0.9363
# Epoch 52/200
# 8/8 [==============================] - 4s 545ms/step - loss: 0.0926 - auc: 0.9967 - val_loss: 0.4332 - val_auc: 0.9343
# Epoch 53/200
# 8/8 [==============================] - 4s 507ms/step - loss: 0.0911 - auc: 0.9969 - val_loss: 0.4327 - val_auc: 0.9364
# Epoch 54/200
# 8/8 [==============================] - 5s 646ms/step - loss: 0.0782 - auc: 0.9975 - val_loss: 0.4510 - val_auc: 0.9346
# Epoch 55/200
# 8/8 [==============================] - 5s 538ms/step - loss: 0.0680 - auc: 0.9990 - val_loss: 0.4372 - val_auc: 0.9360
# Epoch 56/200
# 8/8 [==============================] - 4s 508ms/step - loss: 0.0866 - auc: 0.9970 - val_loss: 0.4403 - val_auc: 0.9371
# Epoch 57/200
# 8/8 [==============================] - 5s 570ms/step - loss: 0.0709 - auc: 0.9985 - val_loss: 0.4455 - val_auc: 0.9308

# %% [markdown]
# ##Performance

# %%
plot_acc_loss_graphs(vgg19_model)

# %% [markdown]
# ## Evaluation

# %%
#save model
vgg19_model.save('/content/drive/MyDrive/Research/models/vgg19_model_03.h5')

# %%
#load saved model:
saved_vgg19_model = tf.keras.models.load_model('/content/drive/MyDrive/Research/models/vgg19_model_02.h5');

# %%
#predict
y_pred_v19 = saved_vgg19_model.predict(ds_test_v19, verbose=1)
print(f'y_pred_shape:{y_pred_v19.shape} and shape[0] is: {y_pred_v19.shape[0]}')
# Out:
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x781af52c49d0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 428ms/step
# y_pred_shape:(70, 2) and shape[0] is: 70

# %%
plot_evaluation_graphs(y_pred_v19, ds_test_v19)
# Out:
#               precision    recall  f1-score   support
#
#       benign       0.54      0.63      0.58        35
#    malignant       0.55      0.46      0.50        35
#
#    micro avg       0.54      0.54      0.54        70
#    macro avg       0.54      0.54      0.54        70
# weighted avg       0.54      0.54      0.54        70
#  samples avg       0.54      0.54      0.54        70

# %% [markdown]
# ##View sample images

# %%
#view sample images
image_v19, label_v19 = ds_test_v19.next()
view_2_images(image_v19, label_v19, y_pred_v19, classes)
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ##Smaller Generators - TAKEN

# %% [markdown]
# ###Create and preprocess datasets

# %%
# def preprocess_v19(images, labels):
#   return tf.keras.applications.vgg19.preprocess_input(images), labels

# %%
# ds_train_v19, ds_val_v19, ds_test_v19 = get_image_dataset_arrays(batch_size_p=64, img_size_p=224)
ds_train_sm_v19, ds_val_sm_v19 = generators_train_val((224,224), tf.keras.applications.vgg19.preprocess_input, train_dir, val_dir, 8)
ds_test_sm_v19 = generator_test((224,224), tf.keras.applications.vgg19.preprocess_input, test_dir, 262)
# Out:
# Found 260 images belonging to 2 classes.
# Found 134 images belonging to 2 classes.
# Found 262 images belonging to 2 classes.

# %% [markdown]
# ###Train, compile and fit model

# %%
pre_trained_model_v19 = Sequential();
pre_trained_model_v19 = tf.keras.applications.VGG19(input_shape=(224,224, 3),  ##
                             include_top = False,
                             weights = 'imagenet',
                             pooling='avg',
                             classes=2
                             )

# Freeze layers
for layer in pre_trained_model_v19.layers: ##
  layer.trainable = False

x = pre_trained_model_v19.output ##
x = layers.Flatten()(x)
x = layers.Dense(32, activation='relu')(x)
x = layers.Dropout(0.5)(x)
output= layers.Dense(class_count, activation='softmax')(x)

#vgg19 model
vgg19_model = Model(pre_trained_model_v19.input, output) ##
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80134624/80134624 [==============================] - 0s 0us/step

# %%
# Compile model
vgg19_model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
              loss=tf.keras.losses.CategoricalCrossentropy(),
              metrics=[AUC(name='auc')]
              )

# Train model
vgg19_model.fit(ds_train_sm_v19, ##
          validation_data=ds_val_sm_v19, ##
          epochs=200,
          # class_weight=class_weights,
          callbacks=[tf.keras.callbacks.EarlyStopping(monitor='val_auc', patience=5),
                    #  tf.keras.callbacks.ModelCheckpoint('models/vgg19_ai_{val_auc:.3f}.h5',
                    #                                     save_best_only=True,
                    #                                     save_weights_only=False,
                    #                                     monitor='val_auc')
                     ]
          )
# Out:
# Epoch 1/200
# 33/33 [==============================] - 10s 202ms/step - loss: 1.2364 - auc: 0.7199 - val_loss: 0.5467 - val_auc: 0.8734
# Epoch 2/200
# 33/33 [==============================] - 3s 97ms/step - loss: 0.5140 - auc: 0.8707 - val_loss: 0.4595 - val_auc: 0.8805
# Epoch 3/200
# 33/33 [==============================] - 3s 90ms/step - loss: 0.4030 - auc: 0.9089 - val_loss: 0.4237 - val_auc: 0.8857
# Epoch 4/200
# 33/33 [==============================] - 3s 98ms/step - loss: 0.3706 - auc: 0.9129 - val_loss: 0.4172 - val_auc: 0.8917
# Epoch 5/200
# 33/33 [==============================] - 4s 106ms/step - loss: 0.3047 - auc: 0.9393 - val_loss: 0.4892 - val_auc: 0.8897
# Epoch 6/200
# 33/33 [==============================] - 3s 90ms/step - loss: 0.3765 - auc: 0.9085 - val_loss: 0.4357 - val_auc: 0.8925
# Epoch 7/200
# 33/33 [==============================] - 3s 90ms/step - loss: 0.2796 - auc: 0.9492 - val_loss: 0.4542 - val_auc: 0.8975
# Epoch 8/200
# 33/33 [==============================] - 3s 96ms/step - loss: 0.2190 - auc: 0.9725 - val_loss: 0.4342 - val_auc: 0.9028
# Epoch 9/200
# 33/33 [==============================] - 4s 106ms/step - loss: 0.2361 - auc: 0.9666 - val_loss: 0.3920 - val_auc: 0.9115
# Epoch 10/200
# 33/33 [==============================] - 3s 91ms/step - loss: 0.2051 - auc: 0.9762 - val_loss: 0.4262 - val_auc: 0.9140
# Epoch 11/200
# 33/33 [==============================] - 3s 90ms/step - loss: 0.1941 - auc: 0.9770 - val_loss: 0.4519 - val_auc: 0.9084
# Epoch 12/200
# 33/33 [==============================] - 3s 92ms/step - loss: 0.1767 - auc: 0.9820 - val_loss: 0.4305 - val_auc: 0.9140
# Epoch 13/200
# 33/33 [==============================] - 4s 107ms/step - loss: 0.1397 - auc: 0.9912 - val_loss: 0.4228 - val_auc: 0.9144
# Epoch 14/200
# 33/33 [==============================] - 3s 91ms/step - loss: 0.1609 - auc: 0.9874 - val_loss: 0.4659 - val_auc: 0.9130
# Epoch 15/200
# 33/33 [==============================] - 3s 91ms/step - loss: 0.1397 - auc: 0.9897 - val_loss: 0.4502 - val_auc: 0.9123
# Epoch 16/200
# 33/33 [==============================] - 4s 105ms/step - loss: 0.1571 - auc: 0.9854 - val_loss: 0.4126 - val_auc: 0.9148
# Epoch 17/200
# 33/33 [==============================] - 3s 92ms/step - loss: 0.1314 - auc: 0.9918 - val_loss: 0.4330 - val_auc: 0.9186
# Epoch 18/200
# 33/33 [==============================] - 3s 92ms/step - loss: 0.1494 - auc: 0.9866 - val_loss: 0.4217 - val_auc: 0.9212
# Epoch 19/200
# 33/33 [==============================] - 3s 93ms/step - loss: 0.1250 - auc: 0.9925 - val_loss: 0.4146 - val_auc: 0.9254
# Epoch 20/200
# 33/33 [==============================] - 3s 94ms/step - loss: 0.1299 - auc: 0.9903 - val_loss: 0.4157 - val_auc: 0.9264
# Epoch 21/200
# 33/33 [==============================] - 3s 93ms/step - loss: 0.0979 - auc: 0.9955 - val_loss: 0.4782 - val_auc: 0.9235
# Epoch 22/200
# 33/33 [==============================] - 3s 92ms/step - loss: 0.1099 - auc: 0.9944 - val_loss: 0.4546 - val_auc: 0.9157
# Epoch 23/200
# 33/33 [==============================] - 4s 108ms/step - loss: 0.1061 - auc: 0.9959 - val_loss: 0.4539 - val_auc: 0.9214
# Epoch 24/200
# 33/33 [==============================] - 3s 98ms/step - loss: 0.0915 - auc: 0.9963 - val_loss: 0.4734 - val_auc: 0.9231
# Epoch 25/200
# 33/33 [==============================] - 3s 101ms/step - loss: 0.0998 - auc: 0.9943 - val_loss: 0.4418 - val_auc: 0.9264

# %% [markdown]
# ###Performance

# %%
plot_acc_loss_graphs(vgg19_model)

# %% [markdown]
# ### Evaluation

# %%
#save model
vgg19_model.save('/content/drive/MyDrive/All mixed/cls/wsl/round1/vgg19_model_sm_wsl_01.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
#load saved model:
saved_vgg19_model = tf.keras.models.load_model('/content/drive/MyDrive/All mixed/cls/wsl/round1/vgg19_model_sm_wsl_01.h5');

# %%
#predict
y_pred_v19 = saved_vgg19_model.predict(ds_test_sm_v19, verbose=1)
print(f'y_pred_shape:{y_pred_v19.shape} and shape[0] is: {y_pred_v19.shape[0]}')
# Out:
# 1/1 [==============================] - 39s 39s/step
# y_pred_shape:(262, 2) and shape[0] is: 262

# %%
plot_evaluation_graphs(y_pred_v19, ds_test_sm_v19)
# Out:
#               precision    recall  f1-score   support
#
#       benign       0.87      0.87      0.87       131
#    malignant       0.87      0.87      0.87       131
#
#    micro avg       0.87      0.87      0.87       262
#    macro avg       0.87      0.87      0.87       262
# weighted avg       0.87      0.87      0.87       262
#  samples avg       0.87      0.87      0.87       262

# %% [markdown]
# #Misclassified Images

# %%
# Convert predictions to class labels
vgg19_predicted_labels = np.argmax(y_pred_v19, axis=1)

# Find misclassified indices
vgg19_misclassified_indices = np.where(vgg19_predicted_labels != ds_test_sm_v19)[0]

# %%
for index in vgg19_misclassified_indices:  # Display the first 5 misclassified images
    img = ds_test_sm_v19[index]
    true_label = y_pred_v19[index]
    predicted_label = vgg19_predicted_labels[index]
    print(img, true_label, predicted_label)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-156-9e27c44a9add> in <cell line: 1>()
# ----> 1 for index in misclassified_indices:  # Display the first 5 misclassified images
#       2     img = ds_test_sm_v19[index]
#       3     true_label = y_pred_v19[index]
#       4     predicted_label = vgg19_predicted_labels[index]
#
# NameError: name 'misclassified_indices' is not defined

# %% [markdown]
# #**WSL ROUND TWO**

# %% [markdown]
# #ResNet50

# %% [markdown]
# ##Setup folders

# %%
rn_train_dir_r2='/content/drive/MyDrive/All mixed/cls/wsl/round2/ResNet50 train'
rn_val_dir_r2='/content/drive/MyDrive/All mixed/cls/wsl/round1/val'
rn_test_dir_r2='/content/drive/MyDrive/All mixed/cls/wsl/round2/test'

# %% [markdown]
# ## Separate Predictions

# %%
rn_df_results = get_dataframe_results(y_pred_rn, resnet_model, ds_test_rn)
# Out:
# 1/1 [==============================] - 2s 2s/step

# %%
rn_df_results.Predicted_Class.value_counts()
# Out:
# Predicted_Class
# 0    139
# 1    123
# Name: count, dtype: int64

# %%
#separate predictions into folder for training
rn_folder_b = '/content/drive/MyDrive/All mixed/cls/wsl/round2/ResNet50 train/benign'
rn_folder_m = '/content/drive/MyDrive/All mixed/cls/wsl/round2/ResNet50 train/malignant'

#move_predicted_images_into_folders(rn_folder_b, rn_folder_m, rn_df_results)
# Out:
# Images moved successfully.

# %%
#mix with original test data
src='/content/drive/MyDrive/All mixed/cls/wsl/round1/train/malignant'
dst = '/content/drive/MyDrive/All mixed/cls/wsl/round2/ResNet50 train/malignant'
#copy_jpg_images(src, dst)
# Out:
# Images copied successfully.

# %%
#mix with original test data
src='/content/drive/MyDrive/All mixed/cls/wsl/round1/train/benign'
dst = '/content/drive/MyDrive/All mixed/cls/wsl/round2/ResNet50 train/benign'
#copy_jpg_images(src, dst)
# Out:
# Images copied successfully.

# %%
count_images(rn_train_dir_r2)
count_images(rn_val_dir_r2)
count_images(rn_test_dir_r2)
# Out:
# 253 files in subdirectory malignant.
# 269 files in subdirectory benign.
# Total: 522 files.
# 67 files in subdirectory malignant.
# 67 files in subdirectory benign.
# Total: 134 files.
# 35 files in subdirectory benign.
# 35 files in subdirectory malignant.
# Total: 70 files.

# %% [markdown]
# ##Smaller generator - TAKEN

# %% [markdown]
# ####Create and preprocess datasets

# %%
#preprocess the datasets
ds_train_sm_rn_r2, ds_val_sm_rn_r2 = generators_train_val((224,224), preprocess_input, rn_train_dir_r2, rn_val_dir_r2, 10)
ds_test_sm_rn_r2 = generator_test((224,224), preprocess_input, rn_test_dir_r2, 70)
# Out:
# Found 522 images belonging to 2 classes.
# Found 134 images belonging to 2 classes.
# Found 70 images belonging to 2 classes.

# %% [markdown]
# ####Train, Compile & Fit Model

# %%
pre_trained_model_rs = Sequential();

pre_trained_model_rs = ResNet50(input_shape=(224,224, 3),
                             include_top = False,
                             weights = 'imagenet',
                             pooling='avg',
                             classes=2
                             )

# %%
# Freeze layers
for layer in pre_trained_model_rs.layers:
  layer.trainable = False

x = pre_trained_model_rs.output
x = layers.Flatten()(x)
x = layers.Dense(512, activation='relu', kernel_regularizer=regularizers.l2(0.01))(x)
x = layers.Dropout(0.5)(x)
x = layers.Dense(356, activation='relu', kernel_regularizer=regularizers.l2(0.001))(x)
x = layers.Dropout(0.5)(x)
x = layers.Dense(256, activation='relu', kernel_regularizer=regularizers.l2(0.01))(x)
x = layers.Dropout(0.5)(x)
x = layers.Dense(200, activation='relu', kernel_regularizer=regularizers.l2(0.001))(x)
x = layers.Dropout(0.5)(x)
x = layers.Dense(128, activation='relu', kernel_regularizer=regularizers.l2(0.01))(x)
x = layers.Dropout(0.5)(x)
x = layers.Dense(64, activation='relu', kernel_regularizer=regularizers.l2(0.001))(x)
x = layers.Dropout(0.5)(x)
output = layers.Dense(class_count, activation='softmax')(x)

#resnet50 model
resnet_model = Model(inputs=pre_trained_model_rs.input, outputs=output)

# %%
#model architecture
resnet_model.summary()
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_2 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  conv1_pad (ZeroPadding2D)   (None, 230, 230, 3)          0         ['input_2[0][0]']
#
#  conv1_conv (Conv2D)         (None, 112, 112, 64)         9472      ['conv1_pad[0][0]']
#
#  conv1_bn (BatchNormalizati  (None, 112, 112, 64)         256       ['conv1_conv[0][0]']
#  on)
#
#  conv1_relu (Activation)     (None, 112, 112, 64)         0         ['conv1_bn[0][0]']
#
#  pool1_pad (ZeroPadding2D)   (None, 114, 114, 64)         0         ['conv1_relu[0][0]']
#
#  pool1_pool (MaxPooling2D)   (None, 56, 56, 64)           0         ['pool1_pad[0][0]']
#
#  conv2_block1_1_conv (Conv2  (None, 56, 56, 64)           4160      ['pool1_pool[0][0]']
#  D)
#
#  conv2_block1_1_bn (BatchNo  (None, 56, 56, 64)           256       ['conv2_block1_1_conv[0][0]']
#  rmalization)
#
#  conv2_block1_1_relu (Activ  (None, 56, 56, 64)           0         ['conv2_block1_1_bn[0][0]']
#  ation)
#
#  conv2_block1_2_conv (Conv2  (None, 56, 56, 64)           36928     ['conv2_block1_1_relu[0][0]']
#  D)
#
#  conv2_block1_2_bn (BatchNo  (None, 56, 56, 64)           256       ['conv2_block1_2_conv[0][0]']
#  rmalization)
#
#  conv2_block1_2_relu (Activ  (None, 56, 56, 64)           0         ['conv2_block1_2_bn[0][0]']
#  ation)
#
#  conv2_block1_0_conv (Conv2  (None, 56, 56, 256)          16640     ['pool1_pool[0][0]']
#  D)
#
#  conv2_block1_3_conv (Conv2  (None, 56, 56, 256)          16640     ['conv2_block1_2_relu[0][0]']
#  D)
#
#  conv2_block1_0_bn (BatchNo  (None, 56, 56, 256)          1024      ['conv2_block1_0_conv[0][0]']
#  rmalization)
#
#  conv2_block1_3_bn (BatchNo  (None, 56, 56, 256)          1024      ['conv2_block1_3_conv[0][0]']
#  rmalization)
#
#  conv2_block1_add (Add)      (None, 56, 56, 256)          0         ['conv2_block1_0_bn[0][0]',
#                                                                      'conv2_block1_3_bn[0][0]']
#
#  conv2_block1_out (Activati  (None, 56, 56, 256)          0         ['conv2_block1_add[0][0]']
#  on)
#
#  conv2_block2_1_conv (Conv2  (None, 56, 56, 64)           16448     ['conv2_block1_out[0][0]']
#  D)
#
#  conv2_block2_1_bn (BatchNo  (None, 56, 56, 64)           256       ['conv2_block2_1_conv[0][0]']
#  rmalization)
#
#  conv2_block2_1_relu (Activ  (None, 56, 56, 64)           0         ['conv2_block2_1_bn[0][0]']
#  ation)
#
#  conv2_block2_2_conv (Conv2  (None, 56, 56, 64)           36928     ['conv2_block2_1_relu[0][0]']
#  D)
#
#  conv2_block2_2_bn (BatchNo  (None, 56, 56, 64)           256       ['conv2_block2_2_conv[0][0]']
#  rmalization)
#
#  conv2_block2_2_relu (Activ  (None, 56, 56, 64)           0         ['conv2_block2_2_bn[0][0]']
#  ation)
#
#  conv2_block2_3_conv (Conv2  (None, 56, 56, 256)          16640     ['conv2_block2_2_relu[0][0]']
#  D)
#
#  conv2_block2_3_bn (BatchNo  (None, 56, 56, 256)          1024      ['conv2_block2_3_conv[0][0]']
#  rmalization)
#
#  conv2_block2_add (Add)      (None, 56, 56, 256)          0         ['conv2_block1_out[0][0]',
#                                                                      'conv2_block2_3_bn[0][0]']
#
#  conv2_block2_out (Activati  (None, 56, 56, 256)          0         ['conv2_block2_add[0][0]']
#  on)
#
#  conv2_block3_1_conv (Conv2  (None, 56, 56, 64)           16448     ['conv2_block2_out[0][0]']
#  D)
#
#  conv2_block3_1_bn (BatchNo  (None, 56, 56, 64)           256       ['conv2_block3_1_conv[0][0]']
#  rmalization)
#
#  conv2_block3_1_relu (Activ  (None, 56, 56, 64)           0         ['conv2_block3_1_bn[0][0]']
#  ation)
#
#  conv2_block3_2_conv (Conv2  (None, 56, 56, 64)           36928     ['conv2_block3_1_relu[0][0]']
#  D)
#
#  conv2_block3_2_bn (BatchNo  (None, 56, 56, 64)           256       ['conv2_block3_2_conv[0][0]']
#  rmalization)
#
#  conv2_block3_2_relu (Activ  (None, 56, 56, 64)           0         ['conv2_block3_2_bn[0][0]']
#  ation)
#
#  conv2_block3_3_conv (Conv2  (None, 56, 56, 256)          16640     ['conv2_block3_2_relu[0][0]']
#  D)
#
#  conv2_block3_3_bn (BatchNo  (None, 56, 56, 256)          1024      ['conv2_block3_3_conv[0][0]']
#  rmalization)
#
#  conv2_block3_add (Add)      (None, 56, 56, 256)          0         ['conv2_block2_out[0][0]',
#                                                                      'conv2_block3_3_bn[0][0]']
#
#  conv2_block3_out (Activati  (None, 56, 56, 256)          0         ['conv2_block3_add[0][0]']
#  on)
#
#  conv3_block1_1_conv (Conv2  (None, 28, 28, 128)          32896     ['conv2_block3_out[0][0]']
#  D)
#
#  conv3_block1_1_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block1_1_conv[0][0]']
#  rmalization)
#
#  conv3_block1_1_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block1_1_bn[0][0]']
#  ation)
#
#  conv3_block1_2_conv (Conv2  (None, 28, 28, 128)          147584    ['conv3_block1_1_relu[0][0]']
#  D)
#
#  conv3_block1_2_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block1_2_conv[0][0]']
#  rmalization)
#
#  conv3_block1_2_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block1_2_bn[0][0]']
#  ation)
#
#  conv3_block1_0_conv (Conv2  (None, 28, 28, 512)          131584    ['conv2_block3_out[0][0]']
#  D)
#
#  conv3_block1_3_conv (Conv2  (None, 28, 28, 512)          66048     ['conv3_block1_2_relu[0][0]']
#  D)
#
#  conv3_block1_0_bn (BatchNo  (None, 28, 28, 512)          2048      ['conv3_block1_0_conv[0][0]']
#  rmalization)
#
#  conv3_block1_3_bn (BatchNo  (None, 28, 28, 512)          2048      ['conv3_block1_3_conv[0][0]']
#  rmalization)
#
#  conv3_block1_add (Add)      (None, 28, 28, 512)          0         ['conv3_block1_0_bn[0][0]',
#                                                                      'conv3_block1_3_bn[0][0]']
#
#  conv3_block1_out (Activati  (None, 28, 28, 512)          0         ['conv3_block1_add[0][0]']
#  on)
#
#  conv3_block2_1_conv (Conv2  (None, 28, 28, 128)          65664     ['conv3_block1_out[0][0]']
#  D)
#
#  conv3_block2_1_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block2_1_conv[0][0]']
#  rmalization)
#
#  conv3_block2_1_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block2_1_bn[0][0]']
#  ation)
#
#  conv3_block2_2_conv (Conv2  (None, 28, 28, 128)          147584    ['conv3_block2_1_relu[0][0]']
#  D)
#
#  conv3_block2_2_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block2_2_conv[0][0]']
#  rmalization)
#
#  conv3_block2_2_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block2_2_bn[0][0]']
#  ation)
#
#  conv3_block2_3_conv (Conv2  (None, 28, 28, 512)          66048     ['conv3_block2_2_relu[0][0]']
#  D)
#
#  conv3_block2_3_bn (BatchNo  (None, 28, 28, 512)          2048      ['conv3_block2_3_conv[0][0]']
#  rmalization)
#
#  conv3_block2_add (Add)      (None, 28, 28, 512)          0         ['conv3_block1_out[0][0]',
#                                                                      'conv3_block2_3_bn[0][0]']
#
#  conv3_block2_out (Activati  (None, 28, 28, 512)          0         ['conv3_block2_add[0][0]']
#  on)
#
#  conv3_block3_1_conv (Conv2  (None, 28, 28, 128)          65664     ['conv3_block2_out[0][0]']
#  D)
#
#  conv3_block3_1_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block3_1_conv[0][0]']
#  rmalization)
#
#  conv3_block3_1_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block3_1_bn[0][0]']
#  ation)
#
#  conv3_block3_2_conv (Conv2  (None, 28, 28, 128)          147584    ['conv3_block3_1_relu[0][0]']
#  D)
#
#  conv3_block3_2_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block3_2_conv[0][0]']
#  rmalization)
#
#  conv3_block3_2_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block3_2_bn[0][0]']
#  ation)
#
#  conv3_block3_3_conv (Conv2  (None, 28, 28, 512)          66048     ['conv3_block3_2_relu[0][0]']
#  D)
#
#  conv3_block3_3_bn (BatchNo  (None, 28, 28, 512)          2048      ['conv3_block3_3_conv[0][0]']
#  rmalization)
#
#  conv3_block3_add (Add)      (None, 28, 28, 512)          0         ['conv3_block2_out[0][0]',
#                                                                      'conv3_block3_3_bn[0][0]']
#
#  conv3_block3_out (Activati  (None, 28, 28, 512)          0         ['conv3_block3_add[0][0]']
#  on)
#
#  conv3_block4_1_conv (Conv2  (None, 28, 28, 128)          65664     ['conv3_block3_out[0][0]']
#  D)
#
#  conv3_block4_1_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block4_1_conv[0][0]']
#  rmalization)
#
#  conv3_block4_1_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block4_1_bn[0][0]']
#  ation)
#
#  conv3_block4_2_conv (Conv2  (None, 28, 28, 128)          147584    ['conv3_block4_1_relu[0][0]']
#  D)
#
#  conv3_block4_2_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block4_2_conv[0][0]']
#  rmalization)
#
#  conv3_block4_2_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block4_2_bn[0][0]']
#  ation)
#
#  conv3_block4_3_conv (Conv2  (None, 28, 28, 512)          66048     ['conv3_block4_2_relu[0][0]']
#  D)
#
#  conv3_block4_3_bn (BatchNo  (None, 28, 28, 512)          2048      ['conv3_block4_3_conv[0][0]']
#  rmalization)
#
#  conv3_block4_add (Add)      (None, 28, 28, 512)          0         ['conv3_block3_out[0][0]',
#                                                                      'conv3_block4_3_bn[0][0]']
#
#  conv3_block4_out (Activati  (None, 28, 28, 512)          0         ['conv3_block4_add[0][0]']
#  on)
#
#  conv4_block1_1_conv (Conv2  (None, 14, 14, 256)          131328    ['conv3_block4_out[0][0]']
#  D)
#
#  conv4_block1_1_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block1_1_conv[0][0]']
#  rmalization)
#
#  conv4_block1_1_relu (Activ  (None, 14, 14, 256)          0         ['conv4_block1_1_bn[0][0]']
#  ation)
#
#  conv4_block1_2_conv (Conv2  (None, 14, 14, 256)          590080    ['conv4_block1_1_relu[0][0]']
#  D)
#
#  conv4_block1_2_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block1_2_conv[0][0]']
#  rmalization)
#
#  conv4_block1_2_relu (Activ  (None, 14, 14, 256)          0         ['conv4_block1_2_bn[0][0]']
#  ation)
#
#  conv4_block1_0_conv (Conv2  (None, 14, 14, 1024)         525312    ['conv3_block4_out[0][0]']
#  D)
#
#  conv4_block1_3_conv (Conv2  (None, 14, 14, 1024)         263168    ['conv4_block1_2_relu[0][0]']
#  D)
#
#  conv4_block1_0_bn (BatchNo  (None, 14, 14, 1024)         4096      ['conv4_block1_0_conv[0][0]']
#  rmalization)
#
#  conv4_block1_3_bn (BatchNo  (None, 14, 14, 1024)         4096      ['conv4_block1_3_conv[0][0]']
#  rmalization)
#
#  conv4_block1_add (Add)      (None, 14, 14, 1024)         0         ['conv4_block1_0_bn[0][0]',
#                                                                      'conv4_block1_3_bn[0][0]']
#
#  conv4_block1_out (Activati  (None, 14, 14, 1024)         0         ['conv4_block1_add[0][0]']
#  on)
#
#  conv4_block2_1_conv (Conv2  (None, 14, 14, 256)          262400    ['conv4_block1_out[0][0]']
#  D)
#
#  conv4_block2_1_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block2_1_conv[0][0]']
#  rmalization)
#
#  conv4_block2_1_relu (Activ  (None, 14, 14, 256)          0         ['conv4_block2_1_bn[0][0]']
#  ation)
#
#  conv4_block2_2_conv (Conv2  (None, 14, 14, 256)          590080    ['conv4_block2_1_relu[0][0]']
#  D)
#
#  conv4_block2_2_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block2_2_conv[0][0]']
#  rmalization)
#
#  conv4_block2_2_relu (Activ  (None, 14, 14, 256)          0         ['conv4_block2_2_bn[0][0]']
#  ation)
#
#  conv4_block2_3_conv (Conv2  (None, 14, 14, 1024)         263168    ['conv4_block2_2_relu[0][0]']
#  D)
#
#  conv4_block2_3_bn (BatchNo  (None, 14, 14, 1024)         4096      ['conv4_block2_3_conv[0][0]']
#  rmalization)
#
#  conv4_block2_add (Add)      (None, 14, 14, 1024)         0         ['conv4_block1_out[0][0]',
#                                                                      'conv4_block2_3_bn[0][0]']
#
#  conv4_block2_out (Activati  (None, 14, 14, 1024)         0         ['conv4_block2_add[0][0]']
#  on)
#
#  conv4_block3_1_conv (Conv2  (None, 14, 14, 256)          262400    ['conv4_block2_out[0][0]']
#  D)
#
#  conv4_block3_1_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block3_1_conv[0][0]']
#  rmalization)
#
#  conv4_block3_1_relu (Activ  (None, 14, 14, 256)          0         ['conv4_block3_1_bn[0][0]']
#  ation)
#
#  conv4_block3_2_conv (Conv2  (None, 14, 14, 256)          590080    ['conv4_block3_1_relu[0][0]']
#  D)
#
#  conv4_block3_2_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block3_2_conv[0][0]']
#  rmalization)
#
#  conv4_block3_2_relu (Activ  (None, 14, 14, 256)          0         ['conv4_block3_2_bn[0][0]']
#  ation)
#
#  conv4_block3_3_conv (Conv2  (None, 14, 14, 1024)         263168    ['conv4_block3_2_relu[0][0]']
#  D)
#
#  conv4_block3_3_bn (BatchNo  (None, 14, 14, 1024)         4096      ['conv4_block3_3_conv[0][0]']
#  rmalization)
#
#  conv4_block3_add (Add)      (None, 14, 14, 1024)         0         ['conv4_block2_out[0][0]',
#                                                                      'conv4_block3_3_bn[0][0]']
#
#  conv4_block3_out (Activati  (None, 14, 14, 1024)         0         ['conv4_block3_add[0][0]']
#  on)
#
#  conv4_block4_1_conv (Conv2  (None, 14, 14, 256)          262400    ['conv4_block3_out[0][0]']
#  D)
#
#  conv4_block4_1_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block4_1_conv[0][0]']
#  rmalization)
#
#  conv4_block4_1_relu (Activ  (None, 14, 14, 256)          0         ['conv4_block4_1_bn[0][0]']
#  ation)
#
#  conv4_block4_2_conv (Conv2  (None, 14, 14, 256)          590080    ['conv4_block4_1_relu[0][0]']
#  D)
#
#  conv4_block4_2_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block4_2_conv[0][0]']
#  rmalization)
#
#  conv4_block4_2_relu (Activ  (None, 14, 14, 256)          0         ['conv4_block4_2_bn[0][0]']
#  ation)
#
#  conv4_block4_3_conv (Conv2  (None, 14, 14, 1024)         263168    ['conv4_block4_2_relu[0][0]']
#  D)
#
#  conv4_block4_3_bn (BatchNo  (None, 14, 14, 1024)         4096      ['conv4_block4_3_conv[0][0]']
#  rmalization)
#
#  conv4_block4_add (Add)      (None, 14, 14, 1024)         0         ['conv4_block3_out[0][0]',
#                                                                      'conv4_block4_3_bn[0][0]']
#
#  conv4_block4_out (Activati  (None, 14, 14, 1024)         0         ['conv4_block4_add[0][0]']
#  on)
#
#  conv4_block5_1_conv (Conv2  (None, 14, 14, 256)          262400    ['conv4_block4_out[0][0]']
#  D)
#
#  conv4_block5_1_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block5_1_conv[0][0]']
#  rmalization)
#
#  conv4_block5_1_relu (Activ  (None, 14, 14, 256)          0         ['conv4_block5_1_bn[0][0]']
#  ation)
#
#  conv4_block5_2_conv (Conv2  (None, 14, 14, 256)          590080    ['conv4_block5_1_relu[0][0]']
#  D)
#
#  conv4_block5_2_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block5_2_conv[0][0]']
#  rmalization)
#
#  conv4_block5_2_relu (Activ  (None, 14, 14, 256)          0         ['conv4_block5_2_bn[0][0]']
#  ation)
#
#  conv4_block5_3_conv (Conv2  (None, 14, 14, 1024)         263168    ['conv4_block5_2_relu[0][0]']
#  D)
#
#  conv4_block5_3_bn (BatchNo  (None, 14, 14, 1024)         4096      ['conv4_block5_3_conv[0][0]']
#  rmalization)
#
#  conv4_block5_add (Add)      (None, 14, 14, 1024)         0         ['conv4_block4_out[0][0]',
#                                                                      'conv4_block5_3_bn[0][0]']
#
#  conv4_block5_out (Activati  (None, 14, 14, 1024)         0         ['conv4_block5_add[0][0]']
#  on)
#
#  conv4_block6_1_conv (Conv2  (None, 14, 14, 256)          262400    ['conv4_block5_out[0][0]']
#  D)
#
#  conv4_block6_1_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block6_1_conv[0][0]']
#  rmalization)
#
#  conv4_block6_1_relu (Activ  (None, 14, 14, 256)          0         ['conv4_block6_1_bn[0][0]']
#  ation)
#
#  conv4_block6_2_conv (Conv2  (None, 14, 14, 256)          590080    ['conv4_block6_1_relu[0][0]']
#  D)
#
#  conv4_block6_2_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block6_2_conv[0][0]']
#  rmalization)
#
#  conv4_block6_2_relu (Activ  (None, 14, 14, 256)          0         ['conv4_block6_2_bn[0][0]']
#  ation)
#
#  conv4_block6_3_conv (Conv2  (None, 14, 14, 1024)         263168    ['conv4_block6_2_relu[0][0]']
#  D)
#
#  conv4_block6_3_bn (BatchNo  (None, 14, 14, 1024)         4096      ['conv4_block6_3_conv[0][0]']
#  rmalization)
#
#  conv4_block6_add (Add)      (None, 14, 14, 1024)         0         ['conv4_block5_out[0][0]',
#                                                                      'conv4_block6_3_bn[0][0]']
#
#  conv4_block6_out (Activati  (None, 14, 14, 1024)         0         ['conv4_block6_add[0][0]']
#  on)
#
#  conv5_block1_1_conv (Conv2  (None, 7, 7, 512)            524800    ['conv4_block6_out[0][0]']
#  D)
#
#  conv5_block1_1_bn (BatchNo  (None, 7, 7, 512)            2048      ['conv5_block1_1_conv[0][0]']
#  rmalization)
#
#  conv5_block1_1_relu (Activ  (None, 7, 7, 512)            0         ['conv5_block1_1_bn[0][0]']
#  ation)
#
#  conv5_block1_2_conv (Conv2  (None, 7, 7, 512)            2359808   ['conv5_block1_1_relu[0][0]']
#  D)
#
#  conv5_block1_2_bn (BatchNo  (None, 7, 7, 512)            2048      ['conv5_block1_2_conv[0][0]']
#  rmalization)
#
#  conv5_block1_2_relu (Activ  (None, 7, 7, 512)            0         ['conv5_block1_2_bn[0][0]']
#  ation)
#
#  conv5_block1_0_conv (Conv2  (None, 7, 7, 2048)           2099200   ['conv4_block6_out[0][0]']
#  D)
#
#  conv5_block1_3_conv (Conv2  (None, 7, 7, 2048)           1050624   ['conv5_block1_2_relu[0][0]']
#  D)
#
#  conv5_block1_0_bn (BatchNo  (None, 7, 7, 2048)           8192      ['conv5_block1_0_conv[0][0]']
#  rmalization)
#
#  conv5_block1_3_bn (BatchNo  (None, 7, 7, 2048)           8192      ['conv5_block1_3_conv[0][0]']
#  rmalization)
#
#  conv5_block1_add (Add)      (None, 7, 7, 2048)           0         ['conv5_block1_0_bn[0][0]',
#                                                                      'conv5_block1_3_bn[0][0]']
#
#  conv5_block1_out (Activati  (None, 7, 7, 2048)           0         ['conv5_block1_add[0][0]']
#  on)
#
#  conv5_block2_1_conv (Conv2  (None, 7, 7, 512)            1049088   ['conv5_block1_out[0][0]']
#  D)
#
#  conv5_block2_1_bn (BatchNo  (None, 7, 7, 512)            2048      ['conv5_block2_1_conv[0][0]']
#  rmalization)
#
#  conv5_block2_1_relu (Activ  (None, 7, 7, 512)            0         ['conv5_block2_1_bn[0][0]']
#  ation)
#
#  conv5_block2_2_conv (Conv2  (None, 7, 7, 512)            2359808   ['conv5_block2_1_relu[0][0]']
#  D)
#
#  conv5_block2_2_bn (BatchNo  (None, 7, 7, 512)            2048      ['conv5_block2_2_conv[0][0]']
#  rmalization)
#
#  conv5_block2_2_relu (Activ  (None, 7, 7, 512)            0         ['conv5_block2_2_bn[0][0]']
#  ation)
#
#  conv5_block2_3_conv (Conv2  (None, 7, 7, 2048)           1050624   ['conv5_block2_2_relu[0][0]']
#  D)
#
#  conv5_block2_3_bn (BatchNo  (None, 7, 7, 2048)           8192      ['conv5_block2_3_conv[0][0]']
#  rmalization)
#
#  conv5_block2_add (Add)      (None, 7, 7, 2048)           0         ['conv5_block1_out[0][0]',
#                                                                      'conv5_block2_3_bn[0][0]']
#
#  conv5_block2_out (Activati  (None, 7, 7, 2048)           0         ['conv5_block2_add[0][0]']
#  on)
#
#  conv5_block3_1_conv (Conv2  (None, 7, 7, 512)            1049088   ['conv5_block2_out[0][0]']
#  D)
#
#  conv5_block3_1_bn (BatchNo  (None, 7, 7, 512)            2048      ['conv5_block3_1_conv[0][0]']
#  rmalization)
#
#  conv5_block3_1_relu (Activ  (None, 7, 7, 512)            0         ['conv5_block3_1_bn[0][0]']
#  ation)
#
#  conv5_block3_2_conv (Conv2  (None, 7, 7, 512)            2359808   ['conv5_block3_1_relu[0][0]']
#  D)
#
#  conv5_block3_2_bn (BatchNo  (None, 7, 7, 512)            2048      ['conv5_block3_2_conv[0][0]']
#  rmalization)
#
#  conv5_block3_2_relu (Activ  (None, 7, 7, 512)            0         ['conv5_block3_2_bn[0][0]']
#  ation)
#
#  conv5_block3_3_conv (Conv2  (None, 7, 7, 2048)           1050624   ['conv5_block3_2_relu[0][0]']
#  D)
#
#  conv5_block3_3_bn (BatchNo  (None, 7, 7, 2048)           8192      ['conv5_block3_3_conv[0][0]']
#  rmalization)
#
#  conv5_block3_add (Add)      (None, 7, 7, 2048)           0         ['conv5_block2_out[0][0]',
#                                                                      'conv5_block3_3_bn[0][0]']
#
#  conv5_block3_out (Activati  (None, 7, 7, 2048)           0         ['conv5_block3_add[0][0]']
#  on)
#
#  avg_pool (GlobalAveragePoo  (None, 2048)                 0         ['conv5_block3_out[0][0]']
#  ling2D)
#
#  flatten_3 (Flatten)         (None, 2048)                 0         ['avg_pool[0][0]']
#
#  dense_13 (Dense)            (None, 512)                  1049088   ['flatten_3[0][0]']
#
#  dropout_10 (Dropout)        (None, 512)                  0         ['dense_13[0][0]']
#
#  dense_14 (Dense)            (None, 356)                  182628    ['dropout_10[0][0]']
#
#  dropout_11 (Dropout)        (None, 356)                  0         ['dense_14[0][0]']
#
#  dense_15 (Dense)            (None, 256)                  91392     ['dropout_11[0][0]']
#
#  dropout_12 (Dropout)        (None, 256)                  0         ['dense_15[0][0]']
#
#  dense_16 (Dense)            (None, 200)                  51400     ['dropout_12[0][0]']
#
#  dropout_13 (Dropout)        (None, 200)                  0         ['dense_16[0][0]']
#
#  dense_17 (Dense)            (None, 128)                  25728     ['dropout_13[0][0]']
#
#  dropout_14 (Dropout)        (None, 128)                  0         ['dense_17[0][0]']
#
#  dense_18 (Dense)            (None, 64)                   8256      ['dropout_14[0][0]']
#
#  dropout_15 (Dropout)        (None, 64)                   0         ['dense_18[0][0]']
#
#  dense_19 (Dense)            (None, 2)                    130       ['dropout_15[0][0]']
#
# ==================================================================================================
# Total params: 24996334 (95.35 MB)
# Trainable params: 1408622 (5.37 MB)
# Non-trainable params: 23587712 (89.98 MB)
# __________________________________________________________________________________________________

# %%
# Compile model
resnet_model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
              loss=tf.keras.losses.CategoricalCrossentropy(),
              metrics=[AUC(name='auc')]
              )

# Train model
resnet_model.fit(ds_train_sm_rn_r2,
          validation_data=ds_val_sm_rn_r2,
          epochs=200,
          callbacks=[tf.keras.callbacks.EarlyStopping(monitor='val_auc', patience=15),
                    #  tf.keras.callbacks.ModelCheckpoint(monitor='val_auc')
                     ]
          )
# Out:
# Epoch 1/200
# 53/53 [==============================] - 13s 126ms/step - loss: 14.3948 - auc: 0.4651 - val_loss: 13.3265 - val_auc: 0.7464
# Epoch 2/200
# 53/53 [==============================] - 7s 135ms/step - loss: 13.4583 - auc: 0.4995 - val_loss: 12.7619 - val_auc: 0.7743
# Epoch 3/200
# 53/53 [==============================] - 7s 132ms/step - loss: 12.7280 - auc: 0.5338 - val_loss: 12.2710 - val_auc: 0.7611
# Epoch 4/200
# 53/53 [==============================] - 5s 98ms/step - loss: 12.2644 - auc: 0.5050 - val_loss: 11.8151 - val_auc: 0.8319
# Epoch 5/200
# 53/53 [==============================] - 7s 128ms/step - loss: 11.8614 - auc: 0.4689 - val_loss: 11.4294 - val_auc: 0.8167
# Epoch 6/200
# 53/53 [==============================] - 5s 97ms/step - loss: 11.4074 - auc: 0.5130 - val_loss: 11.0562 - val_auc: 0.8242
# Epoch 7/200
# 53/53 [==============================] - 7s 140ms/step - loss: 10.9860 - auc: 0.5751 - val_loss: 10.7181 - val_auc: 0.8123
# Epoch 8/200
# 53/53 [==============================] - 5s 98ms/step - loss: 10.6466 - auc: 0.5705 - val_loss: 10.4068 - val_auc: 0.8083
# Epoch 9/200
# 53/53 [==============================] - 7s 130ms/step - loss: 10.3470 - auc: 0.5531 - val_loss: 10.1052 - val_auc: 0.8314
# Epoch 10/200
# 53/53 [==============================] - 5s 99ms/step - loss: 10.0210 - auc: 0.5656 - val_loss: 9.8224 - val_auc: 0.8360
# Epoch 11/200
# 53/53 [==============================] - 7s 142ms/step - loss: 9.7449 - auc: 0.5725 - val_loss: 9.5364 - val_auc: 0.8468
# Epoch 12/200
# 53/53 [==============================] - 5s 98ms/step - loss: 9.4341 - auc: 0.6245 - val_loss: 9.2571 - val_auc: 0.8582
# Epoch 13/200
# 53/53 [==============================] - 7s 133ms/step - loss: 9.1637 - auc: 0.6595 - val_loss: 8.9952 - val_auc: 0.8608
# Epoch 14/200
# 53/53 [==============================] - 5s 101ms/step - loss: 8.9304 - auc: 0.6384 - val_loss: 8.7383 - val_auc: 0.8808
# Epoch 15/200
# 53/53 [==============================] - 7s 127ms/step - loss: 8.7035 - auc: 0.6275 - val_loss: 8.4934 - val_auc: 0.8764
# Epoch 16/200
# 53/53 [==============================] - 5s 101ms/step - loss: 8.4749 - auc: 0.6381 - val_loss: 8.2491 - val_auc: 0.8713
# Epoch 17/200
# 53/53 [==============================] - 7s 131ms/step - loss: 8.2336 - auc: 0.6916 - val_loss: 8.0240 - val_auc: 0.8801
# Epoch 18/200
# 53/53 [==============================] - 6s 114ms/step - loss: 7.9617 - auc: 0.7582 - val_loss: 7.7936 - val_auc: 0.8816
# Epoch 19/200
# 53/53 [==============================] - 7s 129ms/step - loss: 7.7563 - auc: 0.7662 - val_loss: 7.5675 - val_auc: 0.8830
# Epoch 20/200
# 53/53 [==============================] - 6s 106ms/step - loss: 7.5242 - auc: 0.8013 - val_loss: 7.3532 - val_auc: 0.8903
# Epoch 21/200
# 53/53 [==============================] - 6s 119ms/step - loss: 7.3233 - auc: 0.8346 - val_loss: 7.1565 - val_auc: 0.9042
# Epoch 22/200
# 53/53 [==============================] - 6s 106ms/step - loss: 7.1175 - auc: 0.8475 - val_loss: 6.9530 - val_auc: 0.9098
# Epoch 23/200
# 53/53 [==============================] - 7s 131ms/step - loss: 6.9390 - auc: 0.8508 - val_loss: 6.7694 - val_auc: 0.9103
# Epoch 24/200
# 53/53 [==============================] - 6s 104ms/step - loss: 6.7349 - auc: 0.8879 - val_loss: 6.6043 - val_auc: 0.9090
# Epoch 25/200
# 53/53 [==============================] - 7s 134ms/step - loss: 6.5437 - auc: 0.9011 - val_loss: 6.4368 - val_auc: 0.9145
# Epoch 26/200
# 53/53 [==============================] - 6s 104ms/step - loss: 6.3838 - auc: 0.9053 - val_loss: 6.2859 - val_auc: 0.9138
# Epoch 27/200
# 53/53 [==============================] - 5s 99ms/step - loss: 6.1994 - auc: 0.9267 - val_loss: 6.1342 - val_auc: 0.9166
# Epoch 28/200
# 53/53 [==============================] - 7s 125ms/step - loss: 6.0094 - auc: 0.9431 - val_loss: 5.9977 - val_auc: 0.9217
# Epoch 29/200
# 53/53 [==============================] - 5s 103ms/step - loss: 5.9067 - auc: 0.9292 - val_loss: 5.8660 - val_auc: 0.9233
# Epoch 30/200
# 53/53 [==============================] - 8s 142ms/step - loss: 5.7485 - auc: 0.9389 - val_loss: 5.7299 - val_auc: 0.9226
# Epoch 31/200
# 53/53 [==============================] - 6s 104ms/step - loss: 5.5925 - auc: 0.9509 - val_loss: 5.6217 - val_auc: 0.9202
# Epoch 32/200
# 53/53 [==============================] - 6s 115ms/step - loss: 5.4438 - auc: 0.9525 - val_loss: 5.4988 - val_auc: 0.9162
# Epoch 33/200
# 53/53 [==============================] - 7s 134ms/step - loss: 5.2715 - auc: 0.9721 - val_loss: 5.3945 - val_auc: 0.9204
# Epoch 34/200
# 53/53 [==============================] - 5s 101ms/step - loss: 5.1667 - auc: 0.9650 - val_loss: 5.2789 - val_auc: 0.9213
# Epoch 35/200
# 53/53 [==============================] - 7s 130ms/step - loss: 5.0285 - auc: 0.9708 - val_loss: 5.1813 - val_auc: 0.9225
# Epoch 36/200
# 53/53 [==============================] - 5s 99ms/step - loss: 4.9083 - auc: 0.9755 - val_loss: 5.0763 - val_auc: 0.9234
# Epoch 37/200
# 53/53 [==============================] - 8s 143ms/step - loss: 4.7791 - auc: 0.9760 - val_loss: 4.9687 - val_auc: 0.9261
# Epoch 38/200
# 53/53 [==============================] - 5s 99ms/step - loss: 4.6838 - auc: 0.9733 - val_loss: 4.8585 - val_auc: 0.9216
# Epoch 39/200
# 53/53 [==============================] - 6s 112ms/step - loss: 4.5434 - auc: 0.9816 - val_loss: 4.7614 - val_auc: 0.9232
# Epoch 40/200
# 53/53 [==============================] - 6s 118ms/step - loss: 4.4421 - auc: 0.9811 - val_loss: 4.6708 - val_auc: 0.9254
# Epoch 41/200
# 53/53 [==============================] - 5s 102ms/step - loss: 4.3133 - auc: 0.9856 - val_loss: 4.6366 - val_auc: 0.9200
# Epoch 42/200
# 53/53 [==============================] - 7s 131ms/step - loss: 4.2246 - auc: 0.9836 - val_loss: 4.4982 - val_auc: 0.9263
# Epoch 43/200
# 53/53 [==============================] - 6s 105ms/step - loss: 4.1276 - auc: 0.9840 - val_loss: 4.4757 - val_auc: 0.9177
# Epoch 44/200
# 53/53 [==============================] - 7s 134ms/step - loss: 4.0248 - auc: 0.9866 - val_loss: 4.3193 - val_auc: 0.9186
# Epoch 45/200
# 53/53 [==============================] - 6s 109ms/step - loss: 3.8958 - auc: 0.9921 - val_loss: 4.2384 - val_auc: 0.9212
# Epoch 46/200
# 53/53 [==============================] - 6s 106ms/step - loss: 3.7885 - auc: 0.9949 - val_loss: 4.1760 - val_auc: 0.9189
# Epoch 47/200
# 53/53 [==============================] - 7s 127ms/step - loss: 3.7144 - auc: 0.9909 - val_loss: 4.0722 - val_auc: 0.9213
# Epoch 48/200
# 53/53 [==============================] - 5s 101ms/step - loss: 3.6324 - auc: 0.9914 - val_loss: 4.0209 - val_auc: 0.9257
# Epoch 49/200
# 53/53 [==============================] - 7s 130ms/step - loss: 3.5522 - auc: 0.9897 - val_loss: 3.9511 - val_auc: 0.9195
# Epoch 50/200
# 53/53 [==============================] - 5s 100ms/step - loss: 3.4497 - auc: 0.9942 - val_loss: 3.8757 - val_auc: 0.9187
# Epoch 51/200
# 53/53 [==============================] - 5s 99ms/step - loss: 3.3830 - auc: 0.9906 - val_loss: 3.7926 - val_auc: 0.9137
# Epoch 52/200
# 53/53 [==============================] - 5s 102ms/step - loss: 3.2964 - auc: 0.9923 - val_loss: 3.6739 - val_auc: 0.9186
# Epoch 53/200
# 53/53 [==============================] - 7s 126ms/step - loss: 3.1982 - auc: 0.9949 - val_loss: 3.6900 - val_auc: 0.9178
# Epoch 54/200
# 53/53 [==============================] - 6s 104ms/step - loss: 3.1213 - auc: 0.9941 - val_loss: 3.7265 - val_auc: 0.9145
# Epoch 55/200
# 53/53 [==============================] - 6s 105ms/step - loss: 3.0590 - auc: 0.9927 - val_loss: 3.5099 - val_auc: 0.9132
# Epoch 56/200
# 53/53 [==============================] - 5s 101ms/step - loss: 2.9742 - auc: 0.9954 - val_loss: 3.4437 - val_auc: 0.9174
# Epoch 57/200
# 53/53 [==============================] - 8s 145ms/step - loss: 2.9072 - auc: 0.9935 - val_loss: 3.3569 - val_auc: 0.9145

# %% [markdown]
# ####Performance

# %%
plot_acc_loss_graphs(resnet_model)

# %% [markdown]
# ####Evaluation

# %%
# !pwd
# Out:
# /content

# %%
##Evaluation
resnet_model.save('/content/drive/MyDrive/All mixed/cls/wsl/round2/resnet50_sm_wsl_r2_model_05.h5')
# Assuming 'model' is your TensorFlow model
# resnet_model.save("/content/drive/MyDrive/Research/models/resnet50_sm_wsl_model_03.h5")
#load the model:
saved_resnet_r2_model = tf.keras.models.load_model('/content/drive/MyDrive/All mixed/cls/wsl/round2/resnet50_sm_wsl_r2_model_05.h5');
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
y_pred_rn_r2 = saved_resnet_r2_model.predict(ds_test_sm_rn_r2, verbose=1)
print(f'y_pred_shape:{y_pred_rn_r2.shape} and shape[0] is: {y_pred_rn_r2.shape[0]}')
# Out:
# 1/1 [==============================] - 0s 495ms/step
# y_pred_shape:(70, 2) and shape[0] is: 70

# %%
plot_evaluation_graphs(y_pred_rn_r2, ds_test_sm_rn_r2)
# Out:
#               precision    recall  f1-score   support
#
#       benign       0.56      0.57      0.56        35
#    malignant       0.56      0.54      0.55        35
#
#    micro avg       0.56      0.56      0.56        70
#    macro avg       0.56      0.56      0.56        70
# weighted avg       0.56      0.56      0.56        70
#  samples avg       0.56      0.56      0.56        70

# %% [markdown]
# #VGG19

# %% [markdown]
# ##Setup for round 2

# %%
#setup for round 2
v19_train_dir_r2='/content/drive/MyDrive/All mixed/cls/wsl/round2/vgg19 train'
v19_val_dir_r2='/content/drive/MyDrive/All mixed/cls/wsl/round1/val'
v19_test_dir_r2='/content/drive/MyDrive/All mixed/cls/wsl/round2/test'

# %%
y_pred_v19.shape
# Out:
# (262, 2)

# %% [markdown]
# ### Separate Predictions

# %%
v19_df_results = get_dataframe_results(y_pred_v19, saved_vgg19_model, ds_test_sm_v19)
# Out:
# 1/1 [==============================] - 3s 3s/step

# %%
v19_df_results.Predicted_Class.value_counts()
# Out:
# Predicted_Class
# 0    131
# 1    131
# Name: count, dtype: int64

# %%
#separate predictions into folder for training
v19_folder_b = '/content/drive/MyDrive/All mixed/cls/wsl/round2/vgg19 train/benign'
v19_folder_m = '/content/drive/MyDrive/All mixed/cls/wsl/round2/vgg19 train/malignant'

move_predicted_images_into_folders(v19_folder_b, v19_folder_m, v19_df_results)
# Out:
# Images moved successfully.

# %%
#mix with original test data
src='/content/drive/MyDrive/All mixed/cls/wsl/round1/train/benign'
dst = '/content/drive/MyDrive/All mixed/cls/wsl/round2/vgg19 train/benign'
copy_jpg_images(src, dst)
# Out:
# Images copied successfully.

# %%
#mix with original test data
src='/content/drive/MyDrive/All mixed/cls/wsl/round1/train/malignant'
dst = '/content/drive/MyDrive/All mixed/cls/wsl/round2/vgg19 train/malignant'
copy_jpg_images(src, dst)
# Out:
# Images copied successfully.

# %%
count_images(v19_train_dir_r2)
count_images(v19_val_dir_r2)
count_images(v19_test_dir_r2)
# Out:
# 261 files in subdirectory benign.
# 261 files in subdirectory malignant.
# Total: 522 files.
# 67 files in subdirectory malignant.
# 67 files in subdirectory benign.
# Total: 134 files.
# 35 files in subdirectory benign.
# 35 files in subdirectory malignant.
# Total: 70 files.

# %% [markdown]
# ##Smaller Generators - TAKEN

# %% [markdown]
# ###Create and preprocess datasets

# %%
# def preprocess_v19(images, labels):
#   return tf.keras.applications.vgg19.preprocess_input(images), labels

# %%
# ds_train_v19, ds_val_v19, ds_test_v19 = get_image_dataset_arrays(batch_size_p=64, img_size_p=224)
ds_train_sm_v19_r2, ds_val_sm_v19_r2 = generators_train_val((224,224), tf.keras.applications.vgg19.preprocess_input, v19_train_dir_r2, v19_val_dir_r2, 8)
ds_test_sm_v19_r2 = generator_test((224,224), tf.keras.applications.vgg19.preprocess_input, v19_test_dir_r2, 70)
# Out:
# Found 522 images belonging to 2 classes.
# Found 134 images belonging to 2 classes.
# Found 70 images belonging to 2 classes.

# %% [markdown]
# ###Train, compile and fit model

# %%
pre_trained_model_v19 = Sequential();
pre_trained_model_v19 = tf.keras.applications.VGG19(input_shape=(224,224, 3),  ##
                             include_top = False,
                             weights = 'imagenet',
                             pooling='avg',
                             classes=2
                             )

# Freeze layers
for layer in pre_trained_model_v19.layers: ##
  layer.trainable = False

x = pre_trained_model_v19.output
x = layers.Flatten()(x)
x = layers.Dense(512, activation='relu', kernel_regularizer=regularizers.l2(0.01))(x)
x = layers.Dropout(0.5)(x)
x = layers.Dense(256, activation='relu', kernel_regularizer=regularizers.l2(0.01))(x)
x = layers.Dropout(0.5)(x)
x = layers.Dense(64, activation='relu', kernel_regularizer=regularizers.l2(0.01))(x)
x = layers.Dropout(0.5)(x)
output = layers.Dense(class_count, activation='softmax')(x)

#vgg19 model
vgg19_model = Model(pre_trained_model_v19.input, output) ##

# %%
# Compile model
vgg19_model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
              loss=tf.keras.losses.CategoricalCrossentropy(),
              metrics=[AUC(name='auc')]
              )

# Train model
vgg19_model.fit(ds_train_sm_v19, ##
          validation_data=ds_val_sm_v19, ##
          epochs=200,
          # class_weight=class_weights,
          callbacks=[tf.keras.callbacks.EarlyStopping(monitor='val_auc', patience=15),
                    #  tf.keras.callbacks.ModelCheckpoint('models/vgg19_ai_{val_auc:.3f}.h5',
                    #                                     save_best_only=True,
                    #                                     save_weights_only=False,
                    #                                     monitor='val_auc')
                     ]
          )
# Out:
# Epoch 1/200
# 33/33 [==============================] - 7s 112ms/step - loss: 11.3661 - auc: 0.5320 - val_loss: 9.8039 - val_auc: 0.7963
# Epoch 2/200
# 33/33 [==============================] - 3s 103ms/step - loss: 10.9247 - auc: 0.5781 - val_loss: 9.5805 - val_auc: 0.8264
# Epoch 3/200
# 33/33 [==============================] - 3s 93ms/step - loss: 9.9011 - auc: 0.7293 - val_loss: 9.4149 - val_auc: 0.8432
# Epoch 4/200
# 33/33 [==============================] - 3s 93ms/step - loss: 9.9206 - auc: 0.6715 - val_loss: 9.2384 - val_auc: 0.8482
# Epoch 5/200
# 33/33 [==============================] - 3s 105ms/step - loss: 9.6300 - auc: 0.7061 - val_loss: 9.0508 - val_auc: 0.8477
# Epoch 6/200
# 33/33 [==============================] - 3s 93ms/step - loss: 9.4634 - auc: 0.7056 - val_loss: 8.8959 - val_auc: 0.8531
# Epoch 7/200
# 33/33 [==============================] - 3s 93ms/step - loss: 9.1709 - auc: 0.7449 - val_loss: 8.7465 - val_auc: 0.8590
# Epoch 8/200
# 33/33 [==============================] - 3s 101ms/step - loss: 9.0653 - auc: 0.7446 - val_loss: 8.6126 - val_auc: 0.8653
# Epoch 9/200
# 33/33 [==============================] - 4s 111ms/step - loss: 8.8603 - auc: 0.7680 - val_loss: 8.4738 - val_auc: 0.8728
# Epoch 10/200
# 33/33 [==============================] - 3s 94ms/step - loss: 8.7369 - auc: 0.7859 - val_loss: 8.3508 - val_auc: 0.8730
# Epoch 11/200
# 33/33 [==============================] - 3s 95ms/step - loss: 8.5381 - auc: 0.7890 - val_loss: 8.2347 - val_auc: 0.8775
# Epoch 12/200
# 33/33 [==============================] - 3s 94ms/step - loss: 8.3437 - auc: 0.8206 - val_loss: 8.1245 - val_auc: 0.8811
# Epoch 13/200
# 33/33 [==============================] - 4s 111ms/step - loss: 8.2673 - auc: 0.8145 - val_loss: 8.0198 - val_auc: 0.8835
# Epoch 14/200
# 33/33 [==============================] - 3s 94ms/step - loss: 8.1154 - auc: 0.8209 - val_loss: 7.9212 - val_auc: 0.8852
# Epoch 15/200
# 33/33 [==============================] - 3s 95ms/step - loss: 8.0434 - auc: 0.8273 - val_loss: 7.8197 - val_auc: 0.8914
# Epoch 16/200
# 33/33 [==============================] - 3s 101ms/step - loss: 7.9613 - auc: 0.8098 - val_loss: 7.7238 - val_auc: 0.8962
# Epoch 17/200
# 33/33 [==============================] - 3s 95ms/step - loss: 7.7829 - auc: 0.8432 - val_loss: 7.6272 - val_auc: 0.9012
# Epoch 18/200
# 33/33 [==============================] - 3s 94ms/step - loss: 7.6659 - auc: 0.8522 - val_loss: 7.5273 - val_auc: 0.9011
# Epoch 19/200
# 33/33 [==============================] - 3s 94ms/step - loss: 7.5907 - auc: 0.8444 - val_loss: 7.4316 - val_auc: 0.9093
# Epoch 20/200
# 33/33 [==============================] - 3s 101ms/step - loss: 7.4525 - auc: 0.8628 - val_loss: 7.3368 - val_auc: 0.9046
# Epoch 21/200
# 33/33 [==============================] - 3s 93ms/step - loss: 7.3867 - auc: 0.8624 - val_loss: 7.2466 - val_auc: 0.9107
# Epoch 22/200
# 33/33 [==============================] - 3s 93ms/step - loss: 7.2962 - auc: 0.8553 - val_loss: 7.1613 - val_auc: 0.9113
# Epoch 23/200
# 33/33 [==============================] - 4s 111ms/step - loss: 7.2016 - auc: 0.8653 - val_loss: 7.0773 - val_auc: 0.9096
# Epoch 24/200
# 33/33 [==============================] - 3s 94ms/step - loss: 7.1088 - auc: 0.8720 - val_loss: 6.9902 - val_auc: 0.9137
# Epoch 25/200
# 33/33 [==============================] - 3s 94ms/step - loss: 7.0258 - auc: 0.8628 - val_loss: 6.9039 - val_auc: 0.9112
# Epoch 26/200
# 33/33 [==============================] - 5s 142ms/step - loss: 6.8938 - auc: 0.8951 - val_loss: 6.8265 - val_auc: 0.9138
# Epoch 27/200
# 33/33 [==============================] - 4s 112ms/step - loss: 6.8116 - auc: 0.8975 - val_loss: 6.7434 - val_auc: 0.9153
# Epoch 28/200
# 33/33 [==============================] - 4s 110ms/step - loss: 6.7839 - auc: 0.8774 - val_loss: 6.6649 - val_auc: 0.9177
# Epoch 29/200
# 33/33 [==============================] - 3s 93ms/step - loss: 6.6680 - auc: 0.8998 - val_loss: 6.5889 - val_auc: 0.9209
# Epoch 30/200
# 33/33 [==============================] - 4s 110ms/step - loss: 6.5984 - auc: 0.9007 - val_loss: 6.5153 - val_auc: 0.9242
# Epoch 31/200
# 33/33 [==============================] - 3s 95ms/step - loss: 6.4845 - auc: 0.9159 - val_loss: 6.4406 - val_auc: 0.9216
# Epoch 32/200
# 33/33 [==============================] - 3s 94ms/step - loss: 6.4171 - auc: 0.9166 - val_loss: 6.3714 - val_auc: 0.9204
# Epoch 33/200
# 33/33 [==============================] - 3s 101ms/step - loss: 6.4150 - auc: 0.8861 - val_loss: 6.3012 - val_auc: 0.9211
# Epoch 34/200
# 33/33 [==============================] - 3s 97ms/step - loss: 6.3148 - auc: 0.9067 - val_loss: 6.2325 - val_auc: 0.9179
# Epoch 35/200
# 33/33 [==============================] - 3s 94ms/step - loss: 6.1683 - auc: 0.9388 - val_loss: 6.1610 - val_auc: 0.9208
# Epoch 36/200
# 33/33 [==============================] - 5s 151ms/step - loss: 6.1481 - auc: 0.9184 - val_loss: 6.0909 - val_auc: 0.9216
# Epoch 37/200
# 33/33 [==============================] - 5s 135ms/step - loss: 6.0814 - auc: 0.9209 - val_loss: 6.0253 - val_auc: 0.9214
# Epoch 38/200
# 33/33 [==============================] - 3s 94ms/step - loss: 5.9742 - auc: 0.9411 - val_loss: 5.9564 - val_auc: 0.9237
# Epoch 39/200
# 33/33 [==============================] - 3s 94ms/step - loss: 5.8910 - auc: 0.9405 - val_loss: 5.8923 - val_auc: 0.9226
# Epoch 40/200
# 33/33 [==============================] - 3s 105ms/step - loss: 5.8390 - auc: 0.9383 - val_loss: 5.8384 - val_auc: 0.9199
# Epoch 41/200
# 33/33 [==============================] - 3s 104ms/step - loss: 5.7716 - auc: 0.9424 - val_loss: 5.7658 - val_auc: 0.9240
# Epoch 42/200
# 33/33 [==============================] - 3s 94ms/step - loss: 5.7037 - auc: 0.9437 - val_loss: 5.7036 - val_auc: 0.9237
# Epoch 43/200
# 33/33 [==============================] - 3s 95ms/step - loss: 5.6084 - auc: 0.9552 - val_loss: 5.6409 - val_auc: 0.9269
# Epoch 44/200
# 33/33 [==============================] - 5s 154ms/step - loss: 5.5604 - auc: 0.9527 - val_loss: 5.5964 - val_auc: 0.9242
# Epoch 45/200
# 33/33 [==============================] - 3s 94ms/step - loss: 5.5373 - auc: 0.9371 - val_loss: 5.5415 - val_auc: 0.9251
# Epoch 46/200
# 33/33 [==============================] - 3s 94ms/step - loss: 5.4495 - auc: 0.9489 - val_loss: 5.4703 - val_auc: 0.9290
# Epoch 47/200
# 33/33 [==============================] - 4s 106ms/step - loss: 5.3845 - auc: 0.9530 - val_loss: 5.4198 - val_auc: 0.9246
# Epoch 48/200
# 33/33 [==============================] - 3s 100ms/step - loss: 5.2868 - auc: 0.9655 - val_loss: 5.3595 - val_auc: 0.9275
# Epoch 49/200
# 33/33 [==============================] - 3s 93ms/step - loss: 5.3040 - auc: 0.9383 - val_loss: 5.3063 - val_auc: 0.9255
# Epoch 50/200
# 33/33 [==============================] - 3s 94ms/step - loss: 5.1725 - auc: 0.9661 - val_loss: 5.2476 - val_auc: 0.9280
# Epoch 51/200
# 33/33 [==============================] - 3s 100ms/step - loss: 5.1476 - auc: 0.9593 - val_loss: 5.1944 - val_auc: 0.9287
# Epoch 52/200
# 33/33 [==============================] - 4s 106ms/step - loss: 5.0893 - auc: 0.9575 - val_loss: 5.1378 - val_auc: 0.9296
# Epoch 53/200
# 33/33 [==============================] - 3s 94ms/step - loss: 5.0209 - auc: 0.9633 - val_loss: 5.0868 - val_auc: 0.9291
# Epoch 54/200
# 33/33 [==============================] - 3s 95ms/step - loss: 4.9492 - auc: 0.9675 - val_loss: 5.0270 - val_auc: 0.9313
# Epoch 55/200
# 33/33 [==============================] - 4s 137ms/step - loss: 4.9318 - auc: 0.9556 - val_loss: 4.9788 - val_auc: 0.9313
# Epoch 56/200
# 33/33 [==============================] - 3s 95ms/step - loss: 4.8538 - auc: 0.9655 - val_loss: 4.9249 - val_auc: 0.9313
# Epoch 57/200
# 33/33 [==============================] - 3s 94ms/step - loss: 4.8004 - auc: 0.9649 - val_loss: 4.8702 - val_auc: 0.9332
# Epoch 58/200
# 33/33 [==============================] - 3s 95ms/step - loss: 4.7075 - auc: 0.9777 - val_loss: 4.8175 - val_auc: 0.9337
# Epoch 59/200
# 33/33 [==============================] - 3s 103ms/step - loss: 4.6769 - auc: 0.9718 - val_loss: 4.7708 - val_auc: 0.9319
# Epoch 60/200
# 33/33 [==============================] - 3s 103ms/step - loss: 4.6219 - auc: 0.9740 - val_loss: 4.7235 - val_auc: 0.9289
# Epoch 61/200
# 33/33 [==============================] - 3s 96ms/step - loss: 4.5769 - auc: 0.9719 - val_loss: 4.6805 - val_auc: 0.9289
# Epoch 62/200
# 33/33 [==============================] - 3s 95ms/step - loss: 4.5360 - auc: 0.9700 - val_loss: 4.6311 - val_auc: 0.9313
# Epoch 63/200
# 33/33 [==============================] - 3s 101ms/step - loss: 4.4511 - auc: 0.9797 - val_loss: 4.5771 - val_auc: 0.9332
# Epoch 64/200
# 33/33 [==============================] - 4s 106ms/step - loss: 4.4252 - auc: 0.9733 - val_loss: 4.5415 - val_auc: 0.9292
# Epoch 65/200
# 33/33 [==============================] - 3s 94ms/step - loss: 4.3814 - auc: 0.9712 - val_loss: 4.4871 - val_auc: 0.9314
# Epoch 66/200
# 33/33 [==============================] - 3s 99ms/step - loss: 4.3183 - auc: 0.9769 - val_loss: 4.4380 - val_auc: 0.9323
# Epoch 67/200
# 33/33 [==============================] - 3s 95ms/step - loss: 4.2752 - auc: 0.9756 - val_loss: 4.3832 - val_auc: 0.9332
# Epoch 68/200
# 33/33 [==============================] - 3s 95ms/step - loss: 4.1947 - auc: 0.9850 - val_loss: 4.3357 - val_auc: 0.9356
# Epoch 69/200
# 33/33 [==============================] - 3s 95ms/step - loss: 4.1392 - auc: 0.9872 - val_loss: 4.3018 - val_auc: 0.9359
# Epoch 70/200
# 33/33 [==============================] - 4s 113ms/step - loss: 4.0912 - auc: 0.9872 - val_loss: 4.2623 - val_auc: 0.9368
# Epoch 71/200
# 33/33 [==============================] - 3s 98ms/step - loss: 4.0689 - auc: 0.9812 - val_loss: 4.2300 - val_auc: 0.9331
# Epoch 72/200
# 33/33 [==============================] - 3s 94ms/step - loss: 3.9804 - auc: 0.9901 - val_loss: 4.1893 - val_auc: 0.9355
# Epoch 73/200
# 33/33 [==============================] - 3s 94ms/step - loss: 3.9825 - auc: 0.9801 - val_loss: 4.1429 - val_auc: 0.9365
# Epoch 74/200
# 33/33 [==============================] - 3s 100ms/step - loss: 3.8840 - auc: 0.9924 - val_loss: 4.0953 - val_auc: 0.9384
# Epoch 75/200
# 33/33 [==============================] - 4s 105ms/step - loss: 3.8789 - auc: 0.9836 - val_loss: 4.0693 - val_auc: 0.9361
# Epoch 76/200
# 33/33 [==============================] - 3s 95ms/step - loss: 3.8125 - auc: 0.9883 - val_loss: 4.0104 - val_auc: 0.9392
# Epoch 77/200
# 33/33 [==============================] - 3s 94ms/step - loss: 3.7525 - auc: 0.9912 - val_loss: 3.9760 - val_auc: 0.9384
# Epoch 78/200
# 33/33 [==============================] - 4s 110ms/step - loss: 3.7170 - auc: 0.9908 - val_loss: 3.9390 - val_auc: 0.9382
# Epoch 79/200
# 33/33 [==============================] - 3s 96ms/step - loss: 3.7052 - auc: 0.9848 - val_loss: 3.8990 - val_auc: 0.9370
# Epoch 80/200
# 33/33 [==============================] - 3s 94ms/step - loss: 3.6168 - auc: 0.9932 - val_loss: 3.8657 - val_auc: 0.9355
# Epoch 81/200
# 33/33 [==============================] - 3s 101ms/step - loss: 3.5691 - auc: 0.9936 - val_loss: 3.8337 - val_auc: 0.9360
# Epoch 82/200
# 33/33 [==============================] - 4s 108ms/step - loss: 3.5613 - auc: 0.9886 - val_loss: 3.7891 - val_auc: 0.9378
# Epoch 83/200
# 33/33 [==============================] - 3s 94ms/step - loss: 3.5445 - auc: 0.9823 - val_loss: 3.7344 - val_auc: 0.9372
# Epoch 84/200
# 33/33 [==============================] - 4s 109ms/step - loss: 3.4716 - auc: 0.9897 - val_loss: 3.7155 - val_auc: 0.9329
# Epoch 85/200
# 33/33 [==============================] - 5s 151ms/step - loss: 3.4236 - auc: 0.9919 - val_loss: 3.6702 - val_auc: 0.9340
# Epoch 86/200
# 33/33 [==============================] - 3s 101ms/step - loss: 3.3860 - auc: 0.9913 - val_loss: 3.6304 - val_auc: 0.9350
# Epoch 87/200
# 33/33 [==============================] - 3s 93ms/step - loss: 3.3209 - auc: 0.9962 - val_loss: 3.6051 - val_auc: 0.9357
# Epoch 88/200
# 33/33 [==============================] - 3s 93ms/step - loss: 3.2970 - auc: 0.9929 - val_loss: 3.5694 - val_auc: 0.9372
# Epoch 89/200
# 33/33 [==============================] - 4s 112ms/step - loss: 3.2411 - auc: 0.9945 - val_loss: 3.5281 - val_auc: 0.9373
# Epoch 90/200
# 33/33 [==============================] - 3s 98ms/step - loss: 3.1955 - auc: 0.9963 - val_loss: 3.5072 - val_auc: 0.9369
# Epoch 91/200
# 33/33 [==============================] - 3s 94ms/step - loss: 3.1584 - auc: 0.9958 - val_loss: 3.4790 - val_auc: 0.9365

# %% [markdown]
# ###Performance

# %%
plot_acc_loss_graphs(vgg19_model)

# %% [markdown]
# ### Evaluation

# %%
#save model
vgg19_model.save('/content/drive/MyDrive/All mixed/cls/wsl/round2/vgg19_model_sm_wsl_r2_01.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
#load saved model:
saved_vgg19_r2_model = tf.keras.models.load_model('/content/drive/MyDrive/All mixed/cls/wsl/round2/vgg19_model_sm_wsl_r2_01.h5');

# %%
#predict
y_pred_v19_r2 = saved_vgg19_r2_model.predict(ds_test_sm_v19_r2, verbose=1)
print(f'y_pred_shape:{y_pred_v19_r2.shape} and shape[0] is: {y_pred_v19_r2.shape[0]}')
# Out:
# 1/1 [==============================] - 1s 547ms/step
# y_pred_shape:(70, 2) and shape[0] is: 70

# %%
plot_evaluation_graphs(y_pred_v19_r2, ds_test_sm_v19_r2)
# Out:
#               precision    recall  f1-score   support
#
#       benign       0.51      0.71      0.60        35
#    malignant       0.52      0.31      0.39        35
#
#    micro avg       0.51      0.51      0.51        70
#    macro avg       0.52      0.51      0.49        70
# weighted avg       0.52      0.51      0.49        70
#  samples avg       0.51      0.51      0.51        70

# %% [markdown]
# #MobileNet

# %% [markdown]
# ##Setup for round 2

# %%
#setup for round 2
mn_train_dir_r2='/content/drive/MyDrive/All mixed/cls/wsl/round2/mobileNet train'
mn_val_dir_r2='/content/drive/MyDrive/All mixed/cls/wsl/round2/val'
mn_test_dir_r2='/content/drive/MyDrive/All mixed/cls/wsl/round2/test'

# %%
y_pred_mn.shape
# Out:
# (262, 2)

# %% [markdown]
# ### Separate Predictions

# %%
mn_df_results = get_dataframe_results(y_pred_mn, saved_mobileNet_model, ds_test_sm_mn)
# Out:
# 1/1 [==============================] - 1s 1s/step

# %%
mn_df_results.Predicted_Class.value_counts()
# Out:
# Predicted_Class
# 0    138
# 1    124
# Name: count, dtype: int64

# %%
#separate predictions into folder for training
mn_folder_b = '/content/drive/MyDrive/All mixed/cls/wsl/round2/mobileNet train/benign'
mn_folder_m = '/content/drive/MyDrive/All mixed/cls/wsl/round2/mobileNet train/malignant'

move_predicted_images_into_folders(mn_folder_b, mn_folder_m, mn_df_results)
# Out:
# Images moved successfully.

# %%
#mix with original test data
src='/content/drive/MyDrive/All mixed/cls/wsl/round1/train/malignant'
dst = '/content/drive/MyDrive/All mixed/cls/wsl/round2/mobileNet train/malignant'
copy_jpg_images(src, dst)
# Out:
# Images copied successfully.

# %%
#mix with original test data
src='/content/drive/MyDrive/All mixed/cls/wsl/round1/train/benign'
dst = '/content/drive/MyDrive/All mixed/cls/wsl/round2/mobileNet train/benign'
copy_jpg_images(src, dst)
# Out:
# Images copied successfully.

# %%
count_images(mn_train_dir_r2)
count_images(mn_val_dir_r2)
count_images(mn_test_dir_r2)
# Out:
# 268 files in subdirectory benign.
# 254 files in subdirectory malignant.
# Total: 522 files.
# 67 files in subdirectory malignant.
# 67 files in subdirectory benign.
# Total: 134 files.
# 35 files in subdirectory benign.
# 35 files in subdirectory malignant.
# Total: 70 files.

# %% [markdown]
# ##Smaller Generators -TAKEN

# %% [markdown]
# ###Create and preprocess datasets

# %%
# def preprocess_mn(images, labels):
#   return tf.keras.applications.mobilenet.preprocess_input(images), labels

# %%
ds_train_sm_mn_r2, ds_val_sm_mn_r2 = generators_train_val((224,224), tf.keras.applications.mobilenet.preprocess_input, mn_train_dir_r2, mn_val_dir_r2, 8)
ds_test_sm_mn_r2 = generator_test((224,224), tf.keras.applications.mobilenet.preprocess_input, mn_test_dir_r2, 262)
# Out:
# Found 522 images belonging to 2 classes.
# Found 134 images belonging to 2 classes.
# Found 70 images belonging to 2 classes.

# %% [markdown]
# ###Train

# %%
from tensorflow.keras import regularizers
pre_trained_model_mn= Sequential();

pre_trained_model_mn = tf.keras.applications.MobileNet(input_shape=(224,224, 3),  ##
                             include_top = False,
                             weights = 'imagenet',
                             pooling='avg',
                             classes=2
                             )

# Freeze layers
for layer in pre_trained_model_mn.layers: ##
  layer.trainable = False
x = pre_trained_model_mn.output
x = layers.Flatten()(x)
x = layers.Dense(512, activation='relu', kernel_regularizer=regularizers.l2(0.01))(x)
x = layers.Dropout(0.5)(x)
x = layers.Dense(128, activation='relu', kernel_regularizer=regularizers.l2(0.01))(x)
x = layers.Dropout(0.5)(x)
x = layers.Dense(64, activation='relu', kernel_regularizer=regularizers.l2(0.01))(x)
x = layers.Dropout(0.5)(x)
output = layers.Dense(class_count, activation='softmax')(x)

#mobile model
mobileNet_model = Model(pre_trained_model_mn.input, output) ##

# %%
# Compile model
mobileNet_model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
              loss=tf.keras.losses.CategoricalCrossentropy(),
              metrics=[AUC(name='auc')]
              )

# Train model
mobileNet_model.fit(ds_train_sm_mn, ##
          validation_data=ds_val_sm_mn, ##
          epochs=200,
          # callbacks=callback_params,
          # class_weight=class_weights,
          callbacks=[tf.keras.callbacks.EarlyStopping(monitor='val_auc', patience=15),
                    #  tf.keras.callbacks.ModelCheckpoint('models/mobileNet_ai_{val_auc:.3f}.h5',
                    #                                     save_best_only=True,
                    #                                     save_weights_only=False,
                    #                                     monitor='val_auc')
                     ]
          )
# Out:
# Epoch 1/200
# 26/26 [==============================] - 6s 111ms/step - loss: 8.9699 - auc: 0.5745 - val_loss: 6.9257 - val_auc: 0.8841
# Epoch 2/200
# 26/26 [==============================] - 2s 90ms/step - loss: 6.4070 - auc: 0.6769 - val_loss: 5.3850 - val_auc: 0.9122
# Epoch 3/200
# 26/26 [==============================] - 3s 125ms/step - loss: 4.9776 - auc: 0.8187 - val_loss: 4.4083 - val_auc: 0.9164
# Epoch 4/200
# 26/26 [==============================] - 2s 96ms/step - loss: 4.1563 - auc: 0.8675 - val_loss: 3.7863 - val_auc: 0.9307
# Epoch 5/200
# 26/26 [==============================] - 2s 86ms/step - loss: 3.5511 - auc: 0.8982 - val_loss: 3.2551 - val_auc: 0.9270
# Epoch 6/200
# 26/26 [==============================] - 2s 87ms/step - loss: 3.1069 - auc: 0.9137 - val_loss: 2.9045 - val_auc: 0.9218
# Epoch 7/200
# 26/26 [==============================] - 2s 86ms/step - loss: 2.7315 - auc: 0.9259 - val_loss: 2.5648 - val_auc: 0.9322
# Epoch 8/200
# 26/26 [==============================] - 3s 101ms/step - loss: 2.4709 - auc: 0.9201 - val_loss: 2.3225 - val_auc: 0.9314
# Epoch 9/200
# 26/26 [==============================] - 2s 88ms/step - loss: 2.2163 - auc: 0.9331 - val_loss: 2.1293 - val_auc: 0.9246
# Epoch 10/200
# 26/26 [==============================] - 2s 89ms/step - loss: 2.0165 - auc: 0.9415 - val_loss: 1.9843 - val_auc: 0.9243
# Epoch 11/200
# 26/26 [==============================] - 2s 88ms/step - loss: 1.8244 - auc: 0.9518 - val_loss: 1.8229 - val_auc: 0.9294
# Epoch 12/200
# 26/26 [==============================] - 2s 93ms/step - loss: 1.6906 - auc: 0.9513 - val_loss: 1.7228 - val_auc: 0.9243
# Epoch 13/200
# 26/26 [==============================] - 3s 120ms/step - loss: 1.5384 - auc: 0.9624 - val_loss: 1.6225 - val_auc: 0.9274
# Epoch 14/200
# 26/26 [==============================] - 2s 88ms/step - loss: 1.4473 - auc: 0.9594 - val_loss: 1.5357 - val_auc: 0.9192
# Epoch 15/200
# 26/26 [==============================] - 2s 86ms/step - loss: 1.2771 - auc: 0.9832 - val_loss: 1.4471 - val_auc: 0.9319
# Epoch 16/200
# 26/26 [==============================] - 2s 87ms/step - loss: 1.2009 - auc: 0.9791 - val_loss: 1.3897 - val_auc: 0.9288
# Epoch 17/200
# 26/26 [==============================] - 3s 110ms/step - loss: 1.0791 - auc: 0.9880 - val_loss: 1.3281 - val_auc: 0.9314
# Epoch 18/200
# 26/26 [==============================] - 3s 108ms/step - loss: 0.9949 - auc: 0.9911 - val_loss: 1.2806 - val_auc: 0.9265
# Epoch 19/200
# 26/26 [==============================] - 2s 94ms/step - loss: 0.9756 - auc: 0.9827 - val_loss: 1.2489 - val_auc: 0.9263
# Epoch 20/200
# 26/26 [==============================] - 2s 89ms/step - loss: 0.9371 - auc: 0.9827 - val_loss: 1.1768 - val_auc: 0.9259
# Epoch 21/200
# 26/26 [==============================] - 2s 87ms/step - loss: 0.9488 - auc: 0.9729 - val_loss: 1.1251 - val_auc: 0.9236
# Epoch 22/200
# 26/26 [==============================] - 2s 89ms/step - loss: 0.8393 - auc: 0.9894 - val_loss: 1.3651 - val_auc: 0.8908

# %%
##save model
# resnet_model.save('/content/drive/MyDrive/Research/models/resnet_model_ai.h5')
# Assuming 'model' is your TensorFlow model
mobileNet_model.save("/content/drive/MyDrive/All mixed/cls/wsl/round2/mobileNet train/mobileNet_model_sm_wsl_r2_03.h5")
#load the model:
# saved_resnet_model = tf.keras.models.load_model('/content/drive/MyDrive/Research/models/resnet_model_ai.h5');

# %% [markdown]
# ###Performance

# %%
plot_acc_loss_graphs(mobileNet_model)

# %% [markdown]
# ### Evaluation

# %%
#save model
# mobileNet_model.save('/content/drive/MyDrive/Research/models/mobileNet_model_03.h5')

# %%
#load saved model:
saved_mobileNet_model = tf.keras.models.load_model("/content/drive/MyDrive/All mixed/cls/wsl/round2/mobileNet train/mobileNet_model_sm_wsl_r2_03.h5");

# %%
#predict
y_pred_mn_r2 = saved_mobileNet_model.predict(ds_test_sm_mn_r2, verbose=1)
print(f'y_pred_shape:{y_pred_mn_r2.shape} and shape[0] is: {y_pred_mn_r2.shape[0]}')
# Out:
# 1/1 [==============================] - 1s 819ms/step
# y_pred_shape:(70, 2) and shape[0] is: 70

# %%
plot_evaluation_graphs(y_pred_mn_r2, ds_test_sm_mn_r2)
# Out:
#               precision    recall  f1-score   support
#
#       benign       0.56      0.97      0.71        35
#    malignant       0.89      0.23      0.36        35
#
#    micro avg       0.60      0.60      0.60        70
#    macro avg       0.72      0.60      0.54        70
# weighted avg       0.72      0.60      0.54        70
#  samples avg       0.60      0.60      0.60        70
